# %% [markdown]
# ## 한글 폰트 설정

# %%
# 나눔바른고딕 설치, 설치된 폰트가 matplot에서 보여질 수 있도록 연동
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

# %config InlineBackend.figure_format='retina'

# !apt -qq -y install fonts-nanum

import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=10)
plt.rc('font', family='NanumBarunGothic')
mpl.font_manager._rebuild()
# Out:
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 20 not upgraded.

# %% [markdown]
# ## 한국어 형태소 분석기 Mecab 설치
# - 한국어 자연어 처리 konlpy 라이브러리
# - 형태소 분석기 MeCab 설치
# - 설치 명령어: !curl -s https://raw.githubusercontent.com/teddylee777/machine-learning/master/99-Misc/01-Colab/mecab-colab.sh | bash

# %%
# !curl -s https://raw.githubusercontent.com/teddylee777/machine-learning/master/99-Misc/01-Colab/mecab-colab.sh | bash
# Out:
# --2023-01-02 05:41:21--  https://www.dropbox.com/s/9xls0tgtf3edgns/mecab-0.996-ko-0.9.2.tar.gz?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.2.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.2.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/dl/9xls0tgtf3edgns/mecab-0.996-ko-0.9.2.tar.gz [following]
# --2023-01-02 05:41:21--  https://www.dropbox.com/s/dl/9xls0tgtf3edgns/mecab-0.996-ko-0.9.2.tar.gz
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uca66ff69307d2444b961a2505fb.dl.dropboxusercontent.com/cd/0/get/BzymzL60Ri7DbAN5B-Zobmw7TtDPwHsN7ZJ5Czt6ywZdLgQeAoBi8k-Pi2EmRapJGkDpXWfR_y9i6DhIIYCJGL6hvriFoo_d0sF0cpwuuDPKruWL7bfKSgCRc39SQzwAKssTyMK0ugxM2h2uP4W4BJ4wwHquIvwygKRXxAxl9wZ-FFi4ciui4qr1jcNZtq6GRqQ/file?dl=1# [following]
# --2023-01-02 05:41:21--  https://uca66ff69307d2444b961a2505fb.dl.dropboxusercontent.com/cd/0/get/BzymzL60Ri7DbAN5B-Zobmw7TtDPwHsN7ZJ5Czt6ywZdLgQeAoBi8k-Pi2EmRapJGkDpXWfR_y9i6DhIIYCJGL6hvriFoo_d0sF0cpwuuDPKruWL7bfKSgCRc39SQzwAKssTyMK0ugxM2h2uP4W4BJ4wwHquIvwygKRXxAxl9wZ-FFi4ciui4qr1jcNZtq6GRqQ/file?dl=1
# Resolving uca66ff69307d2444b961a2505fb.dl.dropboxusercontent.com (uca66ff69307d2444b961a2505fb.dl.dropboxusercontent.com)... 162.125.2.15, 2620:100:6021:15::a27d:410f
# Connecting to uca66ff69307d2444b961a2505fb.dl.dropboxusercontent.com (uca66ff69307d2444b961a2505fb.dl.dropboxusercontent.com)|162.125.2.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1414979 (1.3M) [application/binary]
# Saving to: ‘mecab-0.996-ko-0.9.2.tar.gz?dl=1’
#
# mecab-0.996-ko-0.9. 100%[===================>]   1.35M  --.-KB/s    in 0.05s
#
# 2023-01-02 05:41:22 (27.1 MB/s) - ‘mecab-0.996-ko-0.9.2.tar.gz?dl=1’ saved [1414979/1414979]
#
# mecab-0.996-ko-0.9.2/
# mecab-0.996-ko-0.9.2/example/
# mecab-0.996-ko-0.9.2/example/example.cpp
# mecab-0.996-ko-0.9.2/example/example_lattice.cpp
# mecab-0.996-ko-0.9.2/example/example_lattice.c
# mecab-0.996-ko-0.9.2/example/example.c
# mecab-0.996-ko-0.9.2/example/thread_test.cpp
# mecab-0.996-ko-0.9.2/mecab-config.in
# mecab-0.996-ko-0.9.2/man/
# mecab-0.996-ko-0.9.2/man/Makefile.am
# mecab-0.996-ko-0.9.2/man/mecab.1
# mecab-0.996-ko-0.9.2/man/Makefile.in
# mecab-0.996-ko-0.9.2/mecab.iss.in
# mecab-0.996-ko-0.9.2/config.guess
# mecab-0.996-ko-0.9.2/README
# mecab-0.996-ko-0.9.2/COPYING
# mecab-0.996-ko-0.9.2/CHANGES.md
# mecab-0.996-ko-0.9.2/README.md
# mecab-0.996-ko-0.9.2/INSTALL
# mecab-0.996-ko-0.9.2/config.sub
# mecab-0.996-ko-0.9.2/configure.in
# mecab-0.996-ko-0.9.2/swig/
# mecab-0.996-ko-0.9.2/swig/Makefile
# mecab-0.996-ko-0.9.2/swig/version.h.in
# mecab-0.996-ko-0.9.2/swig/version.h
# mecab-0.996-ko-0.9.2/swig/MeCab.i
# mecab-0.996-ko-0.9.2/aclocal.m4
# mecab-0.996-ko-0.9.2/LGPL
# mecab-0.996-ko-0.9.2/Makefile.am
# mecab-0.996-ko-0.9.2/configure
# mecab-0.996-ko-0.9.2/tests/
# mecab-0.996-ko-0.9.2/tests/autolink/
# mecab-0.996-ko-0.9.2/tests/autolink/unk.def
# mecab-0.996-ko-0.9.2/tests/autolink/dicrc
# mecab-0.996-ko-0.9.2/tests/autolink/dic.csv
# mecab-0.996-ko-0.9.2/tests/autolink/test
# mecab-0.996-ko-0.9.2/tests/autolink/char.def
# mecab-0.996-ko-0.9.2/tests/autolink/matrix.def
# mecab-0.996-ko-0.9.2/tests/autolink/test.gld
# mecab-0.996-ko-0.9.2/tests/t9/
# mecab-0.996-ko-0.9.2/tests/t9/unk.def
# mecab-0.996-ko-0.9.2/tests/t9/ipadic.pl
# mecab-0.996-ko-0.9.2/tests/t9/dicrc
# mecab-0.996-ko-0.9.2/tests/t9/dic.csv
# mecab-0.996-ko-0.9.2/tests/t9/test
# mecab-0.996-ko-0.9.2/tests/t9/char.def
# mecab-0.996-ko-0.9.2/tests/t9/matrix.def
# mecab-0.996-ko-0.9.2/tests/t9/mkdic.pl
# mecab-0.996-ko-0.9.2/tests/t9/test.gld
# mecab-0.996-ko-0.9.2/tests/cost-train/
# mecab-0.996-ko-0.9.2/tests/cost-train/ipa.train
# mecab-0.996-ko-0.9.2/tests/cost-train/ipa.test
# mecab-0.996-ko-0.9.2/tests/cost-train/seed/
# mecab-0.996-ko-0.9.2/tests/cost-train/seed/rewrite.def
# mecab-0.996-ko-0.9.2/tests/cost-train/seed/feature.def
# mecab-0.996-ko-0.9.2/tests/cost-train/seed/unk.def
# mecab-0.996-ko-0.9.2/tests/cost-train/seed/dicrc
# mecab-0.996-ko-0.9.2/tests/cost-train/seed/dic.csv
# mecab-0.996-ko-0.9.2/tests/cost-train/seed/char.def
# mecab-0.996-ko-0.9.2/tests/cost-train/seed/matrix.def
# mecab-0.996-ko-0.9.2/tests/run-eval.sh
# mecab-0.996-ko-0.9.2/tests/run-cost-train.sh
# mecab-0.996-ko-0.9.2/tests/Makefile.am
# mecab-0.996-ko-0.9.2/tests/katakana/
# mecab-0.996-ko-0.9.2/tests/katakana/unk.def
# mecab-0.996-ko-0.9.2/tests/katakana/dicrc
# mecab-0.996-ko-0.9.2/tests/katakana/dic.csv
# mecab-0.996-ko-0.9.2/tests/katakana/test
# mecab-0.996-ko-0.9.2/tests/katakana/char.def
# mecab-0.996-ko-0.9.2/tests/katakana/matrix.def
# mecab-0.996-ko-0.9.2/tests/katakana/test.gld
# mecab-0.996-ko-0.9.2/tests/eval/
# mecab-0.996-ko-0.9.2/tests/eval/answer
# mecab-0.996-ko-0.9.2/tests/eval/system
# mecab-0.996-ko-0.9.2/tests/eval/test.gld
# mecab-0.996-ko-0.9.2/tests/shiin/
# mecab-0.996-ko-0.9.2/tests/shiin/unk.def
# mecab-0.996-ko-0.9.2/tests/shiin/dicrc
# mecab-0.996-ko-0.9.2/tests/shiin/dic.csv
# mecab-0.996-ko-0.9.2/tests/shiin/test
# mecab-0.996-ko-0.9.2/tests/shiin/char.def
# mecab-0.996-ko-0.9.2/tests/shiin/matrix.def
# mecab-0.996-ko-0.9.2/tests/shiin/mkdic.pl
# mecab-0.996-ko-0.9.2/tests/shiin/test.gld
# mecab-0.996-ko-0.9.2/tests/latin/
# mecab-0.996-ko-0.9.2/tests/latin/unk.def
# mecab-0.996-ko-0.9.2/tests/latin/dicrc
# mecab-0.996-ko-0.9.2/tests/latin/dic.csv
# mecab-0.996-ko-0.9.2/tests/latin/test
# mecab-0.996-ko-0.9.2/tests/latin/char.def
# mecab-0.996-ko-0.9.2/tests/latin/matrix.def
# mecab-0.996-ko-0.9.2/tests/latin/test.gld
# mecab-0.996-ko-0.9.2/tests/chartype/
# mecab-0.996-ko-0.9.2/tests/chartype/unk.def
# mecab-0.996-ko-0.9.2/tests/chartype/dicrc
# mecab-0.996-ko-0.9.2/tests/chartype/dic.csv
# mecab-0.996-ko-0.9.2/tests/chartype/test
# mecab-0.996-ko-0.9.2/tests/chartype/char.def
# mecab-0.996-ko-0.9.2/tests/chartype/matrix.def
# mecab-0.996-ko-0.9.2/tests/chartype/test.gld
# mecab-0.996-ko-0.9.2/tests/run-dics.sh
# mecab-0.996-ko-0.9.2/tests/ngram/
# mecab-0.996-ko-0.9.2/tests/ngram/unk.def
# mecab-0.996-ko-0.9.2/tests/ngram/dicrc
# mecab-0.996-ko-0.9.2/tests/ngram/dic.csv
# mecab-0.996-ko-0.9.2/tests/ngram/test
# mecab-0.996-ko-0.9.2/tests/ngram/char.def
# mecab-0.996-ko-0.9.2/tests/ngram/matrix.def
# mecab-0.996-ko-0.9.2/tests/ngram/test.gld
# mecab-0.996-ko-0.9.2/tests/Makefile.in
# mecab-0.996-ko-0.9.2/ltmain.sh
# mecab-0.996-ko-0.9.2/config.rpath
# mecab-0.996-ko-0.9.2/config.h.in
# mecab-0.996-ko-0.9.2/mecabrc.in
# mecab-0.996-ko-0.9.2/GPL
# mecab-0.996-ko-0.9.2/Makefile.train
# mecab-0.996-ko-0.9.2/ChangeLog
# mecab-0.996-ko-0.9.2/install-sh
# mecab-0.996-ko-0.9.2/AUTHORS
# mecab-0.996-ko-0.9.2/doc/
# mecab-0.996-ko-0.9.2/doc/bindings.html
# mecab-0.996-ko-0.9.2/doc/posid.html
# mecab-0.996-ko-0.9.2/doc/unk.html
# mecab-0.996-ko-0.9.2/doc/learn.html
# mecab-0.996-ko-0.9.2/doc/format.html
# mecab-0.996-ko-0.9.2/doc/libmecab.html
# mecab-0.996-ko-0.9.2/doc/mecab.css
# mecab-0.996-ko-0.9.2/doc/feature.html
# mecab-0.996-ko-0.9.2/doc/Makefile.am
# mecab-0.996-ko-0.9.2/doc/soft.html
# mecab-0.996-ko-0.9.2/doc/en/
# mecab-0.996-ko-0.9.2/doc/en/bindings.html
# mecab-0.996-ko-0.9.2/doc/dic-detail.html
# mecab-0.996-ko-0.9.2/doc/flow.png
# mecab-0.996-ko-0.9.2/doc/mecab.html
# mecab-0.996-ko-0.9.2/doc/index.html
# mecab-0.996-ko-0.9.2/doc/result.png
# mecab-0.996-ko-0.9.2/doc/doxygen/
# mecab-0.996-ko-0.9.2/doc/doxygen/tab_a.png
# mecab-0.996-ko-0.9.2/doc/doxygen/globals_eval.html
# mecab-0.996-ko-0.9.2/doc/doxygen/classMeCab_1_1Tagger-members.html
# mecab-0.996-ko-0.9.2/doc/doxygen/functions_vars.html
# mecab-0.996-ko-0.9.2/doc/doxygen/doxygen.css
# mecab-0.996-ko-0.9.2/doc/doxygen/tab_r.gif
# mecab-0.996-ko-0.9.2/doc/doxygen/classMeCab_1_1Lattice.html
# mecab-0.996-ko-0.9.2/doc/doxygen/functions.html
# mecab-0.996-ko-0.9.2/doc/doxygen/classMeCab_1_1Tagger.html
# mecab-0.996-ko-0.9.2/doc/doxygen/mecab_8h_source.html
# mecab-0.996-ko-0.9.2/doc/doxygen/tabs.css
# mecab-0.996-ko-0.9.2/doc/doxygen/nav_f.png
# mecab-0.996-ko-0.9.2/doc/doxygen/tab_b.png
# mecab-0.996-ko-0.9.2/doc/doxygen/globals.html
# mecab-0.996-ko-0.9.2/doc/doxygen/nav_h.png
# mecab-0.996-ko-0.9.2/doc/doxygen/tab_h.png
# mecab-0.996-ko-0.9.2/doc/doxygen/classMeCab_1_1Model.html
# mecab-0.996-ko-0.9.2/doc/doxygen/globals_func.html
# mecab-0.996-ko-0.9.2/doc/doxygen/closed.png
# mecab-0.996-ko-0.9.2/doc/doxygen/tab_l.gif
# mecab-0.996-ko-0.9.2/doc/doxygen/structmecab__path__t-members.html
# mecab-0.996-ko-0.9.2/doc/doxygen/functions_func.html
# mecab-0.996-ko-0.9.2/doc/doxygen/globals_type.html
# mecab-0.996-ko-0.9.2/doc/doxygen/classMeCab_1_1Lattice-members.html
# mecab-0.996-ko-0.9.2/doc/doxygen/structmecab__node__t.html
# mecab-0.996-ko-0.9.2/doc/doxygen/namespacemembers_func.html
# mecab-0.996-ko-0.9.2/doc/doxygen/tab_s.png
# mecab-0.996-ko-0.9.2/doc/doxygen/structmecab__dictionary__info__t-members.html
# mecab-0.996-ko-0.9.2/doc/doxygen/namespacemembers_type.html
# mecab-0.996-ko-0.9.2/doc/doxygen/classMeCab_1_1Model-members.html
# mecab-0.996-ko-0.9.2/doc/doxygen/structmecab__dictionary__info__t.html
# mecab-0.996-ko-0.9.2/doc/doxygen/namespaces.html
# mecab-0.996-ko-0.9.2/doc/doxygen/namespacemembers.html
# mecab-0.996-ko-0.9.2/doc/doxygen/namespaceMeCab.html
# mecab-0.996-ko-0.9.2/doc/doxygen/structmecab__path__t.html
# mecab-0.996-ko-0.9.2/doc/doxygen/files.html
# mecab-0.996-ko-0.9.2/doc/doxygen/structmecab__node__t-members.html
# mecab-0.996-ko-0.9.2/doc/doxygen/index.html
# mecab-0.996-ko-0.9.2/doc/doxygen/annotated.html
# mecab-0.996-ko-0.9.2/doc/doxygen/globals_defs.html
# mecab-0.996-ko-0.9.2/doc/doxygen/classes.html
# mecab-0.996-ko-0.9.2/doc/doxygen/mecab_8h-source.html
# mecab-0.996-ko-0.9.2/doc/doxygen/doxygen.png
# mecab-0.996-ko-0.9.2/doc/doxygen/tab_b.gif
# mecab-0.996-ko-0.9.2/doc/doxygen/bc_s.png
# mecab-0.996-ko-0.9.2/doc/doxygen/open.png
# mecab-0.996-ko-0.9.2/doc/doxygen/mecab_8h.html
# mecab-0.996-ko-0.9.2/doc/dic.html
# mecab-0.996-ko-0.9.2/doc/partial.html
# mecab-0.996-ko-0.9.2/doc/feature.png
# mecab-0.996-ko-0.9.2/doc/Makefile.in
# mecab-0.996-ko-0.9.2/missing
# mecab-0.996-ko-0.9.2/BSD
# mecab-0.996-ko-0.9.2/NEWS
# mecab-0.996-ko-0.9.2/mkinstalldirs
# mecab-0.996-ko-0.9.2/src/
# mecab-0.996-ko-0.9.2/src/dictionary.h
# mecab-0.996-ko-0.9.2/src/writer.h
# mecab-0.996-ko-0.9.2/src/utils.h
# mecab-0.996-ko-0.9.2/src/string_buffer.cpp
# mecab-0.996-ko-0.9.2/src/tokenizer.cpp
# mecab-0.996-ko-0.9.2/src/make.bat
# mecab-0.996-ko-0.9.2/src/mecab.h
# mecab-0.996-ko-0.9.2/src/freelist.h
# mecab-0.996-ko-0.9.2/src/string_buffer.h
# mecab-0.996-ko-0.9.2/src/learner_tagger.h
# mecab-0.996-ko-0.9.2/src/dictionary_compiler.cpp
# mecab-0.996-ko-0.9.2/src/eval.cpp
# mecab-0.996-ko-0.9.2/src/mecab-system-eval.cpp
# mecab-0.996-ko-0.9.2/src/darts.h
# mecab-0.996-ko-0.9.2/src/param.h
# mecab-0.996-ko-0.9.2/src/char_property.h
# mecab-0.996-ko-0.9.2/src/learner_node.h
# mecab-0.996-ko-0.9.2/src/mecab-dict-gen.cpp
# mecab-0.996-ko-0.9.2/src/mecab-dict-index.cpp
# mecab-0.996-ko-0.9.2/src/winmain.h
# mecab-0.996-ko-0.9.2/src/thread.h
# mecab-0.996-ko-0.9.2/src/context_id.cpp
# mecab-0.996-ko-0.9.2/src/Makefile.am
# mecab-0.996-ko-0.9.2/src/connector.h
# mecab-0.996-ko-0.9.2/src/common.h
# mecab-0.996-ko-0.9.2/src/dictionary_rewriter.cpp
# mecab-0.996-ko-0.9.2/src/Makefile.msvc.in
# mecab-0.996-ko-0.9.2/src/dictionary_rewriter.h
# mecab-0.996-ko-0.9.2/src/feature_index.h
# mecab-0.996-ko-0.9.2/src/iconv_utils.cpp
# mecab-0.996-ko-0.9.2/src/char_property.cpp
# mecab-0.996-ko-0.9.2/src/mecab-test-gen.cpp
# mecab-0.996-ko-0.9.2/src/tagger.cpp
# mecab-0.996-ko-0.9.2/src/mecab-cost-train.cpp
# mecab-0.996-ko-0.9.2/src/learner.cpp
# mecab-0.996-ko-0.9.2/src/dictionary.cpp
# mecab-0.996-ko-0.9.2/src/lbfgs.cpp
# mecab-0.996-ko-0.9.2/src/ucs.h
# mecab-0.996-ko-0.9.2/src/writer.cpp
# mecab-0.996-ko-0.9.2/src/learner_tagger.cpp
# mecab-0.996-ko-0.9.2/src/lbfgs.h
# mecab-0.996-ko-0.9.2/src/libmecab.cpp
# mecab-0.996-ko-0.9.2/src/tokenizer.h
# mecab-0.996-ko-0.9.2/src/mecab.cpp
# mecab-0.996-ko-0.9.2/src/utils.cpp
# mecab-0.996-ko-0.9.2/src/dictionary_generator.cpp
# mecab-0.996-ko-0.9.2/src/param.cpp
# mecab-0.996-ko-0.9.2/src/context_id.h
# mecab-0.996-ko-0.9.2/src/mmap.h
# mecab-0.996-ko-0.9.2/src/viterbi.h
# mecab-0.996-ko-0.9.2/src/viterbi.cpp
# mecab-0.996-ko-0.9.2/src/stream_wrapper.h
# mecab-0.996-ko-0.9.2/src/feature_index.cpp
# mecab-0.996-ko-0.9.2/src/nbest_generator.h
# mecab-0.996-ko-0.9.2/src/ucstable.h
# mecab-0.996-ko-0.9.2/src/nbest_generator.cpp
# mecab-0.996-ko-0.9.2/src/iconv_utils.h
# mecab-0.996-ko-0.9.2/src/connector.cpp
# mecab-0.996-ko-0.9.2/src/Makefile.in
# mecab-0.996-ko-0.9.2/src/scoped_ptr.h
# mecab-0.996-ko-0.9.2/Makefile.in
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a thread-safe mkdir -p... /bin/mkdir -p
# checking for gawk... no
# checking for mawk... mawk
# checking whether make sets $(MAKE)... yes
# checking for gcc... gcc
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to accept ISO C89... none needed
# checking for style of include used by make... GNU
# checking dependency style of gcc... none
# checking for g++... g++
# checking whether we are using the GNU C++ compiler... yes
# checking whether g++ accepts -g... yes
# checking dependency style of g++... none
# checking how to run the C preprocessor... gcc -E
# checking for grep that handles long lines and -e... /bin/grep
# checking for egrep... /bin/grep -E
# checking whether gcc needs -traditional... no
# checking whether make sets $(MAKE)... (cached) yes
# checking build system type... x86_64-unknown-linux-gnu
# checking host system type... x86_64-unknown-linux-gnu
# checking how to print strings... printf
# checking for a sed that does not truncate output... /bin/sed
# checking for fgrep... /bin/grep -F
# checking for ld used by gcc... /usr/bin/ld
# checking if the linker (/usr/bin/ld) is GNU ld... yes
# checking for BSD- or MS-compatible name lister (nm)... /usr/bin/nm -B
# checking the name lister (/usr/bin/nm -B) interface... BSD nm
# checking whether ln -s works... yes
# checking the maximum length of command line arguments... 1572864
# checking whether the shell understands some XSI constructs... yes
# checking whether the shell understands "+="... yes
# checking how to convert x86_64-unknown-linux-gnu file names to x86_64-unknown-linux-gnu format... func_convert_file_noop
# checking how to convert x86_64-unknown-linux-gnu file names to toolchain format... func_convert_file_noop
# checking for /usr/bin/ld option to reload object files... -r
# checking for objdump... objdump
# checking how to recognize dependent libraries... pass_all
# checking for dlltool... dlltool
# checking how to associate runtime and link libraries... printf %s\n
# checking for ar... ar
# checking for archiver @FILE support... @
# checking for strip... strip
# checking for ranlib... ranlib
# checking command to parse /usr/bin/nm -B output from gcc object... ok
# checking for sysroot... no
# ./configure: line 7378: /usr/bin/file: No such file or directory
# checking for mt... no
# checking if : is a manifest tool... no
# checking for ANSI C header files... yes
# checking for sys/types.h... yes
# checking for sys/stat.h... yes
# checking for stdlib.h... yes
# checking for string.h... yes
# checking for memory.h... yes
# checking for strings.h... yes
# checking for inttypes.h... yes
# checking for stdint.h... yes
# checking for unistd.h... yes
# checking for dlfcn.h... yes
# checking for objdir... .libs
# checking if gcc supports -fno-rtti -fno-exceptions... no
# checking for gcc option to produce PIC... -fPIC -DPIC
# checking if gcc PIC flag -fPIC -DPIC works... yes
# checking if gcc static flag -static works... yes
# checking if gcc supports -c -o file.o... yes
# checking if gcc supports -c -o file.o... (cached) yes
# checking whether the gcc linker (/usr/bin/ld) supports shared libraries... yes
# checking whether -lc should be explicitly linked in... no
# checking dynamic linker characteristics... GNU/Linux ld.so
# checking how to hardcode library paths into programs... immediate
# checking whether stripping libraries is possible... yes
# checking if libtool supports shared libraries... yes
# checking whether to build shared libraries... yes
# checking whether to build static libraries... yes
# checking how to run the C++ preprocessor... g++ -E
# checking for ld used by g++... /usr/bin/ld
# checking if the linker (/usr/bin/ld) is GNU ld... yes
# checking whether the g++ linker (/usr/bin/ld) supports shared libraries... yes
# checking for g++ option to produce PIC... -fPIC -DPIC
# checking if g++ PIC flag -fPIC -DPIC works... yes
# checking if g++ static flag -static works... yes
# checking if g++ supports -c -o file.o... yes
# checking if g++ supports -c -o file.o... (cached) yes
# checking whether the g++ linker (/usr/bin/ld) supports shared libraries... yes
# checking dynamic linker characteristics... (cached) GNU/Linux ld.so
# checking how to hardcode library paths into programs... immediate
# checking for library containing strerror... none required
# checking whether byte ordering is bigendian... no
# checking for ld used by GCC... /usr/bin/ld
# checking if the linker (/usr/bin/ld) is GNU ld... yes
# checking for shared library run path origin... done
# checking for iconv... yes
# checking for working iconv... yes
# checking for iconv declaration...
#          extern size_t iconv (iconv_t cd, char * *inbuf, size_t *inbytesleft, char * *outbuf, size_t *outbytesleft);
# checking for ANSI C header files... (cached) yes
# checking for an ANSI C-conforming const... yes
# checking whether byte ordering is bigendian... (cached) no
# checking for string.h... (cached) yes
# checking for stdlib.h... (cached) yes
# checking for unistd.h... (cached) yes
# checking fcntl.h usability... yes
# checking fcntl.h presence... yes
# checking for fcntl.h... yes
# checking for stdint.h... (cached) yes
# checking for sys/stat.h... (cached) yes
# checking sys/mman.h usability... yes
# checking sys/mman.h presence... yes
# checking for sys/mman.h... yes
# checking sys/times.h usability... yes
# checking sys/times.h presence... yes
# checking for sys/times.h... yes
# checking for sys/types.h... (cached) yes
# checking dirent.h usability... yes
# checking dirent.h presence... yes
# checking for dirent.h... yes
# checking ctype.h usability... yes
# checking ctype.h presence... yes
# checking for ctype.h... yes
# checking for sys/types.h... (cached) yes
# checking io.h usability... no
# checking io.h presence... no
# checking for io.h... no
# checking windows.h usability... no
# checking windows.h presence... no
# checking for windows.h... no
# checking pthread.h usability... yes
# checking pthread.h presence... yes
# checking for pthread.h... yes
# checking for off_t... yes
# checking for size_t... yes
# checking size of char... 1
# checking size of short... 2
# checking size of int... 4
# checking size of long... 8
# checking size of long long... 8
# checking size of size_t... 8
# checking for size_t... (cached) yes
# checking for unsigned long long int... yes
# checking for stdlib.h... (cached) yes
# checking for unistd.h... (cached) yes
# checking for sys/param.h... yes
# checking for getpagesize... yes
# checking for working mmap... yes
# checking for main in -lstdc++... yes
# checking for pthread_create in -lpthread... yes
# checking for pthread_join in -lpthread... yes
# checking for getenv... yes
# checking for opendir... yes
# checking whether make is GNU Make... yes
# checking if g++ supports stl <vector> (required)... yes
# checking if g++ supports stl <list> (required)... yes
# checking if g++ supports stl <map> (required)... yes
# checking if g++ supports stl <set> (required)... yes
# checking if g++ supports stl <queue> (required)... yes
# checking if g++ supports stl <functional> (required)... yes
# checking if g++ supports stl <algorithm> (required)... yes
# checking if g++ supports stl <string> (required)... yes
# checking if g++ supports stl <iostream> (required)... yes
# checking if g++ supports stl <sstream> (required)... yes
# checking if g++ supports stl <fstream> (required)... yes
# checking if g++ supports template <class T> (required)... yes
# checking if g++ supports const_cast<> (required)... yes
# checking if g++ supports static_cast<> (required)... yes
# checking if g++ supports reinterpret_cast<> (required)... yes
# checking if g++ supports namespaces (required) ... yes
# checking if g++ supports __thread (optional)... yes
# checking if g++ supports template <class T> (required)... yes
# checking if g++ supports GCC native atomic operations (optional)... yes
# checking if g++ supports OSX native atomic operations (optional)... no
# checking if g++ environment provides all required features... yes
# configure: creating ./config.status
# config.status: creating Makefile
# config.status: creating src/Makefile
# config.status: creating src/Makefile.msvc
# config.status: creating man/Makefile
# config.status: creating doc/Makefile
# config.status: creating tests/Makefile
# config.status: creating swig/version.h
# config.status: creating mecab.iss
# config.status: creating mecab-config
# config.status: creating mecabrc
# config.status: creating config.h
# config.status: executing depfiles commands
# config.status: executing libtool commands
# config.status: executing default commands
# make  all-recursive
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2'
# Making all in src
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/src'
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o viterbi.lo viterbi.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c viterbi.cpp  -fPIC -DPIC -o .libs/viterbi.o
# In file included from viterbi.cpp:14:0:
# param.h:30:13: warning: 'Target {anonymous}::lexical_cast(Source) [with Target = std::__cxx11::basic_string<char>; Source = std::__cxx11::basic_string<char>]' defined but not used [-Wunused-function]
#  std::string lexical_cast<std::string, std::string>(std::string arg) {
#              ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c viterbi.cpp -o viterbi.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o tagger.lo tagger.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c tagger.cpp  -fPIC -DPIC -o .libs/tagger.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c tagger.cpp -o tagger.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o utils.lo utils.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c utils.cpp  -fPIC -DPIC -o .libs/utils.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c utils.cpp -o utils.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o eval.lo eval.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c eval.cpp  -fPIC -DPIC -o .libs/eval.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c eval.cpp -o eval.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o iconv_utils.lo iconv_utils.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c iconv_utils.cpp  -fPIC -DPIC -o .libs/iconv_utils.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c iconv_utils.cpp -o iconv_utils.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o dictionary_rewriter.lo dictionary_rewriter.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c dictionary_rewriter.cpp  -fPIC -DPIC -o .libs/dictionary_rewriter.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c dictionary_rewriter.cpp -o dictionary_rewriter.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o dictionary_generator.lo dictionary_generator.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c dictionary_generator.cpp  -fPIC -DPIC -o .libs/dictionary_generator.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c dictionary_generator.cpp -o dictionary_generator.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o dictionary_compiler.lo dictionary_compiler.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c dictionary_compiler.cpp  -fPIC -DPIC -o .libs/dictionary_compiler.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c dictionary_compiler.cpp -o dictionary_compiler.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o context_id.lo context_id.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c context_id.cpp  -fPIC -DPIC -o .libs/context_id.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c context_id.cpp -o context_id.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o connector.lo connector.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c connector.cpp  -fPIC -DPIC -o .libs/connector.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c connector.cpp -o connector.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o nbest_generator.lo nbest_generator.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c nbest_generator.cpp  -fPIC -DPIC -o .libs/nbest_generator.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c nbest_generator.cpp -o nbest_generator.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o writer.lo writer.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c writer.cpp  -fPIC -DPIC -o .libs/writer.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c writer.cpp -o writer.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o string_buffer.lo string_buffer.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c string_buffer.cpp  -fPIC -DPIC -o .libs/string_buffer.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c string_buffer.cpp -o string_buffer.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o param.lo param.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c param.cpp  -fPIC -DPIC -o .libs/param.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c param.cpp -o param.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o tokenizer.lo tokenizer.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c tokenizer.cpp  -fPIC -DPIC -o .libs/tokenizer.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c tokenizer.cpp -o tokenizer.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o char_property.lo char_property.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c char_property.cpp  -fPIC -DPIC -o .libs/char_property.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c char_property.cpp -o char_property.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o dictionary.lo dictionary.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c dictionary.cpp  -fPIC -DPIC -o .libs/dictionary.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c dictionary.cpp -o dictionary.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o feature_index.lo feature_index.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c feature_index.cpp  -fPIC -DPIC -o .libs/feature_index.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c feature_index.cpp -o feature_index.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o lbfgs.lo lbfgs.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c lbfgs.cpp  -fPIC -DPIC -o .libs/lbfgs.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c lbfgs.cpp -o lbfgs.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o learner_tagger.lo learner_tagger.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c learner_tagger.cpp  -fPIC -DPIC -o .libs/learner_tagger.o
# learner_tagger.cpp:25:7: warning: 'char* MeCab::{anonymous}::mystrdup(const string&)' defined but not used [-Wunused-function]
#  char *mystrdup(const std::string &str) {
#        ^~~~~~~~
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c learner_tagger.cpp -o learner_tagger.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o learner.lo learner.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c learner.cpp  -fPIC -DPIC -o .libs/learner.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c learner.cpp -o learner.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o libmecab.lo libmecab.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c libmecab.cpp  -fPIC -DPIC -o .libs/libmecab.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c libmecab.cpp -o libmecab.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=link g++  -O3 -Wall  -no-undefined -version-info 2:0:0  -o libmecab.la -rpath /usr/local/lib viterbi.lo tagger.lo utils.lo eval.lo iconv_utils.lo dictionary_rewriter.lo dictionary_generator.lo dictionary_compiler.lo context_id.lo connector.lo nbest_generator.lo writer.lo string_buffer.lo param.lo tokenizer.lo char_property.lo dictionary.lo feature_index.lo lbfgs.lo learner_tagger.lo learner.lo libmecab.lo  -lpthread -lpthread  -lstdc++
# libtool: link: g++  -fPIC -DPIC -shared -nostdlib /usr/lib/gcc/x86_64-linux-gnu/7/../../../x86_64-linux-gnu/crti.o /usr/lib/gcc/x86_64-linux-gnu/7/crtbeginS.o  .libs/viterbi.o .libs/tagger.o .libs/utils.o .libs/eval.o .libs/iconv_utils.o .libs/dictionary_rewriter.o .libs/dictionary_generator.o .libs/dictionary_compiler.o .libs/context_id.o .libs/connector.o .libs/nbest_generator.o .libs/writer.o .libs/string_buffer.o .libs/param.o .libs/tokenizer.o .libs/char_property.o .libs/dictionary.o .libs/feature_index.o .libs/lbfgs.o .libs/learner_tagger.o .libs/learner.o .libs/libmecab.o   -lpthread -L/usr/lib/gcc/x86_64-linux-gnu/7 -L/usr/lib/gcc/x86_64-linux-gnu/7/../../../x86_64-linux-gnu -L/usr/lib/gcc/x86_64-linux-gnu/7/../../../../lib -L/lib/x86_64-linux-gnu -L/lib/../lib -L/usr/lib/x86_64-linux-gnu -L/usr/lib/../lib -L/usr/local/cuda/lib64/stubs -L/usr/lib/gcc/x86_64-linux-gnu/7/../../.. -lstdc++ -lm -lc -lgcc_s /usr/lib/gcc/x86_64-linux-gnu/7/crtendS.o /usr/lib/gcc/x86_64-linux-gnu/7/../../../x86_64-linux-gnu/crtn.o  -O3   -Wl,-soname -Wl,libmecab.so.2 -o .libs/libmecab.so.2.0.0
# libtool: link: (cd ".libs" && rm -f "libmecab.so.2" && ln -s "libmecab.so.2.0.0" "libmecab.so.2")
# libtool: link: (cd ".libs" && rm -f "libmecab.so" && ln -s "libmecab.so.2.0.0" "libmecab.so")
# libtool: link: ar cru .libs/libmecab.a  viterbi.o tagger.o utils.o eval.o iconv_utils.o dictionary_rewriter.o dictionary_generator.o dictionary_compiler.o context_id.o connector.o nbest_generator.o writer.o string_buffer.o param.o tokenizer.o char_property.o dictionary.o feature_index.o lbfgs.o learner_tagger.o learner.o libmecab.o
# ar: `u' modifier ignored since `D' is the default (see `U')
# libtool: link: ranlib .libs/libmecab.a
# libtool: link: ( cd ".libs" && rm -f "libmecab.la" && ln -s "../libmecab.la" "libmecab.la" )
# g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o mecab.o mecab.cpp
# /bin/bash ../libtool --tag=CXX   --mode=link g++  -O3 -Wall    -o mecab mecab.o libmecab.la -lpthread -lpthread  -lstdc++
# libtool: link: g++ -O3 -Wall -o .libs/mecab mecab.o  ./.libs/libmecab.so -lpthread -lstdc++
# g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o mecab-dict-index.o mecab-dict-index.cpp
# /bin/bash ../libtool --tag=CXX   --mode=link g++  -O3 -Wall    -o mecab-dict-index mecab-dict-index.o libmecab.la -lpthread -lpthread  -lstdc++
# libtool: link: g++ -O3 -Wall -o .libs/mecab-dict-index mecab-dict-index.o  ./.libs/libmecab.so -lpthread -lstdc++
# g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o mecab-dict-gen.o mecab-dict-gen.cpp
# /bin/bash ../libtool --tag=CXX   --mode=link g++  -O3 -Wall    -o mecab-dict-gen mecab-dict-gen.o libmecab.la -lpthread -lpthread  -lstdc++
# libtool: link: g++ -O3 -Wall -o .libs/mecab-dict-gen mecab-dict-gen.o  ./.libs/libmecab.so -lpthread -lstdc++
# g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o mecab-cost-train.o mecab-cost-train.cpp
# /bin/bash ../libtool --tag=CXX   --mode=link g++  -O3 -Wall    -o mecab-cost-train mecab-cost-train.o libmecab.la -lpthread -lpthread  -lstdc++
# libtool: link: g++ -O3 -Wall -o .libs/mecab-cost-train mecab-cost-train.o  ./.libs/libmecab.so -lpthread -lstdc++
# g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o mecab-system-eval.o mecab-system-eval.cpp
# /bin/bash ../libtool --tag=CXX   --mode=link g++  -O3 -Wall    -o mecab-system-eval mecab-system-eval.o libmecab.la -lpthread -lpthread  -lstdc++
# libtool: link: g++ -O3 -Wall -o .libs/mecab-system-eval mecab-system-eval.o  ./.libs/libmecab.so -lpthread -lstdc++
# g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o mecab-test-gen.o mecab-test-gen.cpp
# /bin/bash ../libtool --tag=CXX   --mode=link g++  -O3 -Wall    -o mecab-test-gen mecab-test-gen.o libmecab.la -lpthread -lpthread  -lstdc++
# libtool: link: g++ -O3 -Wall -o .libs/mecab-test-gen mecab-test-gen.o  ./.libs/libmecab.so -lpthread -lstdc++
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/src'
# Making all in man
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/man'
# make[2]: Nothing to be done for 'all'.
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/man'
# Making all in doc
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/doc'
# make[2]: Nothing to be done for 'all'.
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/doc'
# Making all in tests
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/tests'
# make[2]: Nothing to be done for 'all'.
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/tests'
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2'
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2'
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2'
# Making check in src
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/src'
# make[1]: Nothing to be done for 'check'.
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/src'
# Making check in man
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/man'
# make[1]: Nothing to be done for 'check'.
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/man'
# Making check in doc
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/doc'
# make[1]: Nothing to be done for 'check'.
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/doc'
# Making check in tests
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/tests'
# make  check-TESTS
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/tests'
# ./pos-id.def is not found. minimum setting is used
# reading ./unk.def ... 2
# emitting double-array: 100% |###########################################|
# ./model.def is not found. skipped.
# ./pos-id.def is not found. minimum setting is used
# reading ./dic.csv ... 177
# emitting double-array: 100% |###########################################|
# reading ./matrix.def ... 178x178
# emitting matrix      : 100% |###########################################|
#
# done!
# ./pos-id.def is not found. minimum setting is used
# reading ./unk.def ... 2
# emitting double-array: 100% |###########################################|
# ./model.def is not found. skipped.
# ./pos-id.def is not found. minimum setting is used
# reading ./dic.csv ... 83
# emitting double-array: 100% |###########################################|
# reading ./matrix.def ... 84x84
# emitting matrix      : 100% |###########################################|
#
# done!
# ./pos-id.def is not found. minimum setting is used
# reading ./unk.def ... 2
# emitting double-array: 100% |###########################################|
# ./model.def is not found. skipped.
# ./pos-id.def is not found. minimum setting is used
# reading ./dic.csv ... 450
# emitting double-array: 100% |###########################################|
# reading ./matrix.def ... 1x1
#
# done!
# ./pos-id.def is not found. minimum setting is used
# reading ./unk.def ... 2
# emitting double-array: 100% |###########################################|
# ./model.def is not found. skipped.
# ./pos-id.def is not found. minimum setting is used
# reading ./dic.csv ... 162
# emitting double-array: 100% |###########################################|
# reading ./matrix.def ... 3x3
# emitting matrix      : 100% |###########################################|
#
# done!
# ./pos-id.def is not found. minimum setting is used
# reading ./unk.def ... 2
# emitting double-array: 100% |###########################################|
# ./model.def is not found. skipped.
# ./pos-id.def is not found. minimum setting is used
# reading ./dic.csv ... 4
# emitting double-array: 100% |###########################################|
# reading ./matrix.def ... 1x1
#
# done!
# ./pos-id.def is not found. minimum setting is used
# reading ./unk.def ... 11
# emitting double-array: 100% |###########################################|
# ./model.def is not found. skipped.
# ./pos-id.def is not found. minimum setting is used
# reading ./dic.csv ... 1
# reading ./matrix.def ... 1x1
#
# done!
# ./pos-id.def is not found. minimum setting is used
# reading ./unk.def ... 2
# emitting double-array: 100% |###########################################|
# ./model.def is not found. skipped.
# ./pos-id.def is not found. minimum setting is used
# reading ./dic.csv ... 1
# reading ./matrix.def ... 1x1
#
# done!
# PASS: run-dics.sh
# PASS: run-eval.sh
# seed/pos-id.def is not found. minimum setting is used
# reading seed/unk.def ... 40
# emitting double-array: 100% |###########################################|
# seed/model.def is not found. skipped.
# seed/pos-id.def is not found. minimum setting is used
# reading seed/dic.csv ... 4335
# emitting double-array: 100% |###########################################|
# reading seed/matrix.def ... 1x1
#
# done!
# reading corpus ...
# Number of sentences: 34
# Number of features:  64108
# eta:                 0.00005
# freq:                1
# eval-size:           6
# unk-eval-size:       4
# threads:             1
# charset:             EUC-JP
# C(sigma^2):          1.00000
#
# iter=0 err=1.00000 F=0.35771 target=2406.28355 diff=1.00000
# iter=1 err=0.97059 F=0.65652 target=1484.25231 diff=0.38318
# iter=2 err=0.91176 F=0.79331 target=863.32765 diff=0.41834
# iter=3 err=0.85294 F=0.89213 target=596.72480 diff=0.30881
# iter=4 err=0.61765 F=0.95467 target=336.30744 diff=0.43641
# iter=5 err=0.50000 F=0.96702 target=246.53039 diff=0.26695
# iter=6 err=0.35294 F=0.95472 target=188.93963 diff=0.23361
# iter=7 err=0.20588 F=0.99106 target=168.62665 diff=0.10751
# iter=8 err=0.05882 F=0.99777 target=158.64865 diff=0.05917
# iter=9 err=0.08824 F=0.99665 target=154.14530 diff=0.02839
# iter=10 err=0.08824 F=0.99665 target=151.94257 diff=0.01429
# iter=11 err=0.02941 F=0.99888 target=147.20825 diff=0.03116
# iter=12 err=0.00000 F=1.00000 target=147.34956 diff=0.00096
# iter=13 err=0.02941 F=0.99888 target=146.32592 diff=0.00695
# iter=14 err=0.00000 F=1.00000 target=145.77299 diff=0.00378
# iter=15 err=0.02941 F=0.99888 target=145.24641 diff=0.00361
# iter=16 err=0.00000 F=1.00000 target=144.96490 diff=0.00194
# iter=17 err=0.02941 F=0.99888 target=144.90246 diff=0.00043
# iter=18 err=0.00000 F=1.00000 target=144.75959 diff=0.00099
# iter=19 err=0.00000 F=1.00000 target=144.71727 diff=0.00029
# iter=20 err=0.00000 F=1.00000 target=144.66337 diff=0.00037
# iter=21 err=0.00000 F=1.00000 target=144.61349 diff=0.00034
# iter=22 err=0.00000 F=1.00000 target=144.62987 diff=0.00011
# iter=23 err=0.00000 F=1.00000 target=144.60060 diff=0.00020
# iter=24 err=0.00000 F=1.00000 target=144.59125 diff=0.00006
# iter=25 err=0.00000 F=1.00000 target=144.58619 diff=0.00004
# iter=26 err=0.00000 F=1.00000 target=144.58219 diff=0.00003
# iter=27 err=0.00000 F=1.00000 target=144.58059 diff=0.00001
#
# Done! writing model file ...
# model-ipadic.c1.0.f1.model is not a binary model. reopen it as text mode...
# reading seed/unk.def ... 40
# reading seed/dic.csv ... 4335
# emitting model-ipadic.c1.0.f1.dic/left-id.def/ model-ipadic.c1.0.f1.dic/right-id.def
# emitting model-ipadic.c1.0.f1.dic/unk.def ... 40
# emitting model-ipadic.c1.0.f1.dic/dic.csv ... 4335
# emitting matrix      : 100% |###########################################|
# copying seed/char.def to model-ipadic.c1.0.f1.dic/char.def
# copying seed/rewrite.def to model-ipadic.c1.0.f1.dic/rewrite.def
# copying seed/dicrc to model-ipadic.c1.0.f1.dic/dicrc
# copying seed/feature.def to model-ipadic.c1.0.f1.dic/feature.def
# copying model-ipadic.c1.0.f1.model to model-ipadic.c1.0.f1.dic/model.def
#
# done!
# model-ipadic.c1.0.f1.dic/pos-id.def is not found. minimum setting is used
# reading model-ipadic.c1.0.f1.dic/unk.def ... 40
# emitting double-array: 100% |###########################################|
# model-ipadic.c1.0.f1.dic/pos-id.def is not found. minimum setting is used
# reading model-ipadic.c1.0.f1.dic/dic.csv ... 4335
# emitting double-array: 100% |###########################################|
# reading model-ipadic.c1.0.f1.dic/matrix.def ... 346x346
# emitting matrix      : 100% |###########################################|
#
# done!
#               precision          recall         F
# LEVEL 0:    12.8959(57/442) 11.8998(57/479) 12.3779
# LEVEL 1:    12.2172(54/442) 11.2735(54/479) 11.7264
# LEVEL 2:    11.7647(52/442) 10.8559(52/479) 11.2921
# LEVEL 4:    11.7647(52/442) 10.8559(52/479) 11.2921
# PASS: run-cost-train.sh
# ==================
# All 3 tests passed
# ==================
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/tests'
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/tests'
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2'
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2'
# Making install in src
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/src'
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/src'
# test -z "/usr/local/lib" || /bin/mkdir -p "/usr/local/lib"
#  /bin/bash ../libtool   --mode=install /usr/bin/install -c   libmecab.la '/usr/local/lib'
# libtool: install: /usr/bin/install -c .libs/libmecab.so.2.0.0 /usr/local/lib/libmecab.so.2.0.0
# libtool: install: (cd /usr/local/lib && { ln -s -f libmecab.so.2.0.0 libmecab.so.2 || { rm -f libmecab.so.2 && ln -s libmecab.so.2.0.0 libmecab.so.2; }; })
# libtool: install: (cd /usr/local/lib && { ln -s -f libmecab.so.2.0.0 libmecab.so || { rm -f libmecab.so && ln -s libmecab.so.2.0.0 libmecab.so; }; })
# libtool: install: /usr/bin/install -c .libs/libmecab.lai /usr/local/lib/libmecab.la
# libtool: install: /usr/bin/install -c .libs/libmecab.a /usr/local/lib/libmecab.a
# libtool: install: chmod 644 /usr/local/lib/libmecab.a
# libtool: install: ranlib /usr/local/lib/libmecab.a
# libtool: finish: PATH="/opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/sbin" ldconfig -n /usr/local/lib
# ----------------------------------------------------------------------
# Libraries have been installed in:
#    /usr/local/lib
#
# ...
#    - add LIBDIR to the `LD_RUN_PATH' environment variable
#      during linking
#    - use the `-Wl,-rpath -Wl,LIBDIR' linker flag
#    - have your system administrator add LIBDIR to `/etc/ld.so.conf'
#
# See any operating system documentation about shared libraries for
# more information, such as the ld(1) and ld.so(8) manual pages.
# ----------------------------------------------------------------------
# test -z "/usr/local/bin" || /bin/mkdir -p "/usr/local/bin"
#   /bin/bash ../libtool   --mode=install /usr/bin/install -c mecab '/usr/local/bin'
# libtool: install: /usr/bin/install -c .libs/mecab /usr/local/bin/mecab
# test -z "/usr/local/libexec/mecab" || /bin/mkdir -p "/usr/local/libexec/mecab"
#   /bin/bash ../libtool   --mode=install /usr/bin/install -c mecab-dict-index mecab-dict-gen mecab-cost-train mecab-system-eval mecab-test-gen '/usr/local/libexec/mecab'
# libtool: install: /usr/bin/install -c .libs/mecab-dict-index /usr/local/libexec/mecab/mecab-dict-index
# libtool: install: /usr/bin/install -c .libs/mecab-dict-gen /usr/local/libexec/mecab/mecab-dict-gen
# libtool: install: /usr/bin/install -c .libs/mecab-cost-train /usr/local/libexec/mecab/mecab-cost-train
# libtool: install: /usr/bin/install -c .libs/mecab-system-eval /usr/local/libexec/mecab/mecab-system-eval
# libtool: install: /usr/bin/install -c .libs/mecab-test-gen /usr/local/libexec/mecab/mecab-test-gen
# test -z "/usr/local/include" || /bin/mkdir -p "/usr/local/include"
#  /usr/bin/install -c -m 644 mecab.h '/usr/local/include'
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/src'
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/src'
# Making install in man
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/man'
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/man'
# make[2]: Nothing to be done for 'install-exec-am'.
# test -z "/usr/local/share/man/man1" || /bin/mkdir -p "/usr/local/share/man/man1"
#  /usr/bin/install -c -m 644 mecab.1 '/usr/local/share/man/man1'
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/man'
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/man'
# Making install in doc
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/doc'
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/doc'
# make[2]: Nothing to be done for 'install-exec-am'.
# make[2]: Nothing to be done for 'install-data-am'.
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/doc'
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/doc'
# Making install in tests
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/tests'
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/tests'
# make[2]: Nothing to be done for 'install-exec-am'.
# make[2]: Nothing to be done for 'install-data-am'.
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/tests'
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/tests'
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2'
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2'
# test -z "/usr/local/bin" || /bin/mkdir -p "/usr/local/bin"
#  /usr/bin/install -c mecab-config '/usr/local/bin'
# test -z "/usr/local/etc" || /bin/mkdir -p "/usr/local/etc"
#  /usr/bin/install -c -m 644 mecabrc '/usr/local/etc'
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2'
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2'
# --2023-01-02 05:42:58--  https://www.dropbox.com/s/i8girnk5p80076c/mecab-ko-dic-2.1.1-20180720.tar.gz?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.2.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.2.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/dl/i8girnk5p80076c/mecab-ko-dic-2.1.1-20180720.tar.gz [following]
# --2023-01-02 05:42:59--  https://www.dropbox.com/s/dl/i8girnk5p80076c/mecab-ko-dic-2.1.1-20180720.tar.gz
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucda3155d6ab4e780d541bc4f1ba.dl.dropboxusercontent.com/cd/0/get/Bzyo0-8KhomvdLOxcTT9TqnRSaLdEDds2KvrE3bT4gdm0yScVF1cvOeCQZissV0buKSIMy3ziRvukRed2cxbv4F9xKfzSsYh7tzC7oSrbFU17VWDvjN3kxyDWHPPSWXkhya1oh6UKFU7j27GeaaERsRXF4brgP6g6uIN7v6rb9E9olwvEUbWalk15OMmSLX98WQ/file?dl=1# [following]
# --2023-01-02 05:42:59--  https://ucda3155d6ab4e780d541bc4f1ba.dl.dropboxusercontent.com/cd/0/get/Bzyo0-8KhomvdLOxcTT9TqnRSaLdEDds2KvrE3bT4gdm0yScVF1cvOeCQZissV0buKSIMy3ziRvukRed2cxbv4F9xKfzSsYh7tzC7oSrbFU17VWDvjN3kxyDWHPPSWXkhya1oh6UKFU7j27GeaaERsRXF4brgP6g6uIN7v6rb9E9olwvEUbWalk15OMmSLX98WQ/file?dl=1
# Resolving ucda3155d6ab4e780d541bc4f1ba.dl.dropboxusercontent.com (ucda3155d6ab4e780d541bc4f1ba.dl.dropboxusercontent.com)... 162.125.65.15, 2620:100:6017:15::a27d:20f
# Connecting to ucda3155d6ab4e780d541bc4f1ba.dl.dropboxusercontent.com (ucda3155d6ab4e780d541bc4f1ba.dl.dropboxusercontent.com)|162.125.65.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49775061 (47M) [application/binary]
# Saving to: ‘mecab-ko-dic-2.1.1-20180720.tar.gz?dl=1’
#
# mecab-ko-dic-2.1.1- 100%[===================>]  47.47M  14.8MB/s    in 4.0s
#
# 2023-01-02 05:43:04 (11.8 MB/s) - ‘mecab-ko-dic-2.1.1-20180720.tar.gz?dl=1’ saved [49775061/49775061]
#
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   automake autotools-dev libsigsegv2 m4
# Suggested packages:
#   autoconf-archive gnu-standards autoconf-doc libtool gettext m4-doc
# The following NEW packages will be installed:
#   autoconf automake autotools-dev libsigsegv2 m4
# 0 upgraded, 5 newly installed, 0 to remove and 20 not upgraded.
# Need to get 1,082 kB of archives.
# After this operation, 3,994 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsigsegv2 amd64 2.12-1 [14.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 m4 amd64 1.4.18-1 [197 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 autoconf all 2.69-11 [322 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 autotools-dev all 20180224.1 [39.6 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 automake all 1:1.15.1-3ubuntu2 [509 kB]
# Fetched 1,082 kB in 1s (1,590 kB/s)
# Selecting previously unselected package libsigsegv2:amd64.
# (Reading database ... 124016 files and directories currently installed.)
# Preparing to unpack .../libsigsegv2_2.12-1_amd64.deb ...
# Unpacking libsigsegv2:amd64 (2.12-1) ...
# Selecting previously unselected package m4.
# Preparing to unpack .../archives/m4_1.4.18-1_amd64.deb ...
# Unpacking m4 (1.4.18-1) ...
# Selecting previously unselected package autoconf.
# Preparing to unpack .../autoconf_2.69-11_all.deb ...
# Unpacking autoconf (2.69-11) ...
# Selecting previously unselected package autotools-dev.
# Preparing to unpack .../autotools-dev_20180224.1_all.deb ...
# Unpacking autotools-dev (20180224.1) ...
# Selecting previously unselected package automake.
# Preparing to unpack .../automake_1%3a1.15.1-3ubuntu2_all.deb ...
# Unpacking automake (1:1.15.1-3ubuntu2) ...
# Setting up libsigsegv2:amd64 (2.12-1) ...
# Setting up m4 (1.4.18-1) ...
# Setting up autotools-dev (20180224.1) ...
# Setting up autoconf (2.69-11) ...
# Setting up automake (1:1.15.1-3ubuntu2) ...
# update-alternatives: using /usr/bin/automake-1.15 to provide /usr/bin/automake (automake) in auto mode
# Processing triggers for libc-bin (2.27-3ubuntu1.6) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# mecab-ko-dic-2.1.1-20180720/
# mecab-ko-dic-2.1.1-20180720/configure
# mecab-ko-dic-2.1.1-20180720/COPYING
# mecab-ko-dic-2.1.1-20180720/autogen.sh
# mecab-ko-dic-2.1.1-20180720/Place-station.csv
# mecab-ko-dic-2.1.1-20180720/NNG.csv
# mecab-ko-dic-2.1.1-20180720/README
# mecab-ko-dic-2.1.1-20180720/EF.csv
# mecab-ko-dic-2.1.1-20180720/MAG.csv
# mecab-ko-dic-2.1.1-20180720/Preanalysis.csv
# mecab-ko-dic-2.1.1-20180720/NNB.csv
# mecab-ko-dic-2.1.1-20180720/Person-actor.csv
# mecab-ko-dic-2.1.1-20180720/VV.csv
# mecab-ko-dic-2.1.1-20180720/Makefile.in
# mecab-ko-dic-2.1.1-20180720/matrix.def
# mecab-ko-dic-2.1.1-20180720/EC.csv
# mecab-ko-dic-2.1.1-20180720/NNBC.csv
# mecab-ko-dic-2.1.1-20180720/clean
# mecab-ko-dic-2.1.1-20180720/ChangeLog
# mecab-ko-dic-2.1.1-20180720/J.csv
# mecab-ko-dic-2.1.1-20180720/.keep
# mecab-ko-dic-2.1.1-20180720/feature.def
# mecab-ko-dic-2.1.1-20180720/Foreign.csv
# mecab-ko-dic-2.1.1-20180720/XPN.csv
# mecab-ko-dic-2.1.1-20180720/EP.csv
# mecab-ko-dic-2.1.1-20180720/NR.csv
# mecab-ko-dic-2.1.1-20180720/left-id.def
# mecab-ko-dic-2.1.1-20180720/Place.csv
# mecab-ko-dic-2.1.1-20180720/Symbol.csv
# mecab-ko-dic-2.1.1-20180720/dicrc
# mecab-ko-dic-2.1.1-20180720/NP.csv
# mecab-ko-dic-2.1.1-20180720/ETM.csv
# mecab-ko-dic-2.1.1-20180720/IC.csv
# mecab-ko-dic-2.1.1-20180720/Place-address.csv
# mecab-ko-dic-2.1.1-20180720/Group.csv
# mecab-ko-dic-2.1.1-20180720/model.def
# mecab-ko-dic-2.1.1-20180720/XSN.csv
# mecab-ko-dic-2.1.1-20180720/INSTALL
# mecab-ko-dic-2.1.1-20180720/rewrite.def
# mecab-ko-dic-2.1.1-20180720/Inflect.csv
# mecab-ko-dic-2.1.1-20180720/configure.ac
# mecab-ko-dic-2.1.1-20180720/NNP.csv
# mecab-ko-dic-2.1.1-20180720/CoinedWord.csv
# mecab-ko-dic-2.1.1-20180720/XSV.csv
# mecab-ko-dic-2.1.1-20180720/pos-id.def
# mecab-ko-dic-2.1.1-20180720/Makefile.am
# mecab-ko-dic-2.1.1-20180720/unk.def
# mecab-ko-dic-2.1.1-20180720/missing
# mecab-ko-dic-2.1.1-20180720/VCP.csv
# mecab-ko-dic-2.1.1-20180720/install-sh
# mecab-ko-dic-2.1.1-20180720/Hanja.csv
# mecab-ko-dic-2.1.1-20180720/MAJ.csv
# mecab-ko-dic-2.1.1-20180720/XSA.csv
# mecab-ko-dic-2.1.1-20180720/Wikipedia.csv
# mecab-ko-dic-2.1.1-20180720/tools/
# mecab-ko-dic-2.1.1-20180720/tools/add-userdic.sh
# mecab-ko-dic-2.1.1-20180720/tools/mecab-bestn.sh
# mecab-ko-dic-2.1.1-20180720/tools/convert_for_using_store.sh
# mecab-ko-dic-2.1.1-20180720/user-dic/
# mecab-ko-dic-2.1.1-20180720/user-dic/nnp.csv
# mecab-ko-dic-2.1.1-20180720/user-dic/place.csv
# mecab-ko-dic-2.1.1-20180720/user-dic/person.csv
# mecab-ko-dic-2.1.1-20180720/user-dic/README.md
# mecab-ko-dic-2.1.1-20180720/NorthKorea.csv
# mecab-ko-dic-2.1.1-20180720/VX.csv
# mecab-ko-dic-2.1.1-20180720/right-id.def
# mecab-ko-dic-2.1.1-20180720/VA.csv
# mecab-ko-dic-2.1.1-20180720/char.def
# mecab-ko-dic-2.1.1-20180720/NEWS
# mecab-ko-dic-2.1.1-20180720/MM.csv
# mecab-ko-dic-2.1.1-20180720/ETN.csv
# mecab-ko-dic-2.1.1-20180720/AUTHORS
# mecab-ko-dic-2.1.1-20180720/Person.csv
# mecab-ko-dic-2.1.1-20180720/XR.csv
# mecab-ko-dic-2.1.1-20180720/VCN.csv
# Looking in current directory for macros.
# configure.ac:2: warning: AM_INIT_AUTOMAKE: two- and three-arguments forms are deprecated.  For more info, see:
# configure.ac:2: http://www.gnu.org/software/automake/manual/automake.html#Modernize-AM_005fINIT_005fAUTOMAKE-invocation
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# /tmp/mecab-ko-dic-2.1.1-20180720/missing: Unknown `--is-lightweight' option
# Try `/tmp/mecab-ko-dic-2.1.1-20180720/missing --help' for more information
# configure: WARNING: 'missing' script is too old or missing
# checking for a thread-safe mkdir -p... /bin/mkdir -p
# checking for gawk... no
# checking for mawk... mawk
# checking whether make sets $(MAKE)... yes
# checking whether make supports nested variables... yes
# checking for mecab-config... /usr/local/bin/mecab-config
# checking that generated files are newer than configure... done
# configure: creating ./config.status
# config.status: creating Makefile
# /usr/local/libexec/mecab/mecab-dict-index -d . -o . -f UTF-8 -t UTF-8
# reading ./unk.def ... 13
# emitting double-array: 100% |###########################################|
# reading ./Symbol.csv ... 16
# reading ./Hanja.csv ... 125750
# reading ./XR.csv ... 3637
# reading ./J.csv ... 416
# reading ./Inflect.csv ... 44820
# reading ./EC.csv ... 2547
# reading ./XSV.csv ... 23
# reading ./NNG.csv ... 208524
# reading ./NNB.csv ... 140
# reading ./NR.csv ... 482
# reading ./VA.csv ... 2360
# reading ./MAJ.csv ... 240
# reading ./ETN.csv ... 14
# reading ./VV.csv ... 7331
# reading ./IC.csv ... 1305
# reading ./Foreign.csv ... 11690
# reading ./Person.csv ... 196459
# reading ./VCN.csv ... 7
# reading ./MAG.csv ... 14242
# reading ./CoinedWord.csv ... 148
# reading ./NNBC.csv ... 677
# reading ./XPN.csv ... 83
# reading ./Preanalysis.csv ... 5
# reading ./Place.csv ... 30303
# reading ./Wikipedia.csv ... 36762
# reading ./Place-address.csv ... 19301
# reading ./Person-actor.csv ... 99230
# reading ./EP.csv ... 51
# reading ./Group.csv ... 3176
# reading ./VX.csv ... 125
# reading ./EF.csv ... 1820
# reading ./NorthKorea.csv ... 3
# reading ./VCP.csv ... 9
# reading ./XSA.csv ... 19
# reading ./XSN.csv ... 124
# reading ./MM.csv ... 453
# reading ./Place-station.csv ... 1145
# reading ./NNP.csv ... 2371
# reading ./NP.csv ... 342
# reading ./ETM.csv ... 133
# emitting double-array: 100% |###########################################|
# reading ./matrix.def ... 3822x2693
# emitting matrix      : 100% |###########################################|
#
# done!
# echo To enable dictionary, rewrite /usr/local/etc/mecabrc as \"dicdir = /usr/local/lib/mecab/dic/mecab-ko-dic\"
# To enable dictionary, rewrite /usr/local/etc/mecabrc as "dicdir = /usr/local/lib/mecab/dic/mecab-ko-dic"
# make[1]: Entering directory '/tmp/mecab-ko-dic-2.1.1-20180720'
# make[1]: Nothing to be done for 'install-exec-am'.
#  /bin/mkdir -p '/usr/local/lib/mecab/dic/mecab-ko-dic'
#  /usr/bin/install -c -m 644 model.bin matrix.bin char.bin sys.dic unk.dic left-id.def right-id.def rewrite.def pos-id.def dicrc '/usr/local/lib/mecab/dic/mecab-ko-dic'
# make[1]: Leaving directory '/tmp/mecab-ko-dic-2.1.1-20180720'
# Cloning into 'mecab-python-0.996'...
# Unpacking objects: 100% (17/17), done.
# running build
# running build_py
# creating build
# creating build/lib.linux-x86_64-3.8
# copying MeCab.py -> build/lib.linux-x86_64-3.8
# running build_ext
# building '_MeCab' extension
# creating build/temp.linux-x86_64-3.8
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/include -I/usr/include/python3.8 -c MeCab_wrap.cxx -o build/temp.linux-x86_64-3.8/MeCab_wrap.o
# x86_64-linux-gnu-g++ -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 -Wl,-Bsymbolic-functions -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 build/temp.linux-x86_64-3.8/MeCab_wrap.o -L/usr/local/lib -lmecab -lstdc++ -o build/lib.linux-x86_64-3.8/_MeCab.cpython-38-x86_64-linux-gnu.so
# running install
# running build
# running build_py
# running build_ext
# running install_lib
# copying build/lib.linux-x86_64-3.8/MeCab.py -> /usr/local/lib/python3.8/dist-packages
# copying build/lib.linux-x86_64-3.8/_MeCab.cpython-38-x86_64-linux-gnu.so -> /usr/local/lib/python3.8/dist-packages
# byte-compiling /usr/local/lib/python3.8/dist-packages/MeCab.py to MeCab.cpython-38.pyc
# running install_egg_info
# Writing /usr/local/lib/python3.8/dist-packages/mecab_python-0.996_ko_0.9.2.egg-info
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 1.4 MB/s
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.8/dist-packages (from konlpy) (4.9.2)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.8/dist-packages (from konlpy) (1.21.6)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (465 kB)
#      |████████████████████████████████| 465 kB 50.2 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from JPype1>=0.7.0->konlpy) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->JPype1>=0.7.0->konlpy) (3.0.9)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.1 konlpy-0.6.0

# %% [markdown]
# # 키워드 분석
# * 핵심어(keyword)란 텍스트 자료의 중요한 내용을 압축적으로 제시하는 단어 또는 문구
# * 핵심어 분석이란 불용어 제거와 어간추출 및 형태소 분석 등의 자연어 처리를 시행한 후 텍스트에서 많이 등장하는 형태소의 등장 빈도를 분석함으로써 핵심어를
# 추출
# * 특정 텍스트 자료에 많이 나타나는 형태소가 그 텍스트 주제를 표출할 가능성이 높다는 가정에 기초
# * 물론 빈도 분석에서 영어의 전치사나 한국어의 조사와 같이 의미를 별로 담고 있지 않은 불용어는 제외하는 것이 좋음
# * 키워드 분석은 텍스트의 주제 추정, 텍스트 유사도, 검색 엔진의 검색 결과 우선 순위 측정 등 다양하게 사용될 수 **있음**

# %%
# !pip install pyLDAvis
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyLDAvis
#   Using cached pyLDAvis-3.3.1.tar.gz (1.7 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Collecting sklearn
#   Downloading sklearn-0.0.post1.tar.gz (3.6 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from pyLDAvis) (57.4.0)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.8/dist-packages (from pyLDAvis) (1.3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from pyLDAvis) (2.11.3)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.8/dist-packages (from pyLDAvis) (2.8.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from pyLDAvis) (1.0.2)
# Requirement already satisfied: gensim in /usr/local/lib/python3.8/dist-packages (from pyLDAvis) (3.6.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from pyLDAvis) (1.2.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from pyLDAvis) (1.7.3)
# Requirement already satisfied: future in /usr/local/lib/python3.8/dist-packages (from pyLDAvis) (0.16.0)
# Collecting funcy
#   Downloading funcy-1.17-py2.py3-none-any.whl (33 kB)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.8/dist-packages (from pyLDAvis) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.2.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.2.0->pyLDAvis) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas>=1.2.0->pyLDAvis) (1.15.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.8/dist-packages (from gensim->pyLDAvis) (6.3.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->pyLDAvis) (2.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->pyLDAvis) (3.1.0)
# Building wheels for collected packages: pyLDAvis, sklearn
#   Building wheel for pyLDAvis (PEP 517) ... done
#   Created wheel for pyLDAvis: filename=pyLDAvis-3.3.1-py2.py3-none-any.whl size=136898 sha256=ff5857ce1b5a67fdfe3749b95f275850d0ab803a0ad6cc127720a315f5f489ec
#   Stored in directory: /root/.cache/pip/wheels/90/61/ec/9dbe9efc3acf9c4e37ba70fbbcc3f3a0ebd121060aa593181a
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2344 sha256=1607cebe21aa1f3450503aaa279fc014f6ffaac0ba2b951b02714cdd7ecbff92
#   Stored in directory: /root/.cache/pip/wheels/14/25/f7/1cc0956978ae479e75140219088deb7a36f60459df242b1a72
# Successfully built pyLDAvis sklearn
# Installing collected packages: sklearn, funcy, pyLDAvis
# Successfully installed funcy-1.17 pyLDAvis-3.3.1 sklearn-0.0.post1

# %%
import numpy as np
import pandas as pd
import warnings # 경고 메시지 무시
warnings.filterwarnings(action='ignore')
# 한국어 형태소 분석기 중 성능이 가장 우수한 Mecab 사용
from konlpy.tag import Mecab
mecab = Mecab()
from tqdm import tqdm # 작업 프로세스 시각화
import re # 문자열 처리를 위한 정규표현식 패키지
from gensim import corpora # 단어 빈도수 계산 패키지
import gensim # LDA 모델 활용 목적
import pyLDAvis.gensim_models # LDA 시각화용 패키지
from collections import Counter # 단어 등장 횟수 카운트
# Out:
# /usr/local/lib/python3.8/dist-packages/past/types/oldstr.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.10 it will stop working
#   from collections import Iterable

# %% [markdown]
# ## 파일 불러오기

# %%
import pandas as pd

df = pd.read_excel('/content/윤석열대통령_연설문230101.xlsx')
df.head()
# Out:
#    순번         날짜                         제목  \
# 0   1 2022-05-22                        취임사
# 1   2 2022-03-10     정직한 정부, 정직한 대통령 되겠습니다.
# 2   3 2022-03-22    국민 속으로.. 용산에서 시작하겠습니다.​
# 3   4 2022-04-01  윤석열 정부의 대한민국은 청년이 주인공입니다.
# 4   5 2022-04-01            국민이 안심할 수 있는 사회
#
#                                                   내용
# 0  존경하고 사랑하는 국민 여러분, 750만 재외동포 여러분 그리고 자유를 사랑하는 세...
# 1  위대하고 자랑스러운 국민 여러분! 고맙습니다. 다시 한 번, 진심으로 감사합니다.벅...
# 2  국민 속으로.. 용산에서 시작하겠습니다.​ 대통령 집무실 이전은 새로운 시대의 출발...
# 3  청년들에게 무한한 기회를 제공하는 정부가 되겠습니다. 단기적인 지원이 아닌 목표에 ...
# 4  국가를 위해 희생한 분들이 분노하지 않는 나라를 만들겠다고 분명히 약속 드렸습니다....

# %%
# 데이터 탐색

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   순번      85 non-null     int64
#  1   날짜      85 non-null     datetime64[ns]
#  2   제목      85 non-null     object
#  3   내용      85 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 2.8+ KB

# %%
def clean_text(d):
  pattern = r'[^a-zA-Z\s]'
  text = re.sub(pattern,'',d)
  return text

# %%
news_df = df['내용']
news_df.head()
# Out:
# 0    존경하고 사랑하는 국민 여러분, 750만 재외동포 여러분 그리고 자유를 사랑하는 세...
# 1    위대하고 자랑스러운 국민 여러분! 고맙습니다. 다시 한 번, 진심으로 감사합니다.벅...
# 2    국민 속으로.. 용산에서 시작하겠습니다.​ 대통령 집무실 이전은 새로운 시대의 출발...
# 3    청년들에게 무한한 기회를 제공하는 정부가 되겠습니다. 단기적인 지원이 아닌 목표에 ...
# 4    국가를 위해 희생한 분들이 분노하지 않는 나라를 만들겠다고 분명히 약속 드렸습니다....
# Name: 내용, dtype: object

# %%
# drop_na 하기
news_df.replace("", float("Nan"), inplace = True)
news_df.dropna(inplace= True)
print(len(news_df))
# Out:
# 85

# %%
news_df.head()
# Out:
# 0    존경하고 사랑하는 국민 여러분, 750만 재외동포 여러분 그리고 자유를 사랑하는 세...
# 1    위대하고 자랑스러운 국민 여러분! 고맙습니다. 다시 한 번, 진심으로 감사합니다.벅...
# 2    국민 속으로.. 용산에서 시작하겠습니다.​ 대통령 집무실 이전은 새로운 시대의 출발...
# 3    청년들에게 무한한 기회를 제공하는 정부가 되겠습니다. 단기적인 지원이 아닌 목표에 ...
# 4    국가를 위해 희생한 분들이 분노하지 않는 나라를 만들겠다고 분명히 약속 드렸습니다....
# Name: 내용, dtype: object

# %%
# 전처리용 dictionary 불러오기 

stopword_list = pd.read_excel('/content/stopword_list.xlsx')
stopword_list.head()
# Out:
#   stopword
# 0     가까스로
# 1       가량
# 2       가령
# 3       가민
# 4    가민커넥트

# %%
# 한글자인 키워드 리스트를 불러옵니다. 

one_char_keyword = pd.read_excel('/content/one_char_list.xlsx')
one_char_keyword.head()
# Out:
#   one_char_keyword
# 0                컵
# 1                방
# 2                물
# 3                돈
# 4                꿈

# %%
content_tokenized = list(map(lambda review: mecab.nouns(review), news_df))

# %%
def remove_stopword(tokens):
    review_removed_stopword = []
    for token in tokens:
        # 토큰의 글자 수가 2글자 이상인 경우
        if 1 < len(token):
            # 토큰이 불용어가 아닌 경우만 분석용 리뷰 데이터로 포함
            if token not in list(stopword_list['stopword']):
                review_removed_stopword.append(token)
        # 토큰의 글자 수가 1글자인 경우
        else:
            # 1글자 키워드에 포함되는 경우만 분석용 리뷰 데이터로 포함
            if token in list(one_char_keyword['one_char_keyword']):
                review_removed_stopword.append(token)
    return review_removed_stopword

# %%
content_removed_stopword = list(map(lambda tokens : remove_stopword(tokens), content_tokenized))

# %%
content_removed_stopword
# Out:
# [['존경',
#   '사랑',
#   '국민',
#   '재외',
#   '동포',
#   '자유',
#   '사랑',
#   '세계',
#   '시민',
#   '나라',
#   '자유민주주의',
#   '시장',
#   '경제',
#   '체제',
#   '기반',
#   '국민',
#   '주인',
#   '나라',
#   '재건',
#   '국제',
#   '사회',
#   '책임',
#   '역할',
#   '나라',
#   '시대',
#   '소명',
#   '자리',
#   '역사',
#   '자리',
#   '국민',
#   '감사',
#   '문재인',
#   '박근혜',
#   '대통령',
#   '리마',
#   '야콥',
#   '싱가포르',
#   '대통령',
#   '포스',
#   '아르',
#   '투아',
#   '중앙아프리카',
#   '공화국',
#   '대통령',
#   '왕치산',
#   '중국',
#   '국가',
#   '부주석',
#   '메가와티',
#   '수카르노푸트리',
#   '인도네시아',
#   '대통령',
#   '더글러스',
#   '호프',
#   '해리스',
#   '미국',
#   '부통령',
#   '부군',
#   '조지',
#   '퓨리',
#   '캐나다',
#   '상원',
#   '의장',
#   '하야시',
#   '요시마사',
#   '일본',
#   '외무',
#   '세계',
#   '각국',
#   '경축',
#   '사절',
#   '내외',
#   '귀빈',
#   '감사',
#   '자리',
#   '코로나',
#   '펜데',
#   '극복',
#   '과정',
#   '고통',
#   '감내',
#   '국민',
#   '경의',
#   '헌신',
#   '의료진',
#   '감사',
#   '존경',
#   '국민',
#   '세계',
#   '시민',
#   '세계',
#   '팬데',
#   '위기',
#   '교역',
#   '질서',
#   '변화',
#   '공급',
#   '재편',
#   '기후',
#   '변화',
#   '식량',
#   '에너지',
#   '위기',
#   '분쟁',
#   '평화',
#   '해결',
#   '후퇴',
#   '나라',
#   '독자',
#   '나라',
#   '참여',
#   '해결',
#   '난제',
#   '직면',
#   '위기',
#   '복합',
#   '인류',
#   '사회',
#   '그림자',
#   '나라',
#   '나라',
#   '국내',
#   '저성장',
#   '규모',
#   '실업',
#   '양극',
#   '심화',
#   '다양',
#   '사회',
#   '갈등',
#   '공동체',
#   '결속력',
#   '와해',
#   '한편',
#   '문제',
#   '해결',
#   '정치',
#   '민주주의',
#   '위기',
#   '원인',
#   '지목',
#   '반지',
#   '주의',
#   '견해',
#   '서로',
#   '입장',
#   '조정',
#   '타협',
#   '과학',
#   '진실',
#   '전제',
#   '민주주의',
#   '지탱',
#   '합리주의',
#   '지성',
#   '주의',
#   '국가',
#   '국가',
#   '내부',
#   '집단',
#   '갈등',
#   '진실',
#   '왜곡',
#   '선택',
#   '의견',
#   '억압',
#   '반지',
#   '주의',
#   '민주주의',
#   '위기',
#   '민주주의',
#   '믿음',
#   '상황',
#   '문제',
#   '해결',
#   '역사',
#   '국민',
#   '위기',
#   '국민',
#   '지혜',
#   '용기',
#   '극복',
#   '위기',
#   '극복',
#   '책임',
#   '감사',
#   '마음',
#   '국민',
#   '확신',
#   '세계',
#   '시민',
#   '국내외',
#   '위기',
#   '난제',
#   '해결',
#   '존경',
#   '국민',
#   '세계',
#   '시민',
#   '어려움',
#   '해결',
#   '보편',
#   '가치',
#   '공유',
#   '중요',
#   '자유',
#   '자유',
#   '가치',
#   '정확',
#   '인식',
#   '자유',
#   '가치',
#   '발견',
#   '인류',
#   '역사',
#   '자유',
#   '정치',
#   '권리',
#   '자유',
#   '시장',
#   '번영',
#   '풍요',
#   '번영',
#   '풍요',
#   '경제',
#   '성장',
#   '자유',
#   '확대',
#   '자유',
#   '보편',
#   '가치',
#   '사회',
#   '구성원',
#   '자유',
#   '시민',
#   '개인',
#   '자유',
#   '침해',
#   '방치',
#   '공동체',
#   '구성원',
#   '자유',
#   '위협',
#   '자유',
#   '승자',
#   '독식',
#   '자유',
#   '시민',
#   '일정',
#   '수준',
#   '경제',
#   '기초',
#   '공정',
#   '교육',
#   '문화',
#   '접근',
#   '기회',
#   '보장',
#   '자유',
#   '시민',
#   '자유',
#   '유린',
#   '자유',
#   '시민',
#   '필요',
#   '조건',
#   '충족',
#   '자유',
#   '시민',
#   '연대',
#   '개별',
#   '국가',
#   '국제',
#   '기아',
#   '빈곤',
#   '공권력',
#   '군사력',
#   '불법',
#   '행위',
#   '개인',
#   '자유',
#   '침해',
#   '자유',
#   '시민',
#   '존엄',
#   '유지',
#   '세계',
#   '시민',
#   '자유',
#   '시민',
#   '연대',
#   '자유',
#   '시민',
#   '공정',
#   '규칙',
#   '연대',
#   '박애',
#   '정신',
#   '존경',
#   '국민',
#   '국내',
#   '문제',
#   '중요',
#   '방향',
#   '말씀',
#   '나라',
#   '양극',
#   '사회',
#   '갈등',
#   '자유',
#   '민주주의',
#   '위협',
#   '사회',
#   '발전',
#   '발목',
#   '문제',
#   '도약',
#   '성장',
#   '해결',
#   '성장',
#   '과정',
#   '국민',
#   '기회',
#   '사회',
#   '이동성',
#   '제고',
#   '양극',
#   '갈등',
#   '근원',
#   '제거',
#   '도약',
#   '성장',
#   '과학',
#   '기술',
#   '혁신',
#   '과학',
#   '기술',
#   '혁신',
#   '자유민주주의',
#   '자유',
#   '확대',
#   '존엄',
#   '지속',
#   '가능',
#   '과학',
#   '기술',
#   '혁신',
#   '나라',
#   '노력',
#   '달성',
#   '자유',
#   '창의',
#   '존중',
#   '과학',
#   '기술',
#   '진보',
#   '혁신',
#   '나라',
#   '협력',
#   '연대',
#   '존경',
#   '국민',
#   '세계',
#   '시민',
#   '자유민주주의',
#   '평화',
#   '평화',
#   '자유',
#   '평화',
#   '자유',
#   '인권',
#   '가치',
#   '존중',
#   '국제',
#   '사회',
#   '연대',
#   '보장',
#   '전쟁',
#   '회피',
#   '취약',
#   '평화',
#   '자유',
#   '번영',
#   '지속',
#   '가능',
#   '평화',
#   '추구',
#   '세계',
#   '자유',
#   '평화',
#   '위협',
#   '자유',
#   '한반도',
#   '동북아',
#   '평화',
#   '한반도',
#   '아시아',
#   '세계',
#   '평화',
#   '위협',
#   '북한',
#   '평화',
#   '해결',
#   '대화',
#   '북한',
#   '중단',
#   '실질',
#   '비핵화',
#   '전환',
#   '국제',
#   '사회',
#   '협력',
#   '북한',
#   '경제',
#   '북한',
#   '주민',
#   '개선',
#   '계획',
#   '준비',
#   '북한',
#   '비핵화',
#   '한반도',
#   '지속',
#   '가능',
#   '평화',
#   '아시아',
#   '세계',
#   '평화',
#   '번영',
#   '기여',
#   '사랑',
#   '존경',
#   '국민',
#   '세계',
#   '경제',
#   '대국',
#   '그룹',
#   '자유',
#   '인권',
#   '가치',
#   '기반',
#   '보편',
#   '국제',
#   '규범',
#   '적극',
#   '지지',
#   '수호',
#   '글로벌',
#   '리더',
#   '국가',
#   '자세',
#   '나라',
#   '세계',
#   '시민',
#   '자유',
#   '인권',
#   '확대',
#   '주도',
#   '역할',
#   '국제',
#   '사회',
#   '대한민국',
#   '역할',
#   '기대',
#   '나라',
#   '국내',
#   '문제',
#   '국제',
#   '문제',
#   '분리',
#   '국제',
#   '사회',
#   '기대',
#   '역할',
#   '주도',
#   '수행',
#   '국내',
#   '문제',
#   '해결',
#   '방향',
#   '자유',
#   '인권',
#   '공정',
#   '연대',
#   '가치',
#   '기반',
#   '국민',
#   '주인',
#   '나라',
#   '국제',
#   '사회',
#   '책임',
#   '존경',
#   '나라',
#   '국민',
#   '감사'],
#  ['자랑',
#   '국민',
#   '감사',
#   '마음',
#   '무한',
#   '책임감',
#   '대통령',
#   '당선인',
#   '국민',
#   '공직',
#   '사퇴',
#   '국민',
#   '지지',
#   '성원',
#   '정치',
#   '초심자',
#   '정치',
#   '시작',
#   '어려움',
#   '국민',
#   '국민',
#   '국민',
#   '국민',
#   '공직자',
#   '권력',
#   '굴복',
#   '정의',
#   '국민',
#   '국민',
#   '공정',
#   '정의',
#   '권력',
#   '소신',
#   '희망',
#   '자리',
#   '정의',
#   '일상',
#   '정의',
#   '국민',
#   '약속',
#   '나라',
#   '공정',
#   '상식',
#   '개혁',
#   '목소리',
#   '국민',
#   '통합',
#   '정치',
#   '국민',
#   '호소',
#   '희망',
#   '나라',
#   '명령',
#   '국민',
#   '정치',
#   '유불리',
#   '국민',
#   '이익',
#   '국익',
#   '국정',
#   '기준',
#   '진보',
#   '보수',
#   '대한민국',
#   '영호남',
#   '윤석열',
#   '국민',
#   '국민',
#   '산업',
#   '혁명',
#   '대응',
#   '코로나',
#   '팬데',
#   '극복',
#   '경제',
#   '고질',
#   '저성장',
#   '양극',
#   '전대미문',
#   '거대',
#   '도전',
#   '직면',
#   '윤석열',
#   '정부',
#   '자유민주주의',
#   '시장',
#   '경제',
#   '위기',
#   '극복',
#   '통합',
#   '번영',
#   '시대',
#   '자유민주주의',
#   '위협',
#   '이념',
#   '국민',
#   '상식',
#   '기반',
#   '국정',
#   '운영',
#   '국민',
#   '개개인',
#   '공정',
#   '기회',
#   '보장',
#   '자율',
#   '창의',
#   '발휘',
#   '역동',
#   '나라',
#   '노동',
#   '가치',
#   '존중',
#   '나라',
#   '정부',
#   '주도',
#   '민간',
#   '중심',
#   '경제',
#   '전환',
#   '일자리',
#   '창출',
#   '중산',
#   '필요',
#   '복지',
#   '성장',
#   '지속',
#   '지속',
#   '가능',
#   '발전',
#   '성장',
#   '복지',
#   '공정',
#   '순환',
#   '가능',
#   '첨단',
#   '기술',
#   '혁신',
#   '대대',
#   '지원',
#   '과학',
#   '기술',
#   '선도',
#   '국가',
#   '발돋움',
#   '저성장',
#   '위기',
#   '경제',
#   '성장',
#   '궤도',
#   '성장',
#   '결실',
#   '이웃',
#   '사회',
#   '약자',
#   '국민',
#   '디지털',
#   '플랫',
#   '정부',
#   '구현',
#   '공공',
#   '의사',
#   '결정',
#   '데이터',
#   '기반',
#   '과학',
#   '합리',
#   '정부',
#   '국민',
#   '쌍방향',
#   '소통',
#   '활성',
#   '디지털',
#   '민주주의',
#   '발전',
#   '개인',
#   '복지',
#   '시대',
#   '코로나',
#   '벼랑',
#   '자영업',
#   '소상',
#   '공인',
#   '고통',
#   '분담',
#   '적극',
#   '미래',
#   '준비',
#   '팬데',
#   '위기',
#   '선제',
#   '대응',
#   '사회',
#   '제도',
#   '개혁',
#   '병행',
#   '민주주의',
#   '위협',
#   '부정부패',
#   '국민',
#   '엄단',
#   '국민',
#   '공정',
#   '적용',
#   '법치',
#   '원칙',
#   '국민',
#   '생명',
#   '안전',
#   '최우선',
#   '안심',
#   '대한민국',
#   '국민',
#   '북한',
#   '위협',
#   '전략',
#   '경쟁',
#   '긴장',
#   '글로벌',
#   '외교',
#   '역량',
#   '강화',
#   '과제',
#   '국민',
#   '안전',
#   '재산',
#   '영토',
#   '주권',
#   '도발',
#   '억제',
#   '국방력',
#   '구축',
#   '북한',
#   '불법',
#   '합리',
#   '행동',
#   '원칙',
#   '대처',
#   '남북',
#   '대화',
#   '외교',
#   '안보',
#   '바탕',
#   '자유',
#   '평화',
#   '번영',
#   '기여',
#   '글로벌',
#   '중추',
#   '국가',
#   '미동',
#   '재건',
#   '자유민주주의',
#   '시장',
#   '경제',
#   '인권',
#   '핵심',
#   '가치',
#   '공유',
#   '포괄',
#   '전략',
#   '동맹',
#   '강화',
#   '상호',
#   '존중',
#   '한중',
#   '관계',
#   '발전',
#   '미래',
#   '지향',
#   '관계',
#   '지역',
#   '특화',
#   '글로벌',
#   '협력',
#   '네트워크',
#   '구축',
#   '경제',
#   '안보',
#   '외교',
#   '강화',
#   '대한민국',
#   '국제',
#   '사회',
#   '역할',
#   '책임',
#   '존경',
#   '나라',
#   '국민',
#   '국민',
#   '정치',
#   '민생',
#   '국익',
#   '정치',
#   '대통령',
#   '여당',
#   '노력',
#   '가능',
#   '의회',
#   '소통',
#   '야당',
#   '국정',
#   '현안',
#   '국민',
#   '진솔',
#   '소통',
#   '참모',
#   '정부',
#   '잘못',
#   '고백',
#   '현실',
#   '어려움',
#   '국민',
#   '이해',
#   '존경',
#   '국민',
#   '자리',
#   '시대',
#   '관통',
#   '공정',
#   '상식',
#   '자유민주주의',
#   '정신',
#   '법치',
#   '헌법',
#   '정신',
#   '자유',
#   '공정',
#   '대한민국',
#   '행복',
#   '청년',
#   '나라',
#   '윤석열',
#   '정부',
#   '국민',
#   '고통',
#   '마음',
#   '국민',
#   '신뢰',
#   '보답',
#   '목소리',
#   '초심',
#   '겸손',
#   '자세',
#   '국민',
#   '국민',
#   '국민',
#   '정직',
#   '정부',
#   '국민',
#   '정직',
#   '대통령',
#   '감사'],
#  ['국민',
#   '용산',
#   '시작',
#   '대통령',
#   '집무실',
#   '시대',
#   '출발점',
#   '소통',
#   '대통령실',
#   '구현',
#   '부처',
#   '군림',
#   '권력',
#   '독점',
#   '대통령실',
#   '문제점',
#   '국민',
#   '단절',
#   '공간',
#   '구조',
#   '측면',
#   '공간',
#   '대통령',
#   '공무원',
#   '민간',
#   '전문가',
#   '소통',
#   '정부',
#   '약속',
#   '대통령',
#   '집무실',
#   '기자실',
#   '기존',
#   '청와대',
#   '대통령',
#   '집무',
#   '건물',
#   '기자실',
#   '브리핑',
#   '배치',
#   '국민',
#   '의견',
#   '소통',
#   '강화',
#   '용산',
#   '집무실',
#   '측면',
#   '남쪽',
#   '용산',
#   '공원',
#   '지역',
#   '국민',
#   '소통',
#   '울타리',
#   '투시',
#   '설치',
#   '국민',
#   '대통령',
#   '모습',
#   '사진',
#   '대통령',
#   '용산',
#   '공원',
#   '자연',
#   '국민',
#   '소통'],
#  ['청년',
#   '무한',
#   '기회',
#   '제공',
#   '정부',
#   '단기',
#   '지원',
#   '목표',
#   '안착',
#   '실질',
#   '도움',
#   '정부',
#   '최선',
#   '목소리',
#   '청년',
#   '선생',
#   '마음',
#   '꿈',
#   '변화',
#   '시작',
#   '꿈'],
#  ['국가', '희생', '분노', '나라', '약속', '윤석열', '국가', '희생', '대한민국', '국민', '영웅', '기억'],
#  ['참모',
#   '국민',
#   '목소리',
#   '경청',
#   '대통령',
#   '사회',
#   '갈등',
#   '증폭',
#   '조정',
#   '치유',
#   '국민',
#   '기대',
#   '윤석열',
#   '모습',
#   '공정',
#   '상식',
#   '나라',
#   '약속'],
#  ['선거', '기간', '약속', '비전', '열정', '겸손', '국민'],
#  ['국민'],
#  ['마을',
#   '필요',
#   '애정',
#   '관심',
#   '필요',
#   '공동체',
#   '보람',
#   '행복',
#   '존재',
#   '어린이',
#   '존재',
#   '무한',
#   '잠재력',
#   '가능',
#   '세계',
#   '책임',
#   '건강',
#   '나라'],
#  ['자유',
#   '인권',
#   '공정',
#   '연대',
#   '가치',
#   '기반',
#   '국민',
#   '주인',
#   '나라',
#   '국제',
#   '사회',
#   '책임',
#   '존경',
#   '나라',
#   '국민'],
#  ['자유',
#   '보편',
#   '가치',
#   '사회',
#   '구성원',
#   '자유',
#   '시민',
#   '개인',
#   '자유',
#   '침해',
#   '방치',
#   '공동체',
#   '구성원',
#   '자유',
#   '위협',
#   '자유민주주의',
#   '평화',
#   '평화',
#   '자유',
#   '평화',
#   '자유',
#   '인권',
#   '가치',
#   '존중',
#   '국제',
#   '사회',
#   '연대',
#   '보장'],
#  ['정치',
#   '경제',
#   '군사',
#   '주도',
#   '지정학',
#   '갈등',
#   '산업',
#   '자원',
#   '무기',
#   '공급',
#   '블록',
#   '흐름',
#   '형식',
#   '평화',
#   '북한',
#   '비핵화',
#   '프로세스',
#   '남북',
#   '신뢰',
#   '구축',
#   '순환',
#   '지속',
#   '가능',
#   '평화',
#   '직면',
#   '나라',
#   '안팎',
#   '위기',
#   '도전',
#   '개혁',
#   '완성',
#   '극복',
#   '자유민주주의',
#   '의회주의',
#   '신념',
#   '소상',
#   '공인',
#   '손실',
#   '보상',
#   '방역',
#   '의료',
#   '체계',
#   '전환',
#   '지원',
#   '북한',
#   '당국',
#   '호응',
#   '코로나',
#   '백신',
#   '포함',
#   '의약품',
#   '의료',
#   '기구',
#   '보건',
#   '인력',
#   '필요',
#   '지원',
#   '국민',
#   '희생',
#   '상처',
#   '자긍심',
#   '보답',
#   '여야',
#   '치열',
#   '경쟁',
#   '민생',
#   '초당',
#   '협력',
#   '위기',
#   '극복',
#   '자랑',
#   '역사'],
#  ['민주',
#   '영령',
#   '마음',
#   '가족',
#   '이웃',
#   '아픔',
#   '민주',
#   '운동',
#   '유공자',
#   '유가족',
#   '위로',
#   '말씀',
#   '오월',
#   '정신',
#   '보편',
#   '가치',
#   '회복',
#   '자유민주주의',
#   '헌법',
#   '정신',
#   '오월',
#   '정신',
#   '자유',
#   '인권',
#   '위협',
#   '일체',
#   '불법',
#   '행위',
#   '저항',
#   '명령',
#   '오월',
#   '정신',
#   '오월',
#   '정신',
#   '국민',
#   '단결',
#   '위기',
#   '도전',
#   '확신'],
#  ['바이든',
#   '대통령',
#   '평택',
#   '캠퍼스',
#   '방문',
#   '반도체',
#   '경제',
#   '안보',
#   '의미',
#   '반도체',
#   '글로벌',
#   '포괄',
#   '전략',
#   '동맹',
#   '의미',
#   '기회',
#   '반도체',
#   '미래',
#   '국가',
#   '안보',
#   '자산',
#   '인센티브',
#   '필요',
#   '지원',
#   '계획',
#   '방문',
#   '계기',
#   '관계',
#   '첨단',
#   '기술',
#   '공급',
#   '협력',
#   '기반',
#   '경제',
#   '안보',
#   '동맹',
#   '희망'],
#  ['정부',
#   '교육',
#   '제도',
#   '혁신',
#   '지식',
#   '습득',
#   '문제',
#   '해결',
#   '창의',
#   '교육',
#   '인재',
#   '양성',
#   '혁신',
#   '성장',
#   '기반',
#   '개인',
#   '재능',
#   '적성',
#   '미래형',
#   '교육',
#   '과정',
#   '다양',
#   '고교',
#   '교육',
#   '체계',
#   '강화',
#   '반도체',
#   '첨단',
#   '미래',
#   '산업',
#   '포함',
#   '산업',
#   '부문',
#   '필요',
#   '맞춤',
#   '인재',
#   '문제',
#   '해결',
#   '필요',
#   '정보',
#   '데이터',
#   '발굴',
#   '활용',
#   '방법',
#   '가치',
#   '창출',
#   '창의',
#   '교육',
#   '공교육',
#   '교육',
#   '혁신',
#   '역량'],
#  ['존경',
#   '국민',
#   '보훈',
#   '가족',
#   '국가',
#   '유공자',
#   '현충일',
#   '국립',
#   '현충원',
#   '대한민국',
#   '독립',
#   '투쟁',
#   '순국선열',
#   '공산',
#   '세력',
#   '침략',
#   '자유',
#   '대한민국',
#   '호국',
#   '영령',
#   '목숨',
#   '국민',
#   '생명',
#   '나라',
#   '희생',
#   '경의',
#   '명복',
#   '세월',
#   '가족',
#   '아픔',
#   '간직',
#   '유가족',
#   '위로',
#   '말씀',
#   '자유',
#   '평화',
#   '조국',
#   '희생',
#   '순국선열',
#   '호국',
#   '영령',
#   '용기',
#   '헌신',
#   '중요',
#   '목숨',
#   '용기',
#   '보답',
#   '자유',
#   '민주주의',
#   '인권',
#   '자랑',
#   '대한민국',
#   '그분',
#   '희생',
#   '영웅',
#   '희생',
#   '가족',
#   '눈물',
#   '국가',
#   '안보',
#   '국민',
#   '안전',
#   '영웅',
#   '사명',
#   '가족',
#   '국가',
#   '의무',
#   '국가',
#   '유공자',
#   '유족',
#   '보훈',
#   '체계',
#   '국방력',
#   '근간',
#   '공정',
#   '합리',
#   '보훈',
#   '체계',
#   '마련',
#   '존경',
#   '국민',
#   '북한',
#   '미사일',
#   '위협',
#   '고도',
#   '제도',
#   '종류',
#   '탄도',
#   '미사일',
#   '발사',
#   '북한',
#   '미사일',
#   '한반도',
#   '동북아',
#   '세계',
#   '평화',
#   '위협',
#   '수준',
#   '정부',
#   '북한',
#   '도발',
#   '대처',
#   '북한',
#   '미사일',
#   '위협',
#   '억제',
#   '근본',
#   '실질',
#   '안보',
#   '능력',
#   '국민',
#   '생명',
#   '재산',
#   '빈틈',
#   '국가',
#   '안보',
#   '국민',
#   '안전',
#   '일선',
#   '희생',
#   '민가',
#   '전투기',
#   '추락',
#   '조종간',
#   '공군',
#   '전투',
#   '비행단',
#   '심정민',
#   '소령',
#   '평택',
#   '물류',
#   '센터',
#   '화재',
#   '현장',
#   '인명구조',
#   '임무',
#   '수행',
#   '송탄',
#   '소방서',
#   '구조',
#   '이형석',
#   '소방경',
#   '박수동',
#   '소방장',
#   '조우',
#   '소방교',
#   '대만',
#   '해역',
#   '실종',
#   '선박',
#   '수색',
#   '복귀',
#   '추락',
#   '사고',
#   '지방',
#   '해양',
#   '경찰청',
#   '항공',
#   '정두환',
#   '경감',
#   '황현준',
#   '경사',
#   '경사',
#   '국가',
#   '안보',
#   '국민',
#   '안전',
#   '꿈',
#   '영웅',
#   '국민',
#   '대표',
#   '유가족',
#   '위로',
#   '말씀',
#   '자유',
#   '번영',
#   '나라',
#   '국민',
#   '조국',
#   '희생',
#   '헌신',
#   '예우',
#   '제복',
#   '영웅',
#   '존경',
#   '나라',
#   '국민',
#   '편안',
#   '꿈',
#   '행복',
#   '추구',
#   '존경',
#   '국민',
#   '후손',
#   '자유',
#   '평화',
#   '대한민국',
#   '사명',
#   '자유',
#   '민주주의',
#   '인권',
#   '가치',
#   '추구',
#   '대한민국',
#   '조국',
#   '헌신',
#   '희생',
#   '가치',
#   '영웅',
#   '용기',
#   '국가',
#   '이름',
#   '기억',
#   '유가족',
#   '자부심',
#   '긍지',
#   '대한민국',
#   '정부',
#   '국민',
#   '감사'],
#  ['국무',
#   '회의',
#   '시작',
#   '지난주',
#   '연준',
#   '금리',
#   '인상',
#   '단행',
#   '세계',
#   '경제',
#   '위기',
#   '상황',
#   '각국',
#   '정부',
#   '총력',
#   '대응',
#   '상황',
#   '역량',
#   '결집',
#   '대통령실',
#   '비상',
#   '경제',
#   '대응',
#   '체제',
#   '전환',
#   '내각',
#   '비상',
#   '경제',
#   '장관',
#   '회의',
#   '개최',
#   '지난주',
#   '정부',
#   '경제',
#   '정책',
#   '방향',
#   '논의',
#   '자리',
#   '강조',
#   '위기',
#   '민간',
#   '주도',
#   '시장',
#   '주도',
#   '경제',
#   '체질',
#   '정부',
#   '기업',
#   '걸림돌',
#   '제도',
#   '규제',
#   '개선',
#   '규제',
#   '개혁',
#   '제도',
#   '개선',
#   '경제',
#   '성장',
#   '발목',
#   '이권',
#   '카르텔',
#   '부당',
#   '지대',
#   '추구',
#   '폐습',
#   '규제',
#   '혁신',
#   '경제',
#   '기존',
#   '현장',
#   '필요',
#   '대책',
#   '강구',
#   '당부',
#   '국무',
#   '회의',
#   '경제',
#   '위기',
#   '극복',
#   '안건',
#   '상정',
#   '글로벌',
#   '공급',
#   '이슈',
#   '어려움',
#   '부품',
#   '부담',
#   '자동차',
#   '개별',
#   '소비세',
#   '인하',
#   '기간',
#   '연장',
#   '안건',
#   '상정',
#   '서민',
#   '물가',
#   '안정',
#   '돼지고기',
#   '밀가루',
#   '대두유',
#   '품목',
#   '할당',
#   '관세',
#   '인하',
#   '안건',
#   '상정',
#   '부처',
#   '민생',
#   '안정',
#   '경제',
#   '활력',
#   '정책',
#   '신속',
#   '수립',
#   '정책',
#   '현장',
#   '책임',
#   '필요',
#   '정기',
#   '국무',
#   '회의',
#   '임시',
#   '국무',
#   '회의',
#   '안건',
#   '처리',
#   '국무',
#   '회의',
#   '산업',
#   '핵심',
#   '반도체',
#   '논의',
#   '국무',
#   '위원',
#   '공공',
#   '기관',
#   '혁신',
#   '토론',
#   '공공',
#   '기관',
#   '혁신',
#   '과제',
#   '공공',
#   '기관',
#   '부채',
#   '급증',
#   '작년',
#   '기준',
#   '부채',
#   '급증',
#   '공공',
#   '기관',
#   '조직',
#   '인력',
#   '공공',
#   '기관',
#   '평가',
#   '운영',
#   '개선',
#   '공공',
#   '기관',
#   '기관',
#   '국민',
#   '신뢰',
#   '공공',
#   '기관',
#   '혁신',
#   '부처',
#   '추진',
#   '과제',
#   '국가',
#   '정부',
#   '예외',
#   '지출',
#   '구조',
#   '조정',
#   '필요',
#   '재정',
#   '필요',
#   '재원',
#   '정부',
#   '지원',
#   '필요',
#   '사회',
#   '약자',
#   '지출',
#   '당부',
#   '경제',
#   '부처',
#   '공무원',
#   '공공',
#   '기관',
#   '임직원',
#   '위기',
#   '의식',
#   '경제',
#   '독려',
#   '당부',
#   '정책',
#   '목표',
#   '민생',
#   '민생',
#   '민생',
#   '감사'],
#  ['대한민국',
#   '우주',
#   '도전',
#   '산물',
#   '대한민국',
#   '국민',
#   '청년',
#   '꿈',
#   '희망',
#   '우주',
#   '항공',
#   '우주',
#   '연구원',
#   '연구',
#   '항공',
#   '우주',
#   '연구원',
#   '과제',
#   '진행',
#   '기업',
#   '산업체',
#   '관계자',
#   '감사',
#   '노고',
#   '국민',
#   '대표',
#   '과학',
#   '기술',
#   '정통부',
#   '직원',
#   '감사',
#   '항공',
#   '우주',
#   '산업',
#   '세계',
#   '국가',
#   '우주',
#   '강국',
#   '발전',
#   '노력'],
#  ['원전',
#   '세계',
#   '최고',
#   '수준',
#   '기술력',
#   '안전성',
#   '예산',
#   '시공',
#   '능력',
#   '타임',
#   '버짓',
#   '세계',
#   '기업',
#   '흉내',
#   '원전',
#   '기업',
#   '경쟁력',
#   '세계',
#   '최고',
#   '수준',
#   '경쟁력',
#   '원전',
#   '산업',
#   '생태계',
#   '구축',
#   '세계',
#   '원전',
#   '수출',
#   '시장',
#   '사우디',
#   '체코',
#   '폴란드',
#   '미국',
#   '나라',
#   '탄소',
#   '중립',
#   '추진',
#   '과정',
#   '원전',
#   '에너지원',
#   '인식',
#   '원전',
#   '폐기',
#   '원전',
#   '산업',
#   '세계',
#   '수준',
#   '방향',
#   '수립',
#   '방향',
#   '원전',
#   '산업',
#   '궤도',
#   '정부',
#   '원전',
#   '생태',
#   '거점',
#   '창원',
#   '산업',
#   '현장',
#   '활기',
#   '적극',
#   '지원',
#   '한울',
#   '호기',
#   '건설',
#   '재개',
#   '절차',
#   '기준',
#   '준수',
#   '최대한',
#   '단축',
#   '방향',
#   '효율',
#   '추진',
#   '세계',
#   '주요',
#   '미래',
#   '원전',
#   '시장',
#   '주도',
#   '치열',
#   '경쟁',
#   '정부',
#   '고위',
#   '관계자',
#   '원전',
#   '세일즈',
#   '백방'],
#  ['존경',
#   '참전',
#   '유엔',
#   '참전국',
#   '외교',
#   '사절',
#   '내외',
#   '귀빈',
#   '유엔',
#   '참전',
#   '용사',
#   '교포',
#   '참전',
#   '여정',
#   '나라',
#   '대한민국',
#   '국민',
#   '환영',
#   '전쟁',
#   '주년',
#   '참전',
#   '영웅',
#   '후손',
#   '자리',
#   '영광',
#   '청춘',
#   '공산',
#   '세력',
#   '침략',
#   '대한민국',
#   '자유민주주의',
#   '사명감',
#   '국민',
#   '희생',
#   '헌신',
#   '대한민국',
#   '자유',
#   '기억',
#   '존경',
#   '참전',
#   '대한민국',
#   '자유',
#   '평화',
#   '번영',
#   '국군',
#   '유엔군',
#   '참전',
#   '용사',
#   '희생',
#   '헌신',
#   '공산',
#   '세력',
#   '침략',
#   '절체절명',
#   '위기',
#   '국민',
#   '나라',
#   '일념',
#   '자유',
#   '가치',
#   '세계',
#   '젊은이',
#   '자유',
#   '전장',
#   '산화',
#   '참전',
#   '용사',
#   '가족',
#   '이름',
#   '산하',
#   '북한',
#   '억류',
#   '고통',
#   '국군',
#   '포로',
#   '자리',
#   '부친',
#   '유해',
#   '김학수',
#   '이병',
#   '따님',
#   '북한',
#   '탈출',
#   '귀환',
#   '국군',
#   '용사',
#   '유영복',
#   '김종수',
#   '이대봉',
#   '그리움',
#   '가족',
#   '위로',
#   '존경',
#   '말씀',
#   '정부',
#   '전사자',
#   '유해',
#   '발굴',
#   '노력',
#   '가족',
#   '최선',
#   '존경',
#   '유엔',
#   '참전',
#   '캐나다',
#   '참전',
#   '용사',
#   '로버트',
#   '코미어',
#   '세계',
#   '유일',
#   '유엔',
#   '묘지',
#   '부산',
#   '유엔',
#   '기념',
#   '공원',
#   '안장',
#   '고인',
#   '나이',
#   '전쟁',
#   '참전',
#   '생전',
#   '의사소통',
#   '상태',
#   '나라',
#   '전쟁',
#   '상태',
#   '유언',
#   '프랑스',
#   '참전',
#   '용사',
#   '레몽',
#   '베르나르',
#   '유엔',
#   '기념',
#   '공원',
#   '안장',
#   '참전',
#   '용사',
#   '대한민국',
#   '국민',
#   '영광',
#   '우정',
#   '헌신',
#   '민국',
#   '기억',
#   '용기',
#   '정신',
#   '민국',
#   '국제',
#   '사회',
#   '책임',
#   '일원',
#   '자유',
#   '역할',
#   '용사',
#   '민국',
#   '기술',
#   '리호',
#   '발사',
#   '성공',
#   '우주',
#   '영광',
#   '대한민국',
#   '영웅',
#   '자리',
#   '유엔',
#   '참전',
#   '용사',
#   '후손',
#   '주한',
#   '미군',
#   '장병',
#   '대한민국',
#   '우정',
#   '영원',
#   '기대',
#   '자유',
#   '가치',
#   '참전',
#   '용사',
#   '감사',
#   '감사'],
#  ['자리',
#   '참석',
#   '재외',
#   '동포',
#   '부부',
#   '환영',
#   '감사',
#   '코로나',
#   '고국',
#   '영구',
#   '귀국',
#   '동포',
#   '사회',
#   '어려움',
#   '코로나',
#   '종식',
#   '동포',
#   '사회',
#   '활력',
#   '역사',
#   '나라',
#   '내전',
#   '극복',
#   '민주주의',
#   '번영',
#   '자유민주주의',
#   '국가',
#   '기억',
#   '보편',
#   '가치',
#   '토대',
#   '양국',
#   '수교',
#   '자유',
#   '인권',
#   '법치주의',
#   '수호',
#   '교역',
#   '교류',
#   '전략',
#   '협력',
#   '분야',
#   '세계',
#   '무대',
#   '성장',
#   '방문',
#   '목적',
#   '나토',
#   '협력',
#   '강화',
#   '의미',
#   '평화',
#   '안보',
#   '인권',
#   '민주주의',
#   '나토',
#   '추구',
#   '보편',
#   '가치',
#   '정부',
#   '정책',
#   '방향',
#   '완벽',
#   '일치',
#   '글로벌',
#   '리더',
#   '국가',
#   '규범',
#   '기반',
#   '국제',
#   '질서',
#   '수호',
#   '적극',
#   '기여',
#   '포함',
#   '보편',
#   '가치',
#   '공유',
#   '국가',
#   '협력',
#   '자랑',
#   '동포',
#   '취임식',
#   '국민',
#   '주인',
#   '나라',
#   '국제',
#   '사회',
#   '책임',
#   '존경',
#   '나라',
#   '국민',
#   '약속',
#   '동포',
#   '대한민국',
#   '동포',
#   '어려움',
#   '시대',
#   '법령',
#   '제도',
#   '정비',
#   '현지',
#   '체감',
#   '가능',
#   '디지털',
#   '중심',
#   '교민',
#   '행정',
#   '제공',
#   '최선',
#   '후손',
#   '민족',
#   '정체',
#   '글로벌',
#   '인재',
#   '성장',
#   '차세대',
#   '동포',
#   '교육',
#   '지원',
#   '세계',
#   '나라',
#   '대한민국',
#   '국민',
#   '생명',
#   '안전',
#   '최우선',
#   '모국',
#   '재외',
#   '동포',
#   '사회',
#   '발전',
#   '당부',
#   '동포',
#   '자부심',
#   '자랑',
#   '모국'],
#  ['자랑',
#   '여성',
#   '경제',
#   '여성',
#   '경제인',
#   '여성',
#   '기업주',
#   '시작',
#   '사회',
#   '팬데',
#   '위기',
#   '글로벌',
#   '공급',
#   '재편',
#   '저성장',
#   '문제',
#   '도전',
#   '위기',
#   '직면',
#   '극복',
#   '유일',
#   '자유',
#   '창의',
#   '최대한',
#   '존중',
#   '민간',
#   '주도',
#   '성장',
#   '촉진',
#   '정부',
#   '필요',
#   '규제',
#   '민간',
#   '혁신',
#   '성장',
#   '필요',
#   '지원',
#   '여성',
#   '경제',
#   '경제',
#   '중요',
#   '주체',
#   '여성',
#   '적극',
#   '경제',
#   '활동',
#   '참여',
#   '저성장',
#   '해법',
#   '벤처',
#   '펀드',
#   '조성',
#   '혁신',
#   '여성',
#   '창업',
#   '기업',
#   '발굴',
#   '육성',
#   '여성',
#   '기업',
#   '경영',
#   '역량',
#   '제고',
#   '공공',
#   '기관',
#   '구매',
#   '제도',
#   '국내외',
#   '판로',
#   '개척',
#   '지원',
#   '확대',
#   '스타트업',
#   '기업',
#   '유니콘',
#   '기업',
#   '여성',
#   '기업',
#   '지속',
#   '성장',
#   '완결형',
#   '기업',
#   '생태계',
#   '구현',
#   '정부',
#   '여건',
#   '도전',
#   '여성',
#   '경제인',
#   '뒷받침',
#   '목소리',
#   '경청',
#   '용산',
#   '대통령실'],
#  ['전후방',
#   '각지',
#   '해외',
#   '임무',
#   '전념',
#   '각급',
#   '부대',
#   '장병',
#   '군무원',
#   '노고',
#   '헌신',
#   '감사',
#   '대한민국',
#   '안보',
#   '상황',
#   '북한',
#   '미사일',
#   '위협',
#   '동북아',
#   '안보',
#   '상황',
#   '심화',
#   '안보',
#   '나라',
#   '안보',
#   '국익',
#   '국방력',
#   '뒷받침',
#   '북한',
#   '도발',
#   '억제',
#   '대응',
#   '군사력',
#   '구축',
#   '대비',
#   '태세',
#   '유지',
#   '창군',
#   '수준',
#   '국방',
#   '태세',
#   '설계',
#   '국방',
#   '혁신',
#   '과학',
#   '기술',
#   '강군',
#   '도약',
#   '첨단',
#   '과학',
#   '기술',
#   '강군',
#   '적관',
#   '군기',
#   '소용',
#   '클라우제비츠',
#   '물리',
#   '전투력',
#   '목검',
#   '군대',
#   '정신력',
#   '비유',
#   '군기',
#   '국민',
#   '신뢰',
#   '강군',
#   '면모',
#   '나라',
#   '헌신',
#   '장병',
#   '만족',
#   '병영',
#   '환경',
#   '마련',
#   '각별',
#   '관심',
#   '국군',
#   '통수',
#   '국방',
#   '태세',
#   '확립',
#   '국방',
#   '혁신',
#   '적극',
#   '지원',
#   '국방',
#   '예산',
#   '확충',
#   '법령',
#   '제도',
#   '정비',
#   '사회',
#   '제복',
#   '용사',
#   '존중',
#   '풍토',
#   '조성',
#   '신뢰',
#   '지휘',
#   '체계',
#   '확립',
#   '군대',
#   '군대',
#   '기본',
#   '작전',
#   '현장',
#   '지휘권',
#   '보장',
#   '정부',
#   '지휘',
#   '체계',
#   '필요',
#   '간섭',
#   '안보',
#   '현장',
#   '본연',
#   '임무',
#   '지휘',
#   '보장',
#   '현장',
#   '응시',
#   '본연',
#   '임무',
#   '교본',
#   '소신',
#   '국민',
#   '안심',
#   '생업',
#   '종사',
#   '최선'],
#  ['대한민국',
#   '우주',
#   '리호',
#   '영웅',
#   '자리',
#   '영광',
#   '리호',
#   '발사',
#   '성공',
#   '위성',
#   '기술',
#   '발사체',
#   '기술',
#   '동시',
#   '세계',
#   '우주',
#   '강국',
#   '본격',
#   '우주',
#   '경제',
#   '시대',
#   '정부',
#   '투자',
#   '항공',
#   '우주',
#   '설치',
#   '항공',
#   '우주',
#   '산업',
#   '체계',
#   '지원',
#   '위성',
#   '발사체',
#   '탐사',
#   '로봇',
#   '우주',
#   '교통',
#   '권제',
#   '우주',
#   '실험장',
#   '우주',
#   '공간',
#   '필요',
#   '기술',
#   '적극',
#   '지원',
#   '우주',
#   '어린이',
#   '청소년',
#   '꿈',
#   '미래',
#   '국가',
#   '경쟁력',
#   '핵심',
#   '분야',
#   '우주',
#   '과언',
#   '우주',
#   '분야',
#   '기술력',
#   '산업',
#   '인프라',
#   '기반',
#   '우주',
#   '산업',
#   '경쟁력',
#   '확보',
#   '위성',
#   '기술',
#   '경쟁력',
#   '리호',
#   '성공',
#   '입증',
#   '발사체',
#   '기술력',
#   '기업',
#   '산업',
#   '경쟁력',
#   '강화',
#   '위성',
#   '항법',
#   '시스템',
#   '통신',
#   '위성',
#   '연계',
#   '자율',
#   '드론',
#   '산업',
#   '본격',
#   '우주',
#   '선진국',
#   '영역',
#   '인식',
#   '우주',
#   '탐사',
#   '우주',
#   '자원',
#   '채굴',
#   '우주',
#   '인터넷',
#   '우주',
#   '분야',
#   '적극',
#   '도전',
#   '궤도',
#   '발사',
#   '시작',
#   '착륙',
#   '미국',
#   '아르테미스',
#   '프로그램',
#   '참여',
#   '확대',
#   '샘플',
#   '수집',
#   '자원',
#   '채굴',
#   '임무',
#   '수행',
#   '우주',
#   '탐사',
#   '자원',
#   '역량',
#   '강화',
#   '도전',
#   '우주',
#   '경제',
#   '시대',
#   '확신',
#   '정부',
#   '우주',
#   '경제',
#   '시대',
#   '도약',
#   '실천',
#   '계획',
#   '수립',
#   '과정',
#   '연구자',
#   '현장',
#   '목소리',
#   '최우선',
#   '반영',
#   '국내외',
#   '기업',
#   '협력'],
#  ['정부',
#   '국가',
#   '재정',
#   '전략',
#   '회의',
#   '향후',
#   '우리나라',
#   '재정',
#   '운영',
#   '밑그림',
#   '중요',
#   '자리',
#   '위기',
#   '나라',
#   '재정',
#   '경제',
#   '방파제',
#   '역할',
#   '재정',
#   '유지',
#   '얘기',
#   '탄탄',
#   '재정',
#   '국가',
#   '신인도',
#   '잠재',
#   '위험',
#   '요인',
#   '지적',
#   '상황',
#   '재정',
#   '상황',
#   '악화',
#   '국가',
#   '채무',
#   '증가',
#   '금년',
#   '전망',
#   '증가',
#   '규모',
#   '속도',
#   '역대',
#   '최고',
#   '수준',
#   '재정',
#   '여건',
#   '경제',
#   '고물가',
#   '고금리',
#   '저성장',
#   '복합',
#   '위기',
#   '당면',
#   '민생',
#   '현안',
#   '재정',
#   '위기',
#   '극복',
#   '정부',
#   '솔선',
#   '허리띠',
#   '공공',
#   '부문',
#   '자산',
#   '전수',
#   '조사',
#   '기관',
#   '보유',
#   '연관',
#   '자산',
#   '적정',
#   '수준',
#   '매각',
#   '처분',
#   '공무원',
#   '정원',
#   '보수',
#   '기준',
#   '운용',
#   '예산',
#   '투입',
#   '경제',
#   '성장',
#   '민생',
#   '재정',
#   '만능',
#   '주의',
#   '환상',
#   '재정',
#   '민간',
#   '시장',
#   '영역',
#   '침범',
#   '성장',
#   '제약',
#   '구축',
#   '작동',
#   '정부',
#   '성역',
#   '고강',
#   '지출',
#   '구조',
#   '조정',
#   '국민',
#   '혈세',
#   '재원',
#   '필요',
#   '강조',
#   '경제',
#   '사회',
#   '약자',
#   '정치',
#   '세력',
#   '약자',
#   '사회',
#   '약자',
#   '취약',
#   '계층',
#   '경제',
#   '위기',
#   '극복',
#   '공공',
#   '부문',
#   '긴축',
#   '조성',
#   '자금',
#   '이분',
#   '지원',
#   '한편',
#   '격차',
#   '전략',
#   '기술',
#   '육성',
#   '미래',
#   '산업',
#   '핵심',
#   '인재',
#   '양성',
#   '국가',
#   '미래',
#   '먹거리',
#   '성장',
#   '동력',
#   '발굴',
#   '사업',
#   '돈',
#   '병사',
#   '봉급',
#   '인상',
#   '국민',
#   '약속',
#   '국정',
#   '과제',
#   '절약',
#   '재원',
#   '차질',
#   '이행',
#   '재정',
#   '개혁',
#   '뒷받침',
#   '재정',
#   '유지',
#   '재정',
#   '준칙',
#   '마련',
#   '재정',
#   '준칙',
#   '단순',
#   '합리',
#   '준칙',
#   '이행',
#   '지방',
#   '교육',
#   '재정',
#   '교부금',
#   '제도',
#   '개선',
#   '초중',
#   '학생',
#   '감소',
#   '교육',
#   '환경',
#   '변화',
#   '반영',
#   '지방',
#   '대학',
#   '포함',
#   '대학',
#   '교육',
#   '돈',
#   '초중',
#   '교육',
#   '고등',
#   '교육',
#   '사이',
#   '재정',
#   '균형',
#   '미래',
#   '핵심',
#   '인재',
#   '양성',
#   '제도',
#   '개선',
#   '국회',
#   '협력',
#   '필수',
#   '국회',
#   '소통',
#   '초당',
#   '협력',
#   '대통령실',
#   '정부',
#   '부처',
#   '당부',
#   '재정',
#   '국가',
#   '미래',
#   '재정',
#   '운용',
#   '대한민국',
#   '미래',
#   '결정',
#   '나라',
#   '재정',
#   '대한민국',
#   '도약',
#   '재정',
#   '운용',
#   '전략',
#   '마련',
#   '비상',
#   '각오',
#   '당부'],
#  ['국무',
#   '회의',
#   '민생',
#   '현안',
#   '말씀',
#   '비상',
#   '경제',
#   '민생',
#   '회의',
#   '정부',
#   '제도',
#   '경제',
#   '위기',
#   '민생',
#   '안정',
#   '역량',
#   '결집',
#   '정부',
#   '출범',
#   '차례',
#   '물가',
#   '민생',
#   '대책',
#   '주요',
#   '생필품',
#   '가격',
#   '안정',
#   '취약',
#   '계층',
#   '부담',
#   '완화',
#   '지원',
#   '국민',
#   '체감',
#   '경기',
#   '경제',
#   '타격',
#   '서민',
#   '취약',
#   '계층',
#   '정부',
#   '민생',
#   '안정',
#   '사활',
#   '국가',
#   '재정',
#   '전략',
#   '회의',
#   '공공',
#   '부문',
#   '고강',
#   '지출',
#   '구조',
#   '조정',
#   '차질',
#   '진행',
#   '확보',
#   '재원',
#   '취약',
#   '계층',
#   '지원',
#   '최대한',
#   '투입',
#   '연료비',
#   '식료품',
#   '생필품',
#   '망라',
#   '지원',
#   '지출',
#   '구조',
#   '조정',
#   '민생',
#   '지원',
#   '생활',
#   '물가',
#   '안정',
#   '적극',
#   '수급',
#   '관리',
#   '해외',
#   '수입',
#   '확대',
#   '농축',
#   '수산물',
#   '할인',
#   '지원',
#   '고유',
#   '상황',
#   '지속',
#   '악화',
#   '대비',
#   '유류',
#   '추가',
#   '인하',
#   '가능',
#   '유류',
#   '탄력',
#   '세율',
#   '한도',
#   '확대',
#   '추진',
#   '금리',
#   '상승',
#   '어려움',
#   '대출자',
#   '청년',
#   '부담',
#   '방안',
#   '공공',
#   '임대',
#   '주택',
#   '임대료',
#   '동결',
#   '연장',
#   '글로벌',
#   '인플레이션',
#   '촉발',
#   '위기',
#   '국민',
#   '연대',
#   '위기',
#   '역량',
#   '시험',
#   '가격',
#   '급등',
#   '충격',
#   '취약',
#   '계층',
#   '사회',
#   '약자',
#   '전가',
#   '인플레이션',
#   '경기',
#   '침체',
#   '악순환',
#   '고통',
#   '부담',
#   '연대',
#   '협력',
#   '위기',
#   '극복',
#   '비상',
#   '상황',
#   '대책',
#   '강구',
#   '포함',
#   '부처',
#   '장관',
#   '민생',
#   '안전',
#   '최우선',
#   '과제',
#   '협의',
#   '피부',
#   '체감',
#   '만전',
#   '당부'],
#  ['정보',
#   '보호',
#   '기념식',
#   '개최',
#   '나라',
#   '디지털',
#   '정보',
#   '산업',
#   '판교',
#   '테크노',
#   '밸리',
#   '정보',
#   '보호',
#   '기념',
#   '수상',
#   '영예',
#   '정보',
#   '보호',
#   '유공자',
#   '감사',
#   '생활',
#   '메타',
#   '버스',
#   '디지털',
#   '기술',
#   '자리',
#   '디지털',
#   '전환',
#   '가속',
#   '사이버',
#   '위협',
#   '증가',
#   '사이버',
#   '공격',
#   '민간',
#   '공공',
#   '구별',
#   '차별',
#   '발생',
#   '기반',
#   '시설',
#   '국민',
#   '위협',
#   '글로벌',
#   '조직',
#   '지능',
#   '사이버',
#   '위협',
#   '경영',
#   '위협',
#   '요인',
#   '사이버',
#   '안보',
#   '안전',
#   '디지털',
#   '경제',
#   '구축',
#   '민간',
#   '공공',
#   '협력',
#   '사이버',
#   '대응',
#   '태세',
#   '정부',
#   '민간',
#   '공공',
#   '유기',
#   '정보',
#   '공유',
#   '분석',
#   '체계',
#   '구축',
#   '사이버',
#   '위협',
#   '예방',
#   '대응',
#   '시스템',
#   '대칭',
#   '전력',
#   '비대칭',
#   '전력',
#   '하이브리드',
#   '변모',
#   '전쟁',
#   '양상',
#   '대응',
#   '사이버',
#   '전력',
#   '기술',
#   '고도',
#   '사이',
#   '수행',
#   '역량',
#   '강화',
#   '사이버',
#   '안보',
#   '분야',
#   '인재',
#   '양성',
#   '중요',
#   '대학',
#   '대학원',
#   '전공',
#   '과정',
#   '확대',
#   '정예',
#   '인력',
#   '화이트',
#   '해커',
#   '사이버',
#   '안보',
#   '인재',
#   '양성',
#   '전문',
#   '분야',
#   '복무',
#   '전역',
#   '취업',
#   '창업',
#   '연계',
#   '사이버',
#   '피오트',
#   '제도',
#   '도입',
#   '국가',
#   '사이버',
#   '안보',
#   '기여',
#   '우수',
#   '인재',
#   '양성',
#   '사이버',
#   '예비군',
#   '창설',
#   '국가',
#   '비상',
#   '상황',
#   '대비',
#   '민관',
#   '사이버',
#   '합동',
#   '대응',
#   '역량',
#   '강화',
#   '정부',
#   '사이버',
#   '안보',
#   '기술',
#   '전략',
#   '사업',
#   '육성',
#   '사이버',
#   '위협',
#   '국경',
#   '사이버',
#   '위협',
#   '대응',
#   '국제',
#   '공조',
#   '강화',
#   '미국',
#   '나토',
#   '우방국',
#   '협력',
#   '사이버',
#   '훈련',
#   '사이버',
#   '국제',
#   '협력',
#   '네트워크',
#   '확충',
#   '사이버',
#   '범죄',
#   '공동',
#   '대응',
#   '부다페스트',
#   '협약',
#   '가입',
#   '추진',
#   '사이버',
#   '범죄',
#   '퇴치',
#   '사이버',
#   '규범',
#   '수립',
#   '국제',
#   '공조',
#   '적극',
#   '정부',
#   '민간',
#   '전문가',
#   '사이버',
#   '안보',
#   '안전',
#   '디지털',
#   '혁신',
#   '국가',
#   '정보',
#   '보호'],
#  ['비상',
#   '경제',
#   '민생',
#   '회의',
#   '광화문',
#   '서민',
#   '금융',
#   '통합',
#   '지원',
#   '센터',
#   '한국은행',
#   '기준',
#   '금리',
#   '포인트',
#   '인상',
#   '물가',
#   '상승',
#   '억제',
#   '기준',
#   '금리',
#   '인상',
#   '세계',
#   '상황',
#   '취약',
#   '계층',
#   '채무',
#   '부담',
#   '가중',
#   '코로나',
#   '대출',
#   '자영업',
#   '소상',
#   '공인',
#   '부동산',
#   '가격',
#   '불안',
#   '마음',
#   '마련',
#   '대출',
#   '주택',
#   '구입',
#   '서민',
#   '미래',
#   '불안감',
#   '주식',
#   '투자',
#   '청년',
#   '원리금',
#   '상환',
#   '어려움',
#   '금리',
#   '인상',
#   '물가',
#   '상승',
#   '억제',
#   '조치',
#   '부담',
#   '취약',
#   '계층',
#   '사회',
#   '약자',
#   '전가',
#   '정부',
#   '선제',
#   '지원',
#   '궁극',
#   '사회',
#   '사회',
#   '비용',
#   '미래인',
#   '청년',
#   '세대',
#   '꿈',
#   '희망',
#   '정부',
#   '금융',
#   '자원',
#   '활용',
#   '대책',
#   '마련',
#   '적극',
#   '상환',
#   '어려움',
#   '소상',
#   '공인',
#   '자영업',
#   '금융',
#   '채무',
#   '대출',
#   '채권',
#   '자산',
#   '관리',
#   '공사',
#   '매입',
#   '만기',
#   '연장',
#   '금리',
#   '감면',
#   '상환',
#   '부담',
#   '경감',
#   '고금리',
#   '입자',
#   '신용보증기금',
#   '보증',
#   '저금리',
#   '대출',
#   '전환',
#   '금리',
#   '부담',
#   '연체',
#   '발생',
#   '선제',
#   '이자',
#   '감면',
#   '원금',
#   '상환',
#   '유예',
#   '청년',
#   '특혜',
#   '프로그램',
#   '신설',
#   '청년',
#   '안심',
#   '전환',
#   '대출',
#   '주담',
#   '대출',
#   '상환',
#   '부담',
#   '주택',
#   '담보',
#   '대출자',
#   '안심',
#   '전환',
#   '대출',
#   '제도',
#   '시행',
#   '대출',
#   '금리',
#   '인하',
#   '장기',
#   '고정',
#   '금리',
#   '대출',
#   '전환',
#   '금리',
#   '상승',
#   '부담',
#   '해소',
#   '서민',
#   '경제',
#   '국가',
#   '경제',
#   '기본',
#   '고물가',
#   '고금리',
#   '부담',
#   '서민',
#   '취약',
#   '계층',
#   '전가',
#   '관계',
#   '기관',
#   '신경',
#   '당부'],
#  ['존경',
#   '충남',
#   '도민',
#   '충남',
#   '대천',
#   '해수욕장',
#   '시절',
#   '부모',
#   '해수욕장',
#   '해수욕',
#   '기억',
#   '시작',
#   '머드',
#   '축제',
#   '보령시',
#   '머드',
#   '해양',
#   '자원',
#   '성공',
#   '활용',
#   '지역',
#   '특화',
#   '관광',
#   '산업',
#   '성장',
#   '세계',
#   '축제',
#   '협회',
#   '선정',
#   '아시아',
#   '축제',
#   '나라',
#   '대표',
#   '축제',
#   '사랑',
#   '시민',
#   '충남',
#   '도민',
#   '열정',
#   '노력',
#   '가능',
#   '머드',
#   '축제',
#   '체험',
#   '축제',
#   '해양',
#   '산업',
#   '미래',
#   '비전',
#   '공유',
#   '산업',
#   '박람회',
#   '탄생',
#   '해양',
#   '머드',
#   '박람회',
#   '해양',
#   '자원',
#   '활용',
#   '관광',
#   '산업',
#   '활성',
#   '에너지',
#   '환경',
#   '바이오',
#   '분야',
#   '해양',
#   '산업',
#   '육성',
#   '지역',
#   '경제',
#   '동력',
#   '부산',
#   '개최',
#   '바다',
#   '기념식',
#   '정부',
#   '해양',
#   '산업',
#   '국가',
#   '핵심',
#   '전략산업',
#   '육성',
#   '해양',
#   '바이오',
#   '소재',
#   '국산화',
#   '연구',
#   '산업',
#   '경쟁력',
#   '강화',
#   '권역',
#   '해양',
#   '바이오',
#   '거점',
#   '구축',
#   '건강',
#   '관리',
#   '관광',
#   '휴양',
#   '동시',
#   '제공',
#   '해양',
#   '치유',
#   '산업',
#   '육성',
#   '연안',
#   '어촌',
#   '지역',
#   '경제',
#   '활력',
#   '사랑',
#   '충남',
#   '도민',
#   '충남',
#   '대한민국',
#   '중심',
#   '황해',
#   '해양',
#   '경제',
#   '중심',
#   '세계',
#   '자연',
#   '유산',
#   '등재',
#   '갯벌',
#   '국내',
#   '최초',
#   '해양',
#   '생물',
#   '보호구역',
#   '가로림만',
#   '해양',
#   '관광',
#   '자원',
#   '국립',
#   '생물',
#   '자원',
#   '국가',
#   '생태',
#   '산업단지',
#   '건립',
#   '해양',
#   '바이오',
#   '산업',
#   '지원',
#   '센터',
#   '명실상부',
#   '해양',
#   '바이오',
#   '산업',
#   '거점',
#   '성장',
#   '잠재력',
#   '충남',
#   '미래',
#   '먹거리',
#   '양질',
#   '일자리',
#   '정부',
#   '적극',
#   '뒷받침',
#   '지역',
#   '자원',
#   '활용',
#   '해양',
#   '산업',
#   '균형',
#   '발전',
#   '토대',
#   '지역',
#   '성장',
#   '산업',
#   '발굴',
#   '경제',
#   '산업',
#   '지방',
#   '시대',
#   '해양',
#   '머드',
#   '박람회',
#   '개최',
#   '축하',
#   '서해안',
#   '무궁',
#   '가능',
#   '머드',
#   '가치',
#   '세계',
#   '기대',
#   '코로나',
#   '축제',
#   '국민',
#   '건강',
#   '축제',
#   '정부',
#   '부처',
#   '지자체',
#   '만전',
#   '충남',
#   '도민',
#   '행복',
#   '저녁'],
#  ['코로나',
#   '확산',
#   '기로',
#   '정부',
#   '코로나',
#   '대응',
#   '기본',
#   '철학',
#   '과학',
#   '방역',
#   '과학',
#   '방역',
#   '코로나',
#   '대응',
#   '의사',
#   '결정',
#   '거버넌스',
#   '전문가',
#   '과학',
#   '증거',
#   '기반',
#   '예방',
#   '치료',
#   '정부',
#   '코로나',
#   '유행',
#   '대응',
#   '방안',
#   '발표',
#   '국민',
#   '희생',
#   '강요',
#   '자율',
#   '책임',
#   '중시',
#   '중증',
#   '관리',
#   '위주',
#   '국민',
#   '생명',
#   '건강',
#   '만전',
#   '국민',
#   '불안',
#   '정부',
#   '대책',
#   '설명',
#   '관계',
#   '기관',
#   '병상',
#   '치료제',
#   '확보',
#   '최선',
#   '당부',
#   '백신',
#   '접종',
#   '적극',
#   '권장',
#   '예방',
#   '치명률',
#   '대우',
#   '조선',
#   '해양',
#   '사내',
#   '하청',
#   '노조',
#   '불법',
#   '파업',
#   '장기',
#   '회복',
#   '조선업',
#   '경제',
#   '피해',
#   '지역',
#   '사회',
#   '시민',
#   '우려',
#   '불법',
#   '위협',
#   '방식',
#   '동원',
#   '국민',
#   '용납',
#   '노사',
#   '불문',
#   '산업',
#   '현장',
#   '법치주의',
#   '확립',
#   '경제',
#   '위기',
#   '극복',
#   '매진',
#   '국무회의',
#   '반도체',
#   '전략',
#   '가치',
#   '주제',
#   '토론',
#   '연장선',
#   '반도체',
#   '인재',
#   '양성',
#   '방안',
#   '미래',
#   '먹거리',
#   '성장',
#   '토대',
#   '분야',
#   '투자',
#   '지원',
#   '강조',
#   '반도체',
#   '국가',
#   '안보',
#   '자산',
#   '산업',
#   '핵심',
#   '경제',
#   '비약',
#   '성장',
#   '장기',
#   '계획',
#   '핵심',
#   '전략',
#   '산업',
#   '혁명',
#   '첨단',
#   '산업',
#   '구조',
#   '인재',
#   '성장',
#   '순환',
#   '체계',
#   '중요',
#   '분야',
#   '대학',
#   '정원',
#   '확대',
#   '현장',
#   '전문가',
#   '교육',
#   '기여',
#   '규제',
#   '반도체',
#   '분야',
#   '과학',
#   '기술',
#   '인재',
#   '양성',
#   '산업',
#   '저변',
#   '확대',
#   '정부',
#   '역량',
#   '집중',
#   '정부',
#   '경제',
#   '상황',
#   '당면',
#   '민생',
#   '최우선',
#   '경제',
#   '성장',
#   '동력',
#   '미래',
#   '먹거리',
#   '확보',
#   '책임',
#   '비상',
#   '경제',
#   '민생',
#   '회의',
#   '주재',
#   '업무',
#   '보고',
#   '현안',
#   '점검',
#   '부처',
#   '책임감',
#   '필요',
#   '정책',
#   '신속',
#   '추진',
#   '당부',
#   '포함',
#   '장관',
#   '민생',
#   '나라',
#   '경제',
#   '각오',
#   '정책',
#   '국민',
#   '체감',
#   '정책',
#   '정책',
#   '현장',
#   '장관',
#   '국민',
#   '소통',
#   '당부',
#   '추진',
#   '정책',
#   '장관',
#   '국민',
#   '설명',
#   '국무',
#   '회의',
#   '유엔군',
#   '참전',
#   '참전',
#   '용사',
#   '가족',
#   '훈포장',
#   '수여',
#   '의결',
#   '자유',
#   '수호',
#   '희생',
#   '참전',
#   '용사',
#   '정부',
#   '기억',
#   '제복',
#   '영웅',
#   '책임',
#   '예우',
#   '최선',
#   '국정',
#   '의견',
#   '개진',
#   '토론',
#   '기대',
#   '감사'],
#  ['비상',
#   '경제',
#   '민생',
#   '회의',
#   '서민',
#   '주거',
#   '안정',
#   '방안',
#   '논의',
#   '정부',
#   '임대차',
#   '시장',
#   '안정',
#   '방안',
#   '발표',
#   '금리',
#   '상승',
#   '전세',
#   '대출금',
#   '상환',
#   '부담',
#   '가중',
#   '월세',
#   '전환',
#   '증가',
#   '무주택',
#   '서민',
#   '주거비',
#   '부담',
#   '정부',
#   '취약',
#   '계층',
#   '주거',
#   '안정',
#   '서민',
#   '주거비',
#   '부담',
#   '최선',
#   '노력',
#   '조치',
#   '서민',
#   '주거',
#   '안정',
#   '버팀목',
#   '전세',
#   '자금',
#   '대출',
#   '금리',
#   '연말',
#   '동결',
#   '청년',
#   '신혼',
#   '부부',
#   '전세',
#   '대출',
#   '한도',
#   '확대',
#   '청년',
#   '원가',
#   '주택',
#   '역세권',
#   '주택',
#   '공공',
#   '주택',
#   '공급',
#   '확대',
#   '규제',
#   '개선',
#   '민간',
#   '임대',
#   '주택',
#   '공급',
#   '활성',
#   '취약',
#   '계층',
#   '공공',
#   '임대',
#   '주택',
#   '공급',
#   '확대',
#   '노후',
#   '영구',
#   '임대',
#   '주택',
#   '시설',
#   '정비',
#   '환경',
#   '개선',
#   '임대',
#   '주택',
#   '지원',
#   '대상자',
#   '선제',
#   '발굴',
#   '주지원',
#   '강화',
#   '공공',
#   '임대',
#   '주택',
#   '임대료',
#   '동결',
#   '급여',
#   '대상',
#   '중위',
#   '소득',
#   '확대',
#   '취약',
#   '계층',
#   '주거비',
#   '경감',
#   '지원',
#   '서민',
#   '보증금',
#   '전세',
#   '사기',
#   '기승',
#   '서민',
#   '깡통',
#   '전세',
#   '우려',
#   '지역',
#   '선별',
#   '선제',
#   '관리',
#   '전세',
#   '보증금',
#   '반환',
#   '보증',
#   '활성',
#   '피해자',
#   '이주',
#   '자금',
#   '긴급',
#   '자금',
#   '대출',
#   '신설',
#   '안정',
#   '전세',
#   '사기',
#   '민생',
#   '위협',
#   '범죄',
#   '수사',
#   '일벌백계',
#   '주거',
#   '안정',
#   '주거',
#   '복지',
#   '민생',
#   '안정',
#   '핵심',
#   '정부',
#   '기회',
#   '사다리',
#   '복원',
#   '주거',
#   '안전망',
#   '구축',
#   '관계',
#   '기관',
#   '주거',
#   '분야',
#   '민생',
#   '안정',
#   '방안',
#   '차질',
#   '현장',
#   '이행',
#   '최선',
#   '노력',
#   '논의',
#   '주거',
#   '취약',
#   '계층',
#   '지원',
#   '서민',
#   '주거비',
#   '부담',
#   '완화',
#   '방안',
#   '근본',
#   '부동산',
#   '시장',
#   '안정',
#   '민간',
#   '시장',
#   '주택',
#   '공급',
#   '활성',
#   '금리',
#   '상승',
#   '집값',
#   '안정',
#   '하락세',
#   '주택',
#   '공급',
#   '계획',
#   '차질',
#   '향후',
#   '수년',
#   '원활',
#   '안정',
#   '수요',
#   '대응',
#   '공급',
#   '전월세',
#   '시장',
#   '정상',
#   '임대차',
#   '개정',
#   '사회',
#   '논의',
#   '필요',
#   '시점',
#   '국회',
#   '중심',
#   '공론',
#   '기대',
#   '정부',
#   '논의',
#   '적극',
#   '참여',
#   '걸음',
#   '감사'],
#  ['국무',
#   '위원',
#   '부처',
#   '차관',
#   '처장',
#   '청장',
#   '자리',
#   '인수위',
#   '심혈',
#   '국정',
#   '과제',
#   '공유',
#   '향후',
#   '국정',
#   '운영',
#   '방향',
#   '논의',
#   '화면',
#   '도약',
#   '대한민국',
#   '국민',
#   '나라',
#   '정부',
#   '존재',
#   '국민',
#   '나라',
#   '말씀',
#   '도약',
#   '경제',
#   '도약',
#   '성장',
#   '사회',
#   '해묵',
#   '갈등',
#   '원인',
#   '저성장',
#   '도약',
#   '갈등',
#   '치유',
#   '말씀',
#   '경제',
#   '비상',
#   '상황',
#   '복합',
#   '위기',
#   '직면',
#   '기존',
#   '방식',
#   '관성',
#   '대책',
#   '직면',
#   '위기',
#   '극복',
#   '캐치프레이즈',
#   '정부',
#   '국민',
#   '기대',
#   '이념',
#   '민생',
#   '최우선',
#   '포퓰리즘',
#   '인기',
#   '영합',
#   '정책',
#   '나라',
#   '도약',
#   '기틀',
#   '취임사',
#   '정부',
#   '국민',
#   '자유민주주의',
#   '인권',
#   '법치',
#   '보편',
#   '가치',
#   '규범',
#   '바탕',
#   '국제',
#   '사회',
#   '책임',
#   '연대',
#   '경제',
#   '비약',
#   '성장',
#   '국정',
#   '운영',
#   '철학',
#   '국정',
#   '목표',
#   '논의',
#   '국정',
#   '과제',
#   '국정',
#   '목표',
#   '민간',
#   '중심',
#   '경제',
#   '전환',
#   '산업',
#   '혁명',
#   '첨단',
#   '산업',
#   '구조',
#   '노동',
#   '교육',
#   '혁신',
#   '자유',
#   '창의',
#   '기반',
#   '과학',
#   '기술',
#   '선도',
#   '세계',
#   '평화',
#   '번영',
#   '기여',
#   '글로벌',
#   '리더',
#   '국가',
#   '책임',
#   '역할',
#   '중요',
#   '국정',
#   '목표',
#   '부처',
#   '논리',
#   '접근',
#   '부처',
#   '목표',
#   '공유',
#   '마음가짐',
#   '당부',
#   '국정',
#   '과제',
#   '이행',
#   '과정',
#   '어려움',
#   '사회',
#   '지속',
#   '가능',
#   '필요',
#   '개혁',
#   '과제',
#   '저항',
#   '예상',
#   '지출',
#   '구조',
#   '조정',
#   '공공',
#   '기관',
#   '개혁',
#   '국민',
#   '기준',
#   '국민',
#   '이익',
#   '국가',
#   '미래',
#   '정부',
#   '의사',
#   '결정',
#   '이념',
#   '실용',
#   '과학',
#   '중심',
#   '데이터',
#   '기초',
#   '국민',
#   '소통',
#   '민생',
#   '현안',
#   '현장',
#   '점검',
#   '차관',
#   '처장',
#   '청장',
#   '현장',
#   '국민',
#   '소통',
#   '언론',
#   '설명',
#   '당부',
#   '정부',
#   '추진',
#   '정책',
#   '방향',
#   '민생',
#   '현안',
#   '국민',
#   '설명',
#   '정책',
#   '적극',
#   '국민',
#   '이해',
#   '소통',
#   '강화',
#   '국민',
#   '신뢰',
#   '민간',
#   '예측',
#   '가능',
#   '국민',
#   '필요',
#   '정책',
#   '국민',
#   '차관',
#   '책임감',
#   '당부',
#   '정부',
#   '조직',
#   '예산',
#   '인사',
#   '문화',
#   '국민',
#   '수요',
#   '상황',
#   '변화',
#   '감지',
#   '신속',
#   '대응',
#   '최선',
#   '당부',
#   '국정',
#   '과제',
#   '반영',
#   '국민',
#   '대표',
#   '공약',
#   '추진',
#   '로드맵',
#   '장관',
#   '필요',
#   '제게도',
#   '얘기',
#   '당부',
#   '추구',
#   '정책',
#   '목표',
#   '경제',
#   '비약',
#   '성장',
#   '도약',
#   '역량',
#   '비상',
#   '각오',
#   '자리',
#   '책임감',
#   '자리',
#   '감사'],
#  ['비상',
#   '경제',
#   '민생',
#   '회의',
#   '분당',
#   '서울대학병원',
#   '케어',
#   '혁신',
#   '파크',
#   '바이오',
#   '산업',
#   '혁신',
#   '방',
#   '안',
#   '논의',
#   '바이오',
#   '분야',
#   '국민',
#   '건강',
#   '동시',
#   '고소득',
#   '일자리',
#   '창출',
#   '경제',
#   '성장',
#   '직결',
#   '정부',
#   '바이오',
#   '산업',
#   '국가',
#   '핵심',
#   '전략',
#   '산업',
#   '육성',
#   '계획',
#   '바이오',
#   '백신',
#   '허브',
#   '조성',
#   '금융',
#   '지원',
#   '확대',
#   '기업',
#   '블록버스터',
#   '신약',
#   '백신',
#   '전념',
#   '지원',
#   '바이오',
#   '분야',
#   '연구',
#   '원활',
#   '투자',
#   '규제',
#   '개선',
#   '디지털',
#   '혁신',
#   '의료',
#   '기기',
#   '인허가',
#   '평가',
#   '기관',
#   '단축',
#   '현장',
#   '신속',
#   '활용',
#   '바이오',
#   '분야',
#   '산업',
#   '영역',
#   '규제',
#   '혁신',
#   '방향',
#   '제시',
#   '시장',
#   '예측',
#   '가능',
#   '혁신',
#   '기술',
#   '상용',
#   '지원',
#   '예측',
#   '가능',
#   '투자',
#   '원활',
#   '필요',
#   '규제',
#   '민간',
#   '시장',
#   '보건복지부',
#   '관계',
#   '부처',
#   '연구',
#   '창업',
#   '활동',
#   '제약',
#   '합리',
#   '제도',
#   '규제',
#   '개선',
#   '당부',
#   '정부',
#   '보건복지부',
#   '중요',
#   '추진',
#   '업무',
#   '바이오',
#   '혁신',
#   '규제',
#   '샌드',
#   '박스',
#   '신설',
#   '바이오',
#   '분야',
#   '인재',
#   '양성',
#   '생태계',
#   '현장',
#   '목소리',
#   '적극',
#   '반영',
#   '당부',
#   '국가',
#   '미래',
#   '먹거리',
#   '성장',
#   '동력',
#   '선제',
#   '지원',
#   '정부',
#   '중요',
#   '역할',
#   '궁극',
#   '민생',
#   '정부',
#   '민생',
#   '현안',
#   '핵심',
#   '산업',
#   '육성',
#   '장기',
#   '계획',
#   '준비'],
#  ['존경',
#   '국민',
#   '해군',
#   '장병',
#   '군무원',
#   '현대',
#   '중공업',
#   '임직원',
#   '국내',
#   '기술',
#   '설계',
#   '건조',
#   '세계',
#   '최고',
#   '수준',
#   '차세대',
#   '이지스',
#   '구축함',
#   '정조대',
#   '왕함',
#   '진수',
#   '영광',
#   '해군',
#   '장병',
#   '방위',
#   '사업',
#   '관계자',
#   '노고',
#   '감사',
#   '세계',
#   '일류',
#   '기술력',
#   '함정',
#   '건조',
#   '현대',
#   '중공업',
#   '관계자',
#   '협력',
#   '근로자',
#   '감사',
#   '첨단',
#   '기술',
#   '집약',
#   '세계',
#   '최고',
#   '이지스',
#   '구축함',
#   '기술',
#   '해군',
#   '차세대',
#   '이지스',
#   '구축',
#   '정조대',
#   '왕함',
#   '첨단',
#   '전투',
#   '체계',
#   '기반',
#   '탄도',
#   '미사일',
#   '탐지',
#   '추적',
#   '요격',
#   '능력',
#   '국가',
#   '전략',
#   '자산',
#   '해군',
#   '전투',
#   '역량',
#   '강화',
#   '나라',
#   '수출입',
#   '물동량',
#   '해양',
#   '수송',
#   '바다',
#   '스스로',
#   '해양',
#   '강국',
#   '역량',
#   '경제',
#   '강국',
#   '국민',
#   '바다',
#   '안전',
#   '경제',
#   '활동',
#   '해양',
#   '안보',
#   '구축',
#   '국군',
#   '통수',
#   '바다',
#   '사수',
#   '해군',
#   '장병',
#   '신뢰',
#   '임전무퇴',
#   '정신',
#   '바다',
#   '자리',
#   '방산',
#   '주역',
#   '조선업',
#   '방위',
#   '산업',
#   '관계자',
#   '자리',
#   '조선',
#   '산업',
#   '상반기',
#   '수주',
#   '세계',
#   '최신예',
#   '군함',
#   '세계',
#   '각국',
#   '수출',
#   '정부',
#   '방위',
#   '산업',
#   '경제',
#   '성장',
#   '선도',
#   '첨단',
#   '전략산업',
#   '육성',
#   '세계',
#   '수준',
#   '첨단',
#   '무기',
#   '체계',
#   '방산',
#   '수출',
#   '성장',
#   '동력',
#   '대한민국',
#   '성장',
#   '동력',
#   '견인',
#   '자부심',
#   '당부',
#   '창군',
#   '수준',
#   '국방',
#   '혁신',
#   '과학',
#   '기술',
#   '강군',
#   '도약',
#   '해양',
#   '강국',
#   '꿈',
#   '도전',
#   '정조대',
#   '왕함',
#   '진수',
#   '축하',
#   '해양',
#   '강국',
#   '꿈',
#   '실현',
#   '감사'],
#  ['조코',
#   '위도',
#   '대통령',
#   '공식',
#   '방한',
#   '환영',
#   '인도네시아',
#   '관계',
#   '수교',
#   '경제',
#   '문화',
#   '교류',
#   '외교',
#   '안보',
#   '분야',
#   '괄목',
#   '발전',
#   '인도네시아',
#   '도국',
#   '동남아',
#   '국가',
#   '유일',
#   '특별',
#   '전략',
#   '관계',
#   '인도네시아',
#   '인도',
#   '태평양',
#   '지역',
#   '평화',
#   '공동',
#   '번영',
#   '목표',
#   '공유',
#   '규범',
#   '입각',
#   '국제',
#   '질서',
#   '유지',
#   '양국',
#   '이익',
#   '부합',
#   '조코',
#   '대통령',
#   '변화',
#   '국제',
#   '정세',
#   '양국',
#   '전략',
#   '차원',
#   '협력',
#   '강화',
#   '정부',
#   '외교',
#   '발판',
#   '마련',
#   '인도',
#   '태평양',
#   '지역',
#   '평화',
#   '공동',
#   '번영',
#   '핵심',
#   '파트너',
#   '인도',
#   '태평양',
#   '전략',
#   '중요',
#   '요소',
#   '조코',
#   '대통령',
#   '전략',
#   '중요',
#   '공유',
#   '협력',
#   '강화',
#   '의지',
#   '전달',
#   '중심',
#   '지지',
#   '바탕',
#   '인도',
#   '태평양',
#   '전략',
#   '관점',
#   '조화',
#   '양국',
#   '소통',
#   '공급',
#   '경제',
#   '안보',
#   '포괄',
#   '양국',
#   '실질',
#   '협력',
#   '증진',
#   '인도네시아',
#   '니켈',
#   '핵심',
#   '광물',
#   '나라',
#   '나라',
#   '첨단',
#   '산업',
#   '중요',
#   '소재',
#   '조코',
#   '대통령',
#   '핵심',
#   '광물',
#   '공급',
#   '안정',
#   '양국',
#   '경제',
#   '안보',
#   '협력',
#   '강화',
#   '전기',
#   '배터리',
#   '첨단',
#   '산업',
#   '분야',
#   '전략',
#   '연대',
#   '구축',
#   '출범',
#   '인도',
#   '태평양',
#   '경제',
#   '프레임워크',
#   '양국',
#   '공통',
#   '관심사',
#   '협력',
#   '인도네시아',
#   '포괄',
#   '경제',
#   '협력',
#   '역내',
#   '포괄',
#   '경제',
#   '협정',
#   '발효',
#   '양국',
#   '실질',
#   '협력',
#   '확대',
#   '기여',
#   '인식',
#   '인도네시아',
#   '투자',
#   '기업',
#   '각별',
#   '관심',
#   '지원',
#   '당부',
#   '조코',
#   '대통령',
#   '역점',
#   '인도네시아',
#   '사업',
#   '양측',
#   '협력',
#   '종시',
#   '건설',
#   '경험',
#   '인도네시아',
#   '참고',
#   '정상',
#   '회담',
#   '양국',
#   '협력',
#   '개정',
#   '기업',
#   '인도네시아',
#   '인프라',
#   '행정',
#   '시티',
#   '구축',
#   '적극',
#   '기여',
#   '토대',
#   '마련',
#   '국방',
#   '방산',
#   '협력',
#   '양국',
#   '관계',
#   '심축',
#   '양국',
#   '차세대',
#   '전투기',
#   '시험',
#   '비행',
#   '성공',
#   '쾌거',
#   '축하',
#   '차세대',
#   '전투기',
#   '공동',
#   '사업',
#   '순조',
#   '진행',
#   '양국',
#   '협력',
#   '의지',
#   '확인',
#   '방위',
#   '산업',
#   '세계',
#   '기술력',
#   '생산력',
#   '토대',
#   '여타',
#   '방산',
#   '협력',
#   '적극',
#   '추진',
#   '주요',
#   '국제',
#   '현안',
#   '공조',
#   '심화',
#   '인도네시아',
#   '동남아',
#   '유일',
#   '회원국',
#   '의장국',
#   '정부',
#   '인도네시아',
#   '의장국',
#   '활동',
#   '적극',
#   '지지',
#   '정상',
#   '회의',
#   '참석',
#   '고대',
#   '성공',
#   '회의',
#   '개최',
#   '적극',
#   '협력',
#   '북한',
#   '미사일',
#   '위협',
#   '우려',
#   '공유',
#   '국제',
#   '사회',
#   '단합',
#   '대응',
#   '노력',
#   '우크라',
#   '사태',
#   '해결',
#   '국제',
#   '식량',
#   '에너지',
#   '위기',
#   '해소',
#   '협력',
#   '미얀마',
#   '민주주의',
#   '회복',
#   '인도',
#   '위기',
#   '해소',
#   '지원',
#   '조코',
#   '대통령',
#   '회담',
#   '공통점',
#   '내년도',
#   '인도네시아',
#   '수교',
#   '주년',
#   '양국',
#   '특별',
#   '전략',
#   '관계',
#   '단계',
#   '도약',
#   '조코',
#   '대통령',
#   '소통',
#   '감사'],
#  ['중부',
#   '지방',
#   '집중호우',
#   '피해',
#   '발생',
#   '인명',
#   '피해',
#   '포함',
#   '피해',
#   '위로',
#   '말씀',
#   '일선',
#   '현장',
#   '지자체',
#   '관계',
#   '기관',
#   '담당자',
#   '대응',
#   '집중호우',
#   '예상',
#   '행안',
#   '중심',
#   '비상',
#   '대비',
#   '태세',
#   '돌입',
#   '피해',
#   '최소',
#   '노력',
#   '호우',
#   '지속',
#   '긴장감',
#   '총력',
#   '대응',
#   '당부',
#   '산사태',
#   '취약',
#   '지역',
#   '지대',
#   '침수',
#   '우려',
#   '지역',
#   '위험',
#   '지역',
#   '선제',
#   '통제',
#   '실시',
#   '기상',
#   '상황',
#   '통제',
#   '정보',
#   '국민',
#   '안내',
#   '혼란',
#   '불편',
#   '최소',
#   '천재지변',
#   '인재',
#   '인명',
#   '철저',
#   '점검',
#   '당부',
#   '호우',
#   '상황',
#   '정리',
#   '내용',
#   '조사',
#   '신속',
#   '복구',
#   '지원',
#   '당부',
#   '집중호우',
#   '강수량',
#   '나라',
#   '기상',
#   '관측',
#   '역사',
#   '최고',
#   '기록',
#   '갱신',
#   '기후',
#   '변화',
#   '기상',
#   '기인',
#   '판단',
#   '정부',
#   '기후',
#   '변화',
#   '기상',
#   '일상',
#   '고려',
#   '재난',
#   '관리',
#   '체계',
#   '원점',
#   '검토',
#   '국민',
#   '생명',
#   '재산',
#   '상황',
#   '종료',
#   '총력',
#   '대응',
#   '당부',
#   '국민',
#   '조치',
#   '당부'],
#  ['국무',
#   '회의',
#   '시작',
#   '행안',
#   '상황실',
#   '집중호우',
#   '대처',
#   '긴급',
#   '점검',
#   '회의',
#   '긴장감',
#   '총력',
#   '대응',
#   '인재',
#   '목숨',
#   '관계',
#   '부처',
#   '신속',
#   '복구',
#   '피해',
#   '지원',
#   '주거',
#   '안전',
#   '문제',
#   '주거',
#   '취약',
#   '지역',
#   '취약',
#   '계층',
#   '주거',
#   '안전',
#   '대책',
#   '마련',
#   '당부',
#   '국민',
#   '재산',
#   '생명',
#   '긴장',
#   '정부',
#   '사회',
#   '약자',
#   '취약',
#   '계층',
#   '보호',
#   '민생',
#   '경제',
#   '민간',
#   '투자',
#   '일자리',
#   '창출',
#   '세제',
#   '정상',
#   '원전',
#   '산업',
#   '난파',
#   '한미',
#   '동맹',
#   '강화',
#   '정상',
#   '사회',
#   '지속',
#   '가능',
#   '재정',
#   '확보',
#   '공공',
#   '부문',
#   '개혁',
#   '시동',
#   '국민',
#   '정부',
#   '변화',
#   '혁신',
#   '국무',
#   '위원',
#   '국민',
#   '휴가',
#   '기간',
#   '정치',
#   '시작',
#   '시작',
#   '국민',
#   '방향',
#   '국민',
#   '목표',
#   '국민',
#   '국민',
#   '목소리',
#   '숨소리',
#   '국민',
#   '소통',
#   '정책',
#   '추진',
#   '과정',
#   '국민',
#   '이해',
#   '공감',
#   '탁상',
#   '공론',
#   '현장',
#   '목소리',
#   '적극',
#   '반영',
#   '정책',
#   '현장',
#   '파장',
#   '사전',
#   '검토',
#   '고려',
#   '국민',
#   '정부',
#   '신뢰',
#   '직결',
#   '문제',
#   '국무',
#   '위원',
#   '당부',
#   '연습',
#   '실시',
#   '예정',
#   '형식',
#   '진행',
#   '정부',
#   '연습',
#   '정상',
#   '연합',
#   '군사',
#   '연습',
#   '프리덤',
#   '쉴드',
#   '통합',
#   '시행',
#   '국가',
#   '위기관리',
#   '능력',
#   '향상',
#   '연합',
#   '방위',
#   '태세',
#   '의미',
#   '연습',
#   '변화',
#   '전쟁',
#   '양상',
#   '부합',
#   '실질',
#   '연습',
#   '진행',
#   '국무',
#   '위원',
#   '만전',
#   '당부',
#   '국무',
#   '회의',
#   '주년',
#   '광복절',
#   '독립',
#   '유공자',
#   '훈포장',
#   '수여',
#   '의결',
#   '자유',
#   '독립',
#   '헌신',
#   '무명',
#   '독립',
#   '유공자',
#   '국가',
#   '이름',
#   '기억',
#   '고물가',
#   '부담',
#   '완화',
#   '유류',
#   '인하',
#   '가능',
#   '확대',
#   '근로자',
#   '과세',
#   '한도',
#   '내용',
#   '개별',
#   '소비',
#   '세법',
#   '소득세법',
#   '교통',
#   '에너지',
#   '환경',
#   '세법',
#   '법률',
#   '공포',
#   '안',
#   '의결',
#   '출범',
#   '국회',
#   '민생',
#   '특위',
#   '시작',
#   '본회',
#   '의결',
#   '여야',
#   '처리',
#   '자리',
#   '감사',
#   '미성년자',
#   '대물림',
#   '성년',
#   '미성년자',
#   '한정',
#   '승인',
#   '기회',
#   '부여',
#   '민법',
#   '개정안',
#   '상정',
#   '국가',
#   '사회',
#   '약자',
#   '울타리',
#   '세심',
#   '강조',
#   '집중',
#   '호우',
#   '지속',
#   '예상',
#   '긴장감',
#   '총력',
#   '대응',
#   '부탁',
#   '국민',
#   '안심',
#   '조치',
#   '상황',
#   '현장',
#   '점검',
#   '감사'],
#  ['폭우',
#   '예보',
#   '상황',
#   '중요',
#   '피해',
#   '발생',
#   '내각',
#   '자치',
#   '단체',
#   '적극',
#   '협력',
#   '복구',
#   '상황',
#   '실시간',
#   '확인',
#   '지자체',
#   '필요',
#   '예산',
#   '인력',
#   '신속',
#   '지원',
#   '제도',
#   '당부',
#   '생활',
#   '불편',
#   '자연재해',
#   '취약',
#   '대한민국',
#   '안전',
#   '지자체',
#   '적극',
#   '협력',
#   '폭우',
#   '피해',
#   '취약',
#   '계층',
#   '세심',
#   '이분',
#   '일상',
#   '신속',
#   '회복',
#   '폭우',
#   '기상',
#   '관측',
#   '최대',
#   '폭우',
#   '기상이변',
#   '기상이변',
#   '이변',
#   '최대',
#   '최고',
#   '기록',
#   '과거',
#   '사례',
#   '대응',
#   '예상',
#   '최악',
#   '염두',
#   '대응',
#   '국민',
#   '안전',
#   '국가',
#   '무한',
#   '책임',
#   '공직자',
#   '재난',
#   '극복',
#   '국민',
#   '협조',
#   '중요',
#   '공직자',
#   '긴장',
#   '상황',
#   '예측',
#   '정확',
#   '예상',
#   '근거',
#   '필요',
#   '준비',
#   '만전',
#   '피해',
#   '산발',
#   '특정',
#   '지역',
#   '집중호우',
#   '피해',
#   '예상',
#   '관계',
#   '기관',
#   '긴장',
#   '중앙',
#   '정부',
#   '지자체',
#   '국민',
#   '안전',
#   '최선'],
#  ['기록',
#   '집중호우',
#   '국민',
#   '피해',
#   '현장',
#   '집중호우',
#   '고립',
#   '생명',
#   '사고',
#   '희생자',
#   '명복',
#   '불편',
#   '국민',
#   '정부',
#   '대표',
#   '마음',
#   '하천',
#   '홍수',
#   '도심',
#   '침수',
#   '대응',
#   '기상',
#   '현상',
#   '기상',
#   '계측',
#   '발생',
#   '향후',
#   '현상',
#   '빈발',
#   '근본',
#   '대책',
#   '집중호우',
#   '상황',
#   '응급',
#   '복구',
#   '피해',
#   '지원',
#   '실시간',
#   '상황',
#   '논의',
#   '논의',
#   '기본',
#   '예산',
#   '확보',
#   '준비',
#   '시작',
#   '마음',
#   '자리',
#   '마련',
#   '제도',
#   '신림',
#   '피해',
#   '현장',
#   '저지대',
#   '집중호우',
#   '고지대',
#   '빗물',
#   '지역',
#   '빗물',
#   '하천',
#   '하천',
#   '지류',
#   '수계',
#   '수위',
#   '상승',
#   '저지대',
#   '침수',
#   '지하',
#   '주택',
#   '직접',
#   '피해',
#   '국가',
#   '하천',
#   '수계',
#   '관리',
#   '시스템',
#   '기술',
#   '향상',
#   '첨단',
#   '디지털',
#   '기술',
#   '적극',
#   '활용',
#   '국가',
#   '물길',
#   '수위',
#   '모니터',
#   '시뮬레이션',
#   '경고',
#   '체계',
#   '운영',
#   '필요',
#   '관계',
#   '부처',
#   '지자체',
#   '국가',
#   '하천',
#   '지방',
#   '하천',
#   '본류',
#   '지류',
#   '종합',
#   '물길',
#   '홍수',
#   '경보',
#   '시스템',
#   '구축',
#   '국민',
#   '인명',
#   '재산',
#   '피해',
#   '최소',
#   '전력',
#   '국정',
#   '과제',
#   '추진',
#   '홍수',
#   '예보',
#   '디지털',
#   '트윈',
#   '도심',
#   '침수',
#   '하천',
#   '범람',
#   '지도',
#   '기술',
#   '물',
#   '재해',
#   '예보',
#   '대응',
#   '체계',
#   '오세훈',
#   '시장',
#   '과거',
#   '준비',
#   '행정',
#   '추진',
#   '수조',
#   '수조',
#   '물',
#   '지하',
#   '터널',
#   '광범위',
#   '논의',
#   '종합',
#   '물',
#   '관리',
#   '집중호우',
#   '현상',
#   '재난',
#   '근본',
#   '방',
#   '안',
#   '고견',
#   '당부'],
#  ['비상',
#   '경제',
#   '민생',
#   '회의',
#   '추석',
#   '민생',
#   '대책',
#   '논의',
#   '추석',
#   '명절맞이',
#   '준비',
#   '고물가',
#   '집중호우',
#   '피해',
#   '민생',
#   '기록',
#   '피해',
#   '기록',
#   '피해',
#   '영남',
#   '제외',
#   '지역',
#   '안전',
#   '방역',
#   '피해',
#   '복구',
#   '지원',
#   '명절',
#   '물가',
#   '안정',
#   '취약',
#   '계층',
#   '지원',
#   '점검',
#   '준비',
#   '자리',
#   '마련',
#   '추석',
#   '소외감',
#   '가족',
#   '정부',
#   '최선',
#   '피해',
#   '복구',
#   '지원',
#   '피해',
#   '지역',
#   '피해',
#   '보상',
#   '인명',
#   '피해',
#   '보상',
#   '이재민',
#   '구호',
#   '상공',
#   '지원',
#   '행정력',
#   '동원',
#   '추석',
#   '국민',
#   '추석',
#   '부처',
#   '지자체',
#   '피해',
#   '발생',
#   '재난',
#   '방지',
#   '만전',
#   '신속',
#   '일상',
#   '회복',
#   '복구',
#   '전념',
#   '제도',
#   '말씀',
#   '국민',
#   '안전',
#   '국가',
#   '무한',
#   '책임',
#   '자세',
#   '긴장',
#   '국민',
#   '피부',
#   '명절',
#   '장바구니',
#   '물가',
#   '고물가',
#   '상황',
#   '명절',
#   '기간',
#   '장보기',
#   '부담',
#   '역대',
#   '최대',
#   '규모',
#   '추석',
#   '성수품',
#   '공급',
#   '정부',
#   '할인',
#   '쿠폰',
#   '지원',
#   '호우',
#   '피해',
#   '농산물',
#   '가격',
#   '불안',
#   '발생',
#   '침수',
#   '복구',
#   '지원',
#   '병충해',
#   '예방',
#   '추진',
#   '명절',
#   '취약',
#   '계층',
#   '생활',
#   '안정',
#   '관심',
#   '관계',
#   '부처',
#   '정부',
#   '지원금',
#   '최대한',
#   '신속',
#   '국민',
#   '명절',
#   '세심',
#   '결식아동',
#   '독거',
#   '노인',
#   '장애',
#   '이웃',
#   '무료',
#   '급식',
#   '지원',
#   '도시락',
#   '대체',
#   '수단',
#   '마련',
#   '준비',
#   '당부',
#   '중소기업',
#   '소상인',
#   '명절',
#   '자금',
#   '공급',
#   '근로자',
#   '임금',
#   '지급',
#   '제때',
#   '경제',
#   '단체',
#   '정부',
#   '협력',
#   '임금',
#   '체불',
#   '방지',
#   '하도급',
#   '대금',
#   '조기',
#   '지급',
#   '확산',
#   '안전',
#   '명절',
#   '방역',
#   '의료',
#   '대응',
#   '체계',
#   '마련',
#   '산재',
#   '화재',
#   '전기',
#   '가스',
#   '교통',
#   '분야',
#   '중심',
#   '전면',
#   '특별',
#   '안전',
#   '관리',
#   '실시',
#   '비상',
#   '대응',
#   '체제',
#   '완비',
#   '걱정',
#   '희망',
#   '편안',
#   '추석',
#   '각계',
#   '대표',
#   '참석',
#   '최선',
#   '당부',
#   '감사'],
#  ['임시',
#   '국무',
#   '회의',
#   '시작',
#   '집중호우',
#   '피해',
#   '상황',
#   '점검',
#   '현장',
#   '매진',
#   '국무',
#   '위원',
#   '현장',
#   '필요',
#   '조치',
#   '신속',
#   '당부',
#   '수해',
#   '피해',
#   '국민',
#   '일상',
#   '복귀',
#   '신속',
#   '피해',
#   '지원',
#   '복구',
#   '가용',
#   '자원',
#   '총동원',
#   '재난',
#   '피해',
#   '반복',
#   '재난',
#   '서민',
#   '사회',
#   '약자',
#   '고통',
#   '피해',
#   '국민',
#   '생명',
#   '재산',
#   '국가',
#   '정부',
#   '존재',
#   '국민',
#   '안전',
#   '정부',
#   '무한',
#   '책임',
#   '근본',
#   '기상이변',
#   '집중호우',
#   '대책',
#   '과거',
#   '서울시',
#   '추진',
#   '빗물',
#   '터널',
#   '인프라',
#   '확충',
#   '실행',
#   '안전',
#   '취약',
#   '지역',
#   '철저',
#   '점검',
#   '위험',
#   '선제',
#   '조치',
#   '비극',
#   '되풀이',
#   '임시',
#   '국무',
#   '회의',
#   '광복절',
#   '특별',
#   '사면',
#   '특별',
#   '감형',
#   '특별복',
#   '특별',
#   '감면',
#   '조치',
#   '상정',
#   '사면',
#   '장기간',
#   '지속',
#   '코로나',
#   '서민',
#   '민생',
#   '안정',
#   '중소기업',
#   '인과',
#   '소상',
#   '공인',
#   '서민',
#   '사회',
#   '약자',
#   '재기',
#   '기회',
#   '희망',
#   '사면',
#   '대상',
#   '범위',
#   '경제',
#   '극복',
#   '각계',
#   '의견',
#   '수렴',
#   '신중',
#   '결정',
#   '특별',
#   '사면',
#   '국민',
#   '경제',
#   '위기',
#   '극복',
#   '계기',
#   '정부',
#   '경제',
#   '위기',
#   '극복',
#   '공공',
#   '부문',
#   '긴축',
#   '지출',
#   '구조',
#   '조정',
#   '재정',
#   '여력',
#   '사회',
#   '약자',
#   '지원'],
#  ['존경',
#   '국민',
#   '조국',
#   '독립',
#   '헌신',
#   '독립',
#   '유공자',
#   '사랑',
#   '가족',
#   '나라',
#   '유가족',
#   '광복',
#   '주년',
#   '오늘날',
#   '자유',
#   '일제',
#   '강점기',
#   '암울',
#   '현실',
#   '절망',
#   '자유',
#   '조국',
#   '독립',
#   '목숨',
#   '초개',
#   '희생',
#   '수유리',
#   '광복군',
#   '합동',
#   '묘소',
#   '나이',
#   '중국',
#   '지역',
#   '일제',
#   '항거',
#   '전사',
#   '옥중',
#   '순국',
#   '포함',
#   '선열',
#   '광복군',
#   '지대',
#   '김유신',
#   '김찬',
#   '백정현',
#   '이해순',
#   '방석',
#   '이도순',
#   '김성률',
#   '문학',
#   '일용',
#   '전일',
#   '정상섭',
#   '지사',
#   '한국광복군',
#   '지대',
#   '김순근',
#   '이한기',
#   '조대',
#   '지사',
#   '청년',
#   '전지',
#   '공작대',
#   '활동',
#   '순국',
#   '이평',
#   '지사',
#   '선열',
#   '영전',
#   '명복',
#   '일본',
#   '헌병',
#   '체포',
#   '탈출',
#   '시도',
#   '순국',
#   '백정현',
#   '지사',
#   '일경',
#   '일본',
#   '경찰',
#   '체포',
#   '잔혹',
#   '고문',
#   '군사',
#   '기밀',
#   '누설',
#   '나이',
#   '옥중',
#   '자결',
#   '선택',
#   '김순근',
#   '지사',
#   '광복',
#   '귀국',
#   '호림',
#   '부대',
#   '입대',
#   '자유민주주의',
#   '수호',
#   '대북',
#   '작전',
#   '수행',
#   '전사',
#   '이한기',
#   '지사',
#   '조국',
#   '독립',
#   '이름',
#   '영웅',
#   '기억',
#   '지사',
#   '공적',
#   '정부',
#   '발굴',
#   '건국훈장',
#   '수여',
#   '광복',
#   '선열',
#   '국립',
#   '묘지',
#   '정부',
#   '국가',
#   '국민',
#   '희생',
#   '헌신',
#   '책임',
#   '예우',
#   '소홀',
#   '무명',
#   '희생',
#   '헌신',
#   '국가',
#   '이름',
#   '기억',
#   '선열',
#   '영원',
#   '안식',
#   '기원',
#   '감사'],
#  ['존경',
#   '사랑',
#   '국민',
#   '재외',
#   '동포',
#   '주년',
#   '광복절',
#   '조국',
#   '독립',
#   '희생',
#   '헌신',
#   '순국선열',
#   '애국지사',
#   '유가족',
#   '감사',
#   '경의',
#   '일제',
#   '강점기',
#   '시절',
#   '독립운동',
#   '독립선언',
#   '임시',
#   '정부',
#   '헌장',
#   '윤봉길',
#   '선생',
#   '독립',
#   '정신',
#   '국민',
#   '주인',
#   '민주',
#   '공화국',
#   '자유',
#   '인권',
#   '법치',
#   '존중',
#   '나라',
#   '자유',
#   '인권',
#   '무시',
#   '전체주의',
#   '국가',
#   '독립운동',
#   '일제',
#   '강점기',
#   '시절',
#   '순국선열',
#   '애국지사',
#   '국민',
#   '독립운동',
#   '광복',
#   '결실',
#   '독립운동',
#   '공산',
#   '세력',
#   '자유',
#   '국가',
#   '건국',
#   '과정',
#   '자유민주주의',
#   '토대',
#   '경제성장',
#   '산업',
#   '과정',
#   '바탕',
#   '민주주의',
#   '발전',
#   '과정',
#   '진행',
#   '과거',
#   '약소국',
#   '강대국',
#   '억압',
#   '박탈',
#   '국민',
#   '자유',
#   '주권',
# ...
#   '노사',
#   '문화',
#   '정착',
#   '개혁',
#   '안',
#   '논의',
#   '미래',
#   '노동',
#   '시장',
#   '연구회',
#   '노동',
#   '시장',
#   '개혁',
#   '권고',
#   '안',
#   '제안',
#   '근로',
#   '제도',
#   '탄력',
#   '임금',
#   '체계',
#   '직무',
#   '중심',
#   '개편',
#   '한편',
#   '미만',
#   '사업',
#   '근로',
#   '기준',
#   '적용',
#   '문제',
#   '취약',
#   '계층',
#   '보호',
#   '방안',
#   '포함',
#   '권고',
#   '내용',
#   '토대',
#   '정부',
#   '입장',
#   '정리',
#   '사회',
#   '노동',
#   '약자',
#   '보호',
#   '개혁',
#   '추진',
#   '국회',
#   '내년도',
#   '예산안',
#   '논의',
#   '정부',
#   '예산안',
#   '법정',
#   '기한',
#   '열흘',
#   '마음',
#   '정부',
#   '고물가',
#   '고금리',
#   '고환',
#   '중고',
#   '경제',
#   '위기',
#   '극복',
#   '역대',
#   '최대',
#   '규모',
#   '지출',
#   '구조',
#   '조정',
#   '단행',
#   '건전',
#   '재정',
#   '전환',
#   '절감',
#   '재원',
#   '철저',
#   '서민',
#   '사회',
#   '약자',
#   '지원',
#   '경제',
#   '회복',
#   '초점',
#   '예산',
#   '편성',
#   '예산',
#   '부수',
#   '법안',
#   '지정',
#   '세제',
#   '개편',
#   '안',
#   '국익',
#   '민생',
#   '사활',
#   '이익',
#   '세제',
#   '개편',
#   '국민',
#   '과도',
#   '세부',
#   '정상',
#   '법인세',
#   '인하',
#   '기업',
#   '투자',
#   '일자리',
#   '경제',
#   '활력',
#   '제고',
#   '초당',
#   '협력',
#   '부처',
#   '예산안',
#   '국회',
#   '통과',
#   '내년',
#   '상반기',
#   '조기',
#   '집행',
#   '집행',
#   '준비',
#   '만전',
#   '정부',
#   '목요일',
#   '건강',
#   '보험',
#   '개편',
#   '국민',
#   '건강',
#   '최후',
#   '보루',
#   '건강',
#   '보험',
#   '정상',
#   '보장',
#   '강화',
#   '정부',
#   '의료',
#   '남용',
#   '건강',
#   '보험',
#   '무임승차',
#   '방치',
#   '대다수',
#   '국민',
#   '부담',
#   '전가',
#   '국민',
#   '혈세',
#   '낭비',
#   '인기',
#   '영합',
#   '포퓰리즘',
#   '정책',
#   '재정',
#   '파탄',
#   '건강',
#   '보험',
#   '제도',
#   '근간',
#   '국민',
#   '희생',
#   '강요',
#   '건강',
#   '보험',
#   '개혁',
#   '선택',
#   '필수',
#   '건강',
#   '보험',
#   '급여',
#   '자격',
#   '기준',
#   '강화',
#   '건강',
#   '보험',
#   '낭비',
#   '누수',
#   '방지',
#   '절감',
#   '재원',
#   '의료',
#   '사각지대',
#   '고통',
#   '지원',
#   '중증',
#   '질환',
#   '비용',
#   '필수',
#   '의료',
#   '보장',
#   '건강',
#   '보험',
#   '제도',
#   '요체',
#   '건강',
#   '보험',
#   '지속',
#   '가능',
#   '재고',
#   '중증',
#   '질환',
#   '치료',
#   '필수',
#   '의료',
#   '강화',
#   '국무',
#   '위원',
#   '긴장',
#   '경제',
#   '민생',
#   '전념',
#   '당부',
#   '대외',
#   '의존도',
#   '경제',
#   '성장',
#   '지속',
#   '가능',
#   '수출',
#   '드라이브',
#   '만전',
#   '국민',
#   '국정',
#   '과제',
#   '추진',
#   '상황',
#   '점검',
#   '자리',
#   '국민',
#   '국정',
#   '과제',
#   '추진',
#   '상황',
#   '국민',
#   '목소리',
#   '경청',
#   '향후',
#   '국정',
#   '운영',
#   '반영',
#   '집무실',
#   '정부',
#   '국정',
#   '과제',
#   '보드',
#   '규범',
#   '정책',
#   '방향',
#   '염두',
#   '국정',
#   '반영',
#   '국무',
#   '위원',
#   '국정',
#   '과제',
#   '책자',
#   '완벽',
#   '핵심',
#   '국정',
#   '과제',
#   '이행',
#   '상황',
#   '점검',
#   '정부',
#   '국민',
#   '약속',
#   '최선',
#   '감사'],
#  ['존경',
#   '울진군',
#   '경북',
#   '도민',
#   '내외',
#   '귀빈',
#   '세계',
#   '최고',
#   '경쟁력',
#   '원전',
#   '산업',
#   '생태',
#   '심정',
#   '작년',
#   '마음',
#   '한울',
#   '호기',
#   '준공',
#   '기념',
#   '원전',
#   '건설',
#   '원전',
#   '산업',
#   '근로자',
#   '준공',
#   '협조',
#   '지역',
#   '주민',
#   '감사',
#   '노력',
#   '무분별',
#   '원전',
#   '정책',
#   '에너지',
#   '위기',
#   '시대',
#   '경제',
#   '수습',
#   '상황',
#   '포기',
#   '원전',
#   '산업',
#   '생태',
#   '구축',
#   '노력',
#   '노고',
#   '감사',
#   '원자력',
#   '도전',
#   '성취',
#   '여정',
#   '원자력',
#   '불모지',
#   '우리나라',
#   '세계',
#   '최고',
#   '수준',
#   '기술력',
#   '경쟁력',
#   '자랑',
#   '사막',
#   '원전',
#   '성공',
#   '건설',
#   '원자력',
#   '강국',
#   '자리매김',
#   '한울',
#   '호기',
#   '나라',
#   '독자',
#   '노형',
#   '계측',
#   '설비',
#   '주요',
#   '기자재',
#   '핵심',
#   '기술',
#   '국산화',
#   '최초',
#   '원전',
#   '각국',
#   '정상',
#   '브로슈어',
#   '원전',
#   '시공',
#   '신속',
#   '건설',
#   '비용',
#   '합리',
#   '원전',
#   '안전',
#   '자랑',
#   '자랑',
#   '세계',
#   '최고',
#   '원전',
#   '해외',
#   '수출',
#   '대표',
#   '참조',
#   '원전',
#   '원전',
#   '기술',
#   '우수',
#   '안전성',
#   '세계',
#   '증명',
#   '연간',
#   '수입',
#   '대체',
#   '에너지',
#   '수입',
#   '감소',
#   '전력',
#   '수급',
#   '안정',
#   '무역',
#   '적자',
#   '개선',
#   '기여',
#   '규모',
#   '이집트',
#   '원전',
#   '건설',
#   '프로젝트',
#   '수주',
#   '폴란드',
#   '신규',
#   '원전',
#   '건설',
#   '협력',
#   '정부',
#   '출범',
#   '의미',
#   '성과',
#   '원전',
#   '산업',
#   '도약',
#   '원년',
#   '기억',
#   '정부',
#   '원전',
#   '산업',
#   '수출',
#   '버팀목',
#   '대한민국',
#   '세계',
#   '원전',
#   '강국',
#   '위상',
#   '적극',
#   '지원',
#   '정부',
#   '출범',
#   '합리',
#   '에너지',
#   '정책',
#   '수립',
#   '정권',
#   '무리',
#   '추진',
#   '원전',
#   '정책',
#   '폐기',
#   '원전',
#   '정책',
#   '정상',
#   '원전',
#   '생태',
#   '복원',
#   '박차',
#   '정부',
#   '어려움',
#   '원전',
#   '업계',
#   '일감',
#   '금융',
#   '긴급',
#   '지원',
#   '내년',
#   '규모',
#   '확대',
#   '천억',
#   '규모',
#   '한울',
#   '호기',
#   '건설',
#   '계약',
#   '체결',
#   '내년',
#   '상반기',
#   '원전',
#   '건설',
#   '시장',
#   '활기',
#   '나라',
#   '독자',
#   '소형모듈원전',
#   '천억',
#   '투자',
#   '미래',
#   '원전',
#   '시장',
#   '주도',
#   '확보',
#   '울진',
#   '한울',
#   '호기',
#   '건설',
#   '본격',
#   '개시',
#   '에너지',
#   '안보',
#   '강화',
#   '탄소',
#   '중립',
#   '달성',
#   '수단',
#   '원전',
#   '적극',
#   '활용',
#   '운영',
#   '허가',
#   '만료',
#   '원전',
#   '운전',
#   '안전',
#   '확보',
#   '전제',
#   '속도',
#   '진행',
#   '원전',
#   '발생',
#   '고준',
#   '방폐',
#   '물',
#   '특별법',
#   '제정',
#   '핵심',
#   '기술',
#   '확보',
#   '관리',
#   '원전',
#   '건설',
#   '운영',
#   '과정',
#   '안전',
#   '최우선',
#   '추진',
#   '내외',
#   '귀빈',
#   '한울',
#   '호기',
#   '준공',
#   '시작',
#   '원전',
#   '원전',
#   '산업',
#   '활력',
#   '도약',
#   '정부',
#   '우수',
#   '원전',
#   '기술',
#   '경험',
#   '세계',
#   '뒷받침',
#   '한울',
#   '호기',
#   '준공',
#   '축하',
#   '준공',
#   '기여',
#   '박수',
#   '원전',
#   '건설',
#   '운영',
#   '울진',
#   '지역',
#   '주민',
#   '감사',
#   '말씀',
#   '감사'],
#  ['비상',
#   '경제',
#   '민생',
#   '회의',
#   '국민',
#   '경제',
#   '자문',
#   '회의',
#   '기재',
#   '경제',
#   '정책',
#   '업무',
#   '보고',
#   '진행',
#   '기재',
#   '경제',
#   '정책',
#   '보고',
#   '국민',
#   '경제',
#   '자문',
#   '회의',
#   '위원',
#   '질의',
#   '전문가',
#   '검증',
#   '진행',
#   '금융',
#   '위기',
#   '코로나',
#   '대응',
#   '세계',
#   '통화량',
#   '각국',
#   '정부',
#   '확장',
#   '재정',
#   '정책',
#   '코로나',
#   '물가',
#   '우크라',
#   '전쟁',
#   '공급',
#   '교란',
#   '무역',
#   '보호주의',
#   '강화',
#   '체제',
#   '이완',
#   '상태',
#   '원자재',
#   '가격',
#   '상승',
#   '코스트푸시',
#   '인플레이션',
#   '조짐',
#   '세계',
#   '미국',
#   '연준',
#   '고금리',
#   '정책',
#   '고금리',
#   '정책',
#   '통화',
#   '긴축',
#   '기업',
#   '소비',
#   '위축',
#   '상황',
#   '경제',
#   '실시간',
#   '현안',
#   '대응',
#   '환율',
#   '물가',
#   '관리',
#   '평가',
#   '내년',
#   '유의',
#   '중요',
#   '고금리',
#   '부동산',
#   '자산',
#   '가치',
#   '하락',
#   '가계',
#   '기업',
#   '부채',
#   '문제',
#   '가계',
#   '기업',
#   '부실',
#   '금융',
#   '사이드',
#   '부실',
#   '확대',
#   '관리',
#   '지적',
#   '산업',
#   '복합',
#   '위기',
#   '차례',
#   '얘기',
#   '수출',
#   '돌파',
#   '원자재',
#   '가격',
#   '상승',
#   '나라',
#   '경제',
#   '자원',
#   '부국',
#   '신흥',
#   '시장',
#   '성장',
#   '나라',
#   '교역',
#   '경제',
#   '협력',
#   '인프라',
#   '수주',
#   '경제',
#   '활로',
#   '적극',
#   '모색',
#   '경제',
#   '집안',
#   '미래',
#   '전략',
#   '산업',
#   '투자',
#   '지원',
#   '우주',
#   '항공',
#   '인공지능',
#   '핵심',
#   '전략',
#   '기술',
#   '미래',
#   '기술',
#   '시장',
#   '선점',
#   '국가',
#   '정책',
#   '지원',
#   '산업',
#   '디지털',
#   '혁신',
#   '가속',
#   '법인세',
#   '인하',
#   '투자',
#   '증액',
#   '세액',
#   '공제',
#   '인센티브',
#   '작동',
#   '경제',
#   '서민',
#   '기재',
#   '부가',
#   '중심',
#   '물가',
#   '상황',
#   '점검',
#   '장바구니',
#   '물가',
#   '가계',
#   '어려움',
#   '가계',
#   '지출',
#   '중요',
#   '주거비',
#   '지출',
#   '과거',
#   '이념',
#   '부동산',
#   '문제',
#   '가구',
#   '주택',
#   '과세',
#   '윤리',
#   '세계',
#   '고금리',
#   '상황',
#   '부동산',
#   '자산',
#   '가치',
#   '하락',
#   '임대',
#   '선호',
#   '임대',
#   '선호',
#   '임대',
#   '물량',
#   '주택',
#   '주택',
#   '임대',
#   '물량',
#   '주택',
#   '과세',
#   '임차인',
#   '조세',
#   '전가',
#   '국민',
#   '주거비',
#   '부담',
#   '현실',
#   '차원',
#   '주택',
#   '조세',
#   '부담',
#   '완화',
#   '국민',
#   '주거비',
#   '부담',
#   '경감',
#   '내년',
#   '적극',
#   '세제',
#   '감면',
#   '추진',
#   '물가',
#   '문제',
#   '기재',
#   '시장',
#   '경제',
#   '논리',
#   '공급',
#   '사이드',
#   '비용',
#   '방식',
#   '관세',
#   '인하',
#   '유류',
#   '인하',
#   '지방세',
#   '감면',
#   '방식',
#   '공공요금',
#   '관리',
#   '시장',
#   '논리',
#   '물가',
#   '관리',
#   '내년',
#   '지속',
#   '정부',
#   '출범',
#   '세계',
#   '경제',
#   '위기',
#   '파도',
#   '극복',
#   '긴급',
#   '현안',
#   '대응',
#   '위주',
#   '금년도',
#   '정책',
#   '실행',
#   '성장',
#   '발전',
#   '잘못',
#   '제도',
#   '적폐',
#   '청산',
#   '제도',
#   '개선',
#   '개혁',
#   '가동',
#   '말씀',
#   '노동',
#   '개혁',
#   '교육',
#   '개혁',
#   '연금',
#   '개혁',
#   '인기',
#   '국가',
#   '미래',
#   '미래',
#   '세대',
#   '개혁',
#   '적극',
#   '추진',
#   '개혁',
#   '추진',
#   '원년',
#   '주무',
#   '부처',
#   '중심',
#   '필요',
#   '개혁',
#   '내용',
#   '선별',
#   '국민',
#   '논의',
#   '공론화',
#   '사회',
#   '대합',
#   '개혁',
#   '신속',
#   '추진',
#   '노동',
#   '개혁',
#   '노동시장',
#   '이중',
#   '구조',
#   '개선',
#   '합리',
#   '보상',
#   '체계',
#   '노노',
#   '착취',
#   '시스템',
#   '노동',
#   '가치',
#   '존중',
#   '이중',
#   '구조',
#   '양극',
#   '심화',
#   '사이',
#   '자본',
#   '노동',
#   '사이',
#   '논의',
#   '착취',
#   '구조',
#   '존재',
#   '노동',
#   '가치',
#   '노동',
#   '가치',
#   '무시',
#   '이중',
#   '구조',
#   '개선',
#   '측면',
#   '노동',
#   '개혁',
#   '공정성',
#   '중요',
#   '산업',
#   '구조',
#   '노동',
#   '수요',
#   '기반',
#   '변화',
#   '노동',
#   '제도',
#   '노사',
#   '관계',
#   '노사',
#   '법치주의',
#   '나라',
#   '성장',
#   '과제',
#   '사법부',
#   '보수',
#   '얘기',
#   '집행',
#   '분쟁',
#   '해결',
#   '기관',
#   '처리',
#   '법관',
#   '세계관',
#   '판결',
#   '송사',
#   '사법부',
#   '법관',
#   '개개인',
#   '세계관',
#   '지양',
#   '대법원',
#   '판례',
#   '판결',
#   '권장',
#   '송사',
#   '사회',
#   '비용',
#   '노사',
#   '관계',
#   '효율',
#   '분쟁',
#   '비용',
#   '노동자',
#   '복지',
#   '노사',
#   '법치주의',
#   '정립',
#   '필요',
#   '쟁의',
#   '갈등',
#   '국가',
#   '리드',
#   '부패',
#   '공직',
#   '부패',
#   '민간',
#   '기업',
#   '부패',
#   '상정',
#   '노사',
#   '관계',
#   '노조',
#   '부패',
#   '사회',
#   '국민',
#   '관심',
#   '노사',
#   '법치주의',
#   '확립',
#   '노동',
#   '노동',
#   '개혁',
#   '노조',
#   '부패',
#   '공직',
#   '부패',
#   '기업',
#   '부패',
#   '사회',
#   '척결',
#   '부패',
#   '집행',
#   '차원',
#   '기업',
#   '부패',
#   '기업',
#   '회계',
#   '투명',
#   '어려움',
#   '회계',
#   '투명',
#   '강화',
#   '과정',
#   '기업',
#   '세계',
#   '기업',
#   '노동',
#   '운동',
#   '노조',
#   '활동',
#   '투명',
#   '회계',
#   '건강',
#   '발전',
#   '필요',
#   '제도',
#   '개혁',
#   '성장',
#   '원동력',
#   '정책',
#   '기재',
#   '업무',
#   '보고',
#   '각계',
#   '전문',
#   '가분',
#   '조언',
#   '점검',
#   '당부',
#   '감사'],
#  ['자리',
#   '국민',
#   '통합',
#   '위원회',
#   '출범식',
#   '새해',
#   '김한길',
#   '위원장',
#   '정부',
#   '청사',
#   '회의',
#   '국민',
#   '통합',
#   '방안',
#   '연구',
#   '결과',
#   '자리',
#   '장관',
#   '공유',
#   '출범',
#   '노고',
#   '감사',
#   '법학',
#   '공부',
#   '국민',
#   '통합',
#   '기제',
#   '헌법',
#   '헌법',
#   '국민',
#   '동화',
#   '통합',
#   '과정',
#   '기제',
#   '헌법',
#   '가치',
#   '가치',
#   '지향',
#   '통합',
#   '과정',
#   '나라',
#   '헌법',
#   '자유민주주의',
#   '자유',
#   '삭제',
#   '주장',
#   '규모',
#   '의견',
#   '세력',
#   '존재',
#   '안정',
#   '통합',
#   '국가',
#   '정부',
#   '비약',
#   '성장',
#   '경제',
#   '도약',
#   '과정',
#   '통합',
#   '사회',
#   '갈등',
#   '분열',
#   '복지',
#   '생산',
#   '가치',
#   '분열',
#   '갈등',
#   '싸움',
#   '소모',
#   '사회',
#   '낭비',
#   '미래',
#   '세대',
#   '소위',
#   '싸움',
#   '무기',
#   '소진',
#   '사회',
#   '갈등',
#   '분열',
#   '국민',
#   '통합',
#   '국가',
#   '발전',
#   '위기',
#   '극복',
#   '중요',
#   '관점',
#   '노고',
#   '감사',
#   '새해',
#   '감사'],
#  ['내년도',
#   '산업',
#   '정책',
#   '산업',
#   '통상',
#   '자원',
#   '중소',
#   '벤처',
#   '기업',
#   '합동',
#   '업무',
#   '보고',
#   '대통령',
#   '보고',
#   '자리',
#   '국민',
#   '정부',
#   '내년',
#   '산업',
#   '기업',
#   '정책',
#   '방향',
#   '운영',
#   '설명',
#   '자리',
#   '단체',
#   '민간',
#   '전문가',
#   '국민',
#   '입장',
#   '의견',
#   '질문',
#   '내용',
#   '업무',
#   '과정',
#   '내년',
#   '산업',
#   '정책',
#   '중요',
#   '기본',
#   '기업',
#   '중소기업',
#   '상생',
#   '발전',
#   '산업',
#   '중기',
#   '내년도',
#   '업무',
#   '보고',
#   '자리',
#   '기업',
#   '상생',
#   '부처',
#   '유대',
#   '협력',
#   '소통',
#   '바탕',
#   '산업',
#   '중기',
#   '부가',
#   '내년',
#   '업무',
#   '협조',
#   '당부',
#   '국제',
#   '상황',
#   '과거',
#   '체제',
#   '자유',
#   '무역',
#   '질서',
#   '고부',
#   '가치',
#   '산업',
#   '첨단',
#   '기술',
#   '의존',
#   '첨단',
#   '기술',
#   '국가',
#   '블록',
#   '공급',
#   '재편',
#   '국가',
#   '안보',
#   '문제',
#   '나라',
#   '정치',
#   '사회',
#   '가치',
#   '국제',
#   '사회',
#   '공공',
#   '아젠다',
#   '나라',
#   '관심',
#   '기여',
#   '책임',
#   '국가',
#   '블록화',
#   '소위',
#   '패키지',
#   '통상',
#   '무역',
#   '문제',
#   '과거',
#   '정부',
#   '민간',
#   '기업',
#   '해외',
#   '진출',
#   '경제',
#   '위기',
#   '돌파',
#   '중요',
#   '수출',
#   '증진',
#   '산업',
#   '필수',
#   '원자재',
#   '조달',
#   '영역',
#   '정부',
#   '민간',
#   '관료주의',
#   '사고',
#   '기업',
#   '중심',
#   '국민',
#   '중심',
#   '정부',
#   '변모',
#   '상황',
#   '대응',
#   '중소',
#   '처부',
#   '중소',
#   '상공',
#   '소상인',
#   '지원',
#   '해결',
#   '중요',
#   '내년도',
#   '경제',
#   '위기',
#   '돌파',
#   '트랙',
#   '수출',
#   '증진',
#   '스타트업',
#   '코리아',
#   '기치',
#   '기술',
#   '기업',
#   '스타트업',
#   '세계',
#   '기업',
#   '모습',
#   '기술',
#   '투자',
#   '시장',
#   '기대',
#   '소위',
#   '경제',
#   '센티멘탈',
#   '센티',
#   '얘기',
#   '경기',
#   '활성',
#   '도움',
#   '기업',
#   '과정',
#   '양질',
#   '일자리',
#   '중소',
#   '내년도',
#   '스타트업',
#   '코리아',
#   '기치',
#   '실현',
#   '당부',
#   '얘기',
#   '장관',
#   '보고',
#   '단체',
#   '전문',
#   '가분',
#   '응답',
#   '과정',
#   '국민',
#   '감사'],
#  ['과기부',
#   '개인',
#   '정보',
#   '원안',
#   '업무',
#   '보고',
#   '준비',
#   '말씀',
#   '산업',
#   '중기',
#   '산업',
#   '과학',
#   '기술',
#   '기반',
#   '경제',
#   '가치',
#   '창출',
#   '근본',
#   '경제',
#   '가치',
#   '개연',
#   '과학',
#   '기술',
#   '미래',
#   '전략',
#   '기술',
#   '정부',
#   '국민',
#   '과학',
#   '교육',
#   '과학',
#   '인재',
#   '양성',
#   '국가',
#   '미래',
#   '역할',
#   '개인',
#   '정보',
#   '데이터',
#   '경제',
#   '활성',
#   '개인',
#   '프라이버시',
#   '보호',
#   '데이터',
#   '권리',
#   '경제',
#   '발전',
#   '활용',
#   '화두',
#   '원안',
#   '원자력',
#   '중요',
#   '화석',
#   '연료',
#   '탄소',
#   '중립',
#   '우크라',
#   '전쟁',
#   '화석',
#   '연료',
#   '공급',
#   '차질',
#   '가격',
#   '원자력',
#   '활용',
#   '기본',
#   '방사능',
#   '국민',
#   '원자력',
#   '에너지',
#   '활용',
#   '방',
#   '안',
#   '경제',
#   '유익',
#   '의미',
#   '국민',
#   '보고',
#   '의견',
#   '개진',
#   '가급적',
#   '국민',
#   '눈높이',
#   '정책',
#   '방향',
#   '업무',
#   '보고',
#   '전문',
#   '가분',
#   '의견',
#   '개진',
#   '감사'],
#  ['국방',
#   '전력',
#   '자산',
#   '운용',
#   '중요',
#   '전력',
#   '체계',
#   '구축',
#   '연구',
#   '대한민국',
#   '국방',
#   '뒷받침',
#   '감사',
#   '경의',
#   '북한',
#   '무인기',
#   '영공',
#   '침범',
#   '용납',
#   '사건',
#   '발생',
#   '국민',
#   '걱정',
#   '우려',
#   '북한',
#   '도발',
#   '대가',
#   '자유',
#   '평화',
#   '사랑',
#   '존중',
#   '국가',
#   '침략',
#   '전쟁',
#   '거부',
#   '자유',
#   '자위',
#   '행사',
#   '자유',
#   '침범',
#   '행위',
#   '응징',
#   '보복',
#   '자유',
#   '공격',
#   '도발',
#   '억제',
#   '대량',
#   '살상',
#   '무기',
#   '도발',
#   '메시지',
#   '주저',
#   '북한',
#   '대량',
#   '살상',
#   '무기',
#   '전념',
#   '소형',
#   '무인기',
#   '비대칭',
#   '전력',
#   '집중',
#   '무인기',
#   '운영',
#   '소형',
#   '무인기',
#   '대응',
#   '곤란',
#   '방식',
#   '자유',
#   '침범',
#   '사회',
#   '교란',
#   '북한',
#   '무인기',
#   '대응',
#   '체계',
#   '무인기',
#   '영공',
#   '침범',
#   '비행',
#   '물체',
#   '대응',
#   '체계',
#   '검토',
#   '미비점',
#   '신속',
#   '보완',
#   '우크라',
#   '전쟁',
#   '비대칭',
#   '전력',
#   '전쟁',
#   '중요',
#   '요소',
#   '비대칭',
#   '전력',
#   '강화',
#   '북한',
#   '대응',
#   '기존',
#   '전력',
#   '증강',
#   '계획',
#   '검토',
#   '필요',
#   '내년도',
#   '예산안',
#   '체계',
#   '전력',
#   '포함',
#   '방위력',
#   '개선',
#   '예산',
#   '반영',
#   '근거리',
#   '정찰',
#   '드론',
#   '해안',
#   '정찰',
#   '무인기',
#   '북한',
#   '무인기',
#   '대응',
#   '전력',
#   '확보',
#   '예산',
#   '감액',
#   '안보',
#   '현실',
#   '결과',
#   '필요',
#   '비대칭',
#   '전력',
#   '조기',
#   '확보',
#   '각고',
#   '노력',
#   '당부',
#   '안보',
#   '상황',
#   '국군',
#   '통수',
#   '용기',
#   '결기',
#   '충만',
#   '군대',
#   '범접',
#   '두려움',
#   '국민',
#   '믿음',
#   '강군',
#   '전력',
#   '체계',
#   '국민',
#   '안전',
#   '불법',
#   '전쟁',
#   '대비',
#   '전쟁',
#   '준비',
#   '전쟁',
#   '전쟁',
#   '대비',
#   '평화',
#   '압도',
#   '우월',
#   '전쟁',
#   '준비',
#   '위장',
#   '평화',
#   '평화',
#   '안보',
#   '기반'],
#  ['존경',
#   '사랑',
#   '국민',
#   '해외',
#   '동포',
#   '새해',
#   '새해',
#   '지난해',
#   '세계',
#   '경제',
#   '복합',
#   '위기',
#   '나라',
#   '안팎',
#   '국민',
#   '의지',
#   '극복',
#   '글로벌',
#   '공급',
#   '교란',
#   '원자재',
#   '가격',
#   '급등',
#   '물가',
#   '상승',
#   '세계',
#   '각국',
#   '금리',
#   '인상',
#   '정책',
#   '대응',
#   '세계',
#   '경제',
#   '경기',
#   '침체',
#   '가능',
#   '세계',
#   '경기',
#   '침체',
#   '여파',
#   '실물',
#   '경제',
#   '둔화',
#   '경제',
#   '상황',
#   '점검',
#   '물가',
#   '상승',
#   '억제',
#   '실시',
#   '금리',
#   '인상',
#   '조치',
#   '가계',
#   '기업',
#   '과도',
#   '부담',
#   '확대',
#   '선제',
#   '관리',
#   '복합',
#   '위기',
#   '수출',
#   '돌파',
#   '수출',
#   '경제',
#   '근간',
#   '일자리',
#   '원천',
#   '체제',
#   '약화',
#   '보호주의',
#   '강화',
#   '과정',
#   '안보',
#   '경제',
#   '기술',
#   '협력',
#   '패키지',
#   '운영',
#   '수출',
#   '전략',
#   '과거',
#   '자유',
#   '인권',
#   '법치',
#   '보편',
#   '가치',
#   '공유',
#   '나라',
#   '경제',
#   '산업',
#   '연대',
#   '보편',
#   '가치',
#   '기반',
#   '연대',
#   '외교',
#   '현실',
#   '전략',
#   '선택',
#   '외교',
#   '중심',
#   '경제',
#   '수출',
#   '전략',
#   '해외',
#   '수주',
#   '프로젝트',
#   '가동',
#   '인프라',
#   '건설',
#   '원전',
#   '방산',
#   '분야',
#   '수출',
#   '동력',
#   '육성',
#   '무역',
#   '금융',
#   '역대',
#   '최대',
#   '규모',
#   '확대',
#   '대한민국',
#   '수출',
#   '영토',
#   '세계',
#   '확대',
#   '정책',
#   '역량',
#   '총동원',
#   '세계사',
#   '위기',
#   '도전',
#   '세계',
#   '경제',
#   '혁신',
#   '기술',
#   '산업',
#   '발굴',
#   '나라',
#   '양질',
#   '일자리',
#   '창출',
#   '지속',
#   '가능',
#   '성장',
#   '기업가',
#   '정신',
#   '미래',
#   '세대',
#   '기술',
#   '산업',
#   '도전',
#   '도전',
#   '지원',
#   '바이오산업',
#   '방산',
#   '원자력',
#   '탄소',
#   '중립',
#   '엔터',
#   '스타트업',
#   '코리아',
#   '시대',
#   '미래',
#   '전략',
#   '기술',
#   '투자',
#   '선제',
#   '리호',
#   '발사',
#   '성공',
#   '시작',
#   '미래',
#   '세대',
#   '무한',
#   '기회',
#   '우주',
#   '경제',
#   '시대',
#   '재정',
#   '여건',
#   '정부',
#   '투자',
#   '시대',
#   '미래',
#   '전략',
#   '기술',
#   '산업',
#   '경쟁력',
#   '우주',
#   '항공',
#   '인공지능',
#   '첨단',
#   '바이오',
#   '핵심',
#   '전략',
#   '기술',
#   '미래',
#   '기술',
#   '시장',
#   '선점',
#   '지원',
#   '소홀',
#   '존경',
#   '국민',
#   '유지',
#   '지대',
#   '추구',
#   '매몰',
#   '나라',
#   '미래',
#   '대한민국',
#   '미래',
#   '미래',
#   '세대',
#   '운명',
#   '노동',
#   '교육',
#   '연금',
#   '개혁',
#   '노동',
#   '개혁',
#   '경제',
#   '성장',
#   '견인',
#   '변화',
#   '수요',
#   '노동',
#   '시장',
#   '노사',
#   '노노',
#   '관계',
#   '공정',
#   '확립',
#   '근로',
#   '현장',
#   '안전',
#   '개선',
#   '노력',
#   '노동',
#   '시장',
#   '이중',
#   '구조',
#   '개선',
#   '직무',
#   '중심',
#   '성과급',
#   '중심',
#   '전환',
#   '추진',
#   '기업',
#   '귀족',
#   '강성',
#   '노조',
#   '타협',
#   '연공',
#   '서열',
#   '시스템',
#   '매몰',
#   '기업',
#   '정부',
#   '지원',
#   '차별',
#   '노동',
#   '개혁',
#   '출발점',
#   '노사',
#   '법치주의',
#   '노사',
#   '법치주의',
#   '필요',
#   '쟁의',
#   '갈등',
#   '예방',
#   '진정',
#   '노동',
#   '가치',
#   '존중',
#   '세계',
#   '각국',
#   '변화',
#   '기술',
#   '폭발',
#   '인력',
#   '수요',
#   '대응',
#   '교육',
#   '개혁',
#   '사활',
#   '나라',
#   '경쟁력',
#   '직결',
#   '고등',
#   '교육',
#   '권한',
#   '지역',
#   '지역',
#   '산업',
#   '연계',
#   '지원',
#   '교육',
#   '개혁',
#   '지역',
#   '균형발전',
#   '지역',
#   '균형발전',
#   '저출산',
#   '문제',
#   '해결',
#   '지름길',
#   '미래',
#   '세대',
#   '교육',
#   '교육',
#   '과정',
#   '다양',
#   '공정',
#   '기회',
#   '연금',
#   '개혁',
#   '중요',
#   '눈덩이',
#   '연금',
#   '재정',
#   '적자',
#   '해결',
#   '연금',
#   '제도',
#   '지속',
#   '가능',
#   '장담',
#   '연금',
#   '개혁',
#   '성공',
#   '나라',
#   '공통점',
#   '사회',
#   '합의',
#   '목표',
#   '연구',
#   '논의',
#   '결론',
#   '도달',
#   '연금',
#   '재정',
#   '과학',
#   '조사',
#   '연구',
#   '국민',
#   '의견',
#   '수렴',
#   '공론',
#   '작업',
#   '속도',
#   '추진',
#   '국회',
#   '개혁',
#   '안',
#   '제출',
#   '사랑',
#   '국민',
#   '위기',
#   '도전',
#   '대한민국',
#   '나라',
#   '잘못',
#   '스스로',
#   '의지',
#   '변화',
#   '혁신',
#   '추진',
#   '집착',
#   '타협',
#   '바다',
#   '만족',
#   '자유',
#   '기회',
#   '연대',
#   '미래',
#   '선사',
#   '국민',
#   '제게',
#   '부여',
#   '사명',
#   '국민',
#   '도약',
#   '새해',
#   '자유',
#   '기회',
#   '바다',
#   '감사']]

# %%
# 역토큰화 (토큰화 작업을 되돌림)
detokenized_doc = []
for i in range(len(df)):
    t = ' '.join(content_removed_stopword[i])
    detokenized_doc.append(t)

df['headline_text'] = detokenized_doc # 다시 text['headline_text']에 재저장

# %%
df['headline_text'][:5]
# Out:
# 0    존경 사랑 국민 재외 동포 자유 사랑 세계 시민 나라 자유민주주의 시장 경제 체제 ...
# 1    자랑 국민 감사 마음 무한 책임감 대통령 당선인 국민 공직 사퇴 국민 지지 성원 정...
# 2    국민 용산 시작 대통령 집무실 시대 출발점 소통 대통령실 구현 부처 군림 권력 독점...
# 3    청년 무한 기회 제공 정부 단기 지원 목표 안착 실질 도움 정부 최선 목소리 청년 ...
# 4               국가 희생 분노 나라 약속 윤석열 국가 희생 대한민국 국민 영웅 기억
# Name: headline_text, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(stop_words='english', max_features= 100) # 상위 1,000개의 단어를 보존 
X = vectorizer.fit_transform(df['headline_text'])
X.shape # TF-IDF 행렬의 크기 확인
# Out:
# (85, 100)

# %%
from sklearn.decomposition import LatentDirichletAllocation
lda_model=LatentDirichletAllocation(n_components=7,learning_method='online',max_iter=1)    #random_state=777,

# %%
lda_top=lda_model.fit_transform(X)

# %%
print(lda_model.components_)
print(lda_model.components_.shape)
# Out:
# [[0.83304419 0.90707701 1.00637236 0.83989224 0.9252768  0.74698668
#   0.84240016 0.94460986 0.75827634 0.792801   0.88122425 0.94225718
#   0.91803724 0.78947554 1.13486169 0.88245727 1.15371433 0.91918692
#   0.80771224 0.87082729 0.83260828 1.02275109 0.79129228 0.83343715
#   1.05755812 0.89126233 1.04482457 0.84062141 1.02895926 0.85771239
#   0.96530997 0.79007795 0.84152017 0.9616107  0.98335835 0.78674362
#   0.82769659 0.8925583  0.94220768 0.93238204 0.90605989 0.92571741
#   0.85034269 0.76580216 0.9766715  1.04744879 0.7811702  0.79181011
#   1.04500349 0.90112399 0.96988025 0.96450435 0.8049439  0.91980063
#   1.04209479 1.16497302 0.8366505  0.82327638 0.9569473  1.02232067
#   0.85390876 0.96407946 0.88428871 0.71415628 0.76455265 0.96586089
#   1.14024159 0.95949277 0.97513991 1.01119828 0.92059565 0.83164764
#   1.0779914  0.89975287 0.95686838 0.96931476 0.94632836 0.77351456
#   0.8860064  0.85031363 0.8175873  0.70690928 0.91286903 1.0418738
#   0.77362465 0.80824378 0.8664449  0.80142027 0.75961615 0.81717506
#   0.93068204 0.96471969 0.84737705 0.88878078 0.94392749 0.94359251
#   0.92888752 0.85777572 0.82611348 0.95825404]
#  [0.97707191 0.93072134 1.02088451 1.02239136 1.01395398 0.87312232
#   0.97053433 1.10390036 0.87142981 0.95914334 0.87556316 0.78937387
#   0.97983452 1.01719006 0.83929926 0.85914075 0.88189082 1.32947625
#   0.90601914 0.98422572 0.96425945 1.01343691 0.91354544 0.95088707
#   0.92636066 1.03155376 1.2761349  0.92746585 0.95545672 0.8803259
#   0.92965173 1.02482337 1.11315069 0.96695524 0.97015789 1.03178423
#   0.98374109 1.1650981  0.81598082 0.86062867 0.92139553 0.82819563
#   0.9112032  1.18910807 0.96687931 1.00021636 0.91754358 0.85705697
#   1.02852289 1.12625305 0.86225765 0.80438624 0.9336678  1.0523466
#   0.97665536 0.89597368 0.83335698 0.81902444 0.88260688 1.15851842
#   0.85337546 0.75084802 0.9486994  0.83522571 0.95871678 0.76874748
#   0.94822697 1.14575051 0.84243389 1.1767477  0.85804178 0.97055193
#   0.86977753 0.97261721 1.24393671 1.01659406 0.75465938 0.9735052
#   1.08851832 0.87565856 0.89048609 0.84369589 0.82267494 1.12724702
#   0.93660438 0.89211981 1.04691341 1.00194597 0.92591984 0.9327668
#   0.75699398 0.93052142 0.88156266 0.87861851 0.84309145 0.98356524
#   0.76216615 0.95756502 1.0655136  0.94843543]
#  [0.9474614  0.99107513 0.85778279 0.86934333 1.11354721 0.81115114
#   1.08632678 0.81443629 0.83703896 0.91378271 0.75903326 0.77583063
#   1.11917637 0.94950445 0.70649749 0.91266922 1.07787798 1.40879986
#   0.83540981 1.03969935 0.77895407 0.84169277 0.77728407 0.82848561
#   0.96826885 0.90513705 0.9789255  0.83965128 0.85427549 1.10784084
#   1.16168605 0.9339556  0.92947571 0.9004453  0.93366543 1.04785954
#   0.81949599 1.05074249 1.01393517 1.00455394 0.95381345 0.8815093
#   0.96004312 0.92088397 1.04988452 0.78243364 0.76692948 0.87162455
#   0.98534902 0.77976628 0.95655738 0.87157676 0.96951216 0.63496132
#   0.82628157 0.98171542 1.14388291 1.13260537 0.86076801 0.80412193
#   0.97668331 0.96737917 0.67026319 0.9675011  0.87824864 0.97845791
#   0.79980197 0.89311614 0.95791435 0.93083566 1.27204954 1.09702151
#   0.81602399 1.00837956 0.82626889 0.86513068 0.79239724 0.85966915
#   0.83438714 1.02018438 0.87782903 1.04683579 1.08978968 1.04387151
#   0.7607329  0.79279431 0.82128979 0.84641108 0.8415742  0.90624857
#   1.15791192 0.83731639 1.01998306 0.94272189 0.79949791 0.89694154
#   0.94474072 0.9470814  0.79352399 0.92704616]
#  [0.81964485 1.00473107 0.89401597 0.94585059 0.94199617 0.92073538
#   1.14754188 1.0534361  1.03491636 0.97168697 0.89846997 1.12413807
#   0.9270419  0.77264831 0.98070962 0.81501894 0.92790852 1.05814705
#   1.33321776 1.07400046 0.855733   0.99218104 1.16592275 0.88312186
#   1.08418409 1.08063776 0.93877828 0.88576817 0.74024131 0.94403648
#   1.18968953 0.88049024 1.13441568 0.79018593 1.00944591 0.7747732
#   0.95464218 0.89166192 1.056367   1.03991319 1.06945436 0.93864363
#   0.93071459 0.96076828 0.76663043 0.96143956 0.81535315 0.95576529
#   1.14840462 0.91854359 0.95641618 0.92271102 0.85357364 0.84929167
#   0.88562386 0.85513728 0.86777329 0.85573656 0.91337859 0.96427376
#   1.06636974 1.27808139 0.81422839 1.28861092 0.86534981 0.81570357
#   0.79107031 1.15513102 1.02000353 1.04461621 1.03428419 0.86760971
#   0.87639719 0.89125197 1.03663387 0.9506358  0.99390514 0.9115674
#   0.79567529 0.97491511 0.9537901  0.91305576 0.76784088 0.95529066
#   0.86976616 0.82228004 0.96372183 0.83829945 0.80825826 0.99230477
#   0.8521686  1.12998509 0.77894692 0.85745003 0.92740927 1.03065129
#   0.93727639 0.91133914 0.99334843 1.01404623]
#  [0.81673772 0.96613159 1.02050603 0.83065296 0.88524044 1.12724244
#   1.05202701 0.9682646  0.90747573 0.86104189 0.822211   0.81302734
#   0.85835193 0.92409148 0.86362976 0.87419777 1.22873779 2.01261906
#   0.82331304 0.83741915 0.94091889 0.80536557 1.01340433 0.89783961
#   0.87898902 0.93130432 1.04516091 0.83816237 0.81891151 0.75250776
#   1.08650215 0.81728614 1.08709853 0.92519943 1.09991471 0.87014252
#   0.94585259 0.93655281 0.82560662 0.83404004 0.91229642 0.89080031
#   0.98506432 0.95371081 0.91254631 0.98887864 1.02794384 0.88741546
#   1.11248407 1.06593331 0.93983552 0.95011731 0.85859744 0.96491014
#   0.89013375 1.13016449 1.02997698 1.030448   1.13075394 0.79589403
#   1.10114791 0.96632951 1.04557368 0.85998715 0.86360658 0.82032597
#   0.7433326  0.99706167 0.94874489 0.8707618  0.9469632  1.09157308
#   0.86578407 0.81003391 1.09757686 0.90911576 0.79737348 1.00574488
#   0.98104385 0.89284818 0.8241952  0.93119313 0.96668358 1.02173036
#   0.92826257 0.92076948 0.9679474  0.96594055 0.94157959 0.98758808
#   1.24797272 0.96875868 0.8640767  0.79394174 1.00977263 0.84297843
#   1.01934506 1.00202523 0.91018522 1.03696191]
#  [0.86106301 0.94722348 0.78727788 0.89582102 0.85845544 0.92820148
#   0.82724689 0.74011015 1.08000359 0.72569006 0.84804083 0.79658835
#   0.92861432 0.86650703 0.78701487 0.95899215 0.94779005 0.95533683
#   0.93060866 0.81984797 0.91688665 0.76024867 0.80868867 0.93128252
#   0.96005167 0.85312451 0.96054639 0.96932179 0.75638082 0.86888504
#   1.01592015 1.09484424 0.75052584 0.92701313 0.77865545 1.02731226
#   0.79104303 0.95046022 0.79050272 0.83300768 0.90413552 0.8466856
#   0.81848439 0.80684424 0.79523037 0.9457126  1.01300725 0.89494343
#   1.03903343 0.73633812 1.03299303 0.80100966 0.73760996 1.00055014
#   1.03791346 0.93773654 1.09761273 0.98234009 1.05314264 0.84142403
#   0.89898857 0.90888697 0.80790639 1.13423915 0.89077384 0.98913439
#   0.89035215 0.92851317 0.8505895  0.96474485 0.86889838 0.82154907
#   0.83146026 0.77106008 0.85028374 1.04638426 0.77213535 0.72691197
#   0.71970139 0.80460605 1.10221659 0.83217544 0.97179245 0.95053865
#   0.78879231 0.96395028 0.85346733 0.71624121 0.79696896 0.7966293
#   1.010701   1.05048889 0.82793714 0.85086994 0.98683251 0.76478389
#   0.86278411 1.09673789 0.82748332 0.81324771]
#  [0.94317599 0.8140601  0.81676348 0.92287274 0.81542097 0.92739849
#   1.2864188  0.82225726 0.83298194 0.90405052 0.89452765 1.18471238
#   0.9416321  0.94131191 0.96535797 0.99650535 0.80085174 1.15415684
#   1.04280252 1.11481843 0.96319027 0.90233618 0.92333011 0.92661843
#   0.81269148 0.89149144 0.91287387 0.85375205 1.00006237 0.87935093
#   0.91304748 0.94513901 1.02489224 1.03005878 0.84508493 0.83016285
#   0.88683617 0.96121266 0.88700138 0.94459973 0.87002462 0.9681245
#   1.01745678 0.76039422 0.88252246 0.68390262 1.02119381 0.96425647
#   0.84138317 1.18326862 0.97602492 0.77417009 0.9887846  0.99164952
#   0.79188524 0.92404178 0.85592001 1.00608347 0.8820163  0.92393996
#   0.90142287 1.13838446 0.84380731 1.03723295 1.09842256 0.81895942
#   1.0141044  1.04766281 0.97298729 0.86159397 1.02856532 0.91284809
#   1.01346685 0.90910148 1.03541707 0.75145553 1.03495745 0.93865264
#   1.01058687 0.91815308 0.93893657 0.83594648 0.81522443 1.14563332
#   0.92339657 0.93857556 1.01325592 1.05945604 1.00402024 1.07389488
#   0.77563653 0.80905828 0.81261554 0.871501   0.84091105 0.90921103
#   1.10401669 0.92183621 0.85002702 0.93742346]]
# (7, 100)

# %%
terms = vectorizer.get_feature_names() # 단어 집합. 1,000개의 단어가 저장됨.

def get_topics(components, feature_names, n=10):
    for idx, topic in enumerate(components):
        print("Topic %d:" % (idx+1), [(feature_names[i], topic[i].round(2)) for i in topic.argsort()[:-n - 1:-1]])
get_topics(lda_model.components_,terms)
# Out:
# Topic 1: [('시장', 1.16), ('국가', 1.15), ('원전', 1.14), ('교육', 1.13), ('적극', 1.08), ('기술', 1.06), ('부처', 1.05), ('사회', 1.05), ('나라', 1.04), ('수출', 1.04)]
# Topic 2: [('국민', 1.33), ('나라', 1.28), ('정부', 1.24), ('변화', 1.19), ('자리', 1.18), ('미래', 1.17), ('안정', 1.16), ('위기', 1.15), ('지원', 1.13), ('산업', 1.13)]
# Topic 3: [('국민', 1.41), ('자유', 1.27), ('대응', 1.16), ('피해', 1.16), ('신속', 1.14), ('안보', 1.13), ('관계', 1.12), ('개선', 1.11), ('당부', 1.11), ('재정', 1.1)]
# Topic 4: [('국제', 1.33), ('역할', 1.29), ('양국', 1.28), ('대응', 1.19), ('금융', 1.17), ('위기', 1.16), ('사회', 1.15), ('경제', 1.15), ('대한민국', 1.13), ('필요', 1.13)]
# Topic 5: [('국민', 2.01), ('피해', 1.25), ('국가', 1.23), ('안전', 1.13), ('시장', 1.13), ('개혁', 1.13), ('사회', 1.11), ('약자', 1.1), ('디지털', 1.1), ('정부', 1.1)]
# Topic 6: [('역할', 1.13), ('중요', 1.1), ('신속', 1.1), ('협력', 1.1), ('대통령', 1.09), ('공공', 1.08), ('안전', 1.05), ('필요', 1.05), ('정상', 1.05), ('사회', 1.04)]
# Topic 7: [('경제', 1.29), ('과학', 1.18), ('산업', 1.18), ('국민', 1.15), ('지원', 1.15), ('양국', 1.14), ('규제', 1.11), ('현장', 1.1), ('연대', 1.1), ('평화', 1.07)]
